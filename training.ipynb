# %% [markdown]
# # 0.Setup and data loading

# %%
import pandas as pd
import numpy as np
import os
import random

# ignore warnings
import warnings
warnings.filterwarnings('ignore')

import importlib
import train_models_util
import feature_importance
import evaluate_models_util
importlib.reload(train_models_util)
importlib.reload(feature_importance)
importlib.reload(evaluate_models_util)
from train_models_util import (
    train_xgb_optuna, 
    train_catboost_optuna, 
    train_lgbm_optuna
)
from evaluate_models_util import evaluate_and_log
from feature_importance import get_top_features_shap

# set all random seeds for reproducibility
np.random.seed(42)
random.seed(42)
os.environ['PYTHONHASHSEED'] = str(42)

# %%
EXPERIMENT_NAME = "Fraud-detection-custom-thresholds_v12_downsample_auc_pr"

# %%
from functools import partial

common_eval_kwargs = dict(
    results_dir="ai-gen/results",
    top_k_list=[1000, 5000, 10000],
    cost_threshold_selection=True,
    bootstrap_n=200,
    time_col="TransactionDT",
    time_unit="s",
    time_freq="M",
    time_origin="start",
    min_slice_size=500,
)
evaluate_and_log = partial(evaluate_and_log, **common_eval_kwargs)

# %%
data_folder = 'ieee-fraud-detection-data/processed/'

data = pd.read_csv(f'{data_folder}train_processed.csv')

# %%
data = data.drop(columns=['TransactionDT','uid'], axis='columns')

# %%
cat_cols = np.array(data.select_dtypes(include=['object']).columns)
for c in cat_cols:
    if c in data.columns:
        if data[c].isnull().sum()>0:
            data[c].fillna('missing', inplace=True)
        data[c] = data[c].astype('category')

# %%
# attempt without suffle, since the data have time relation
n = len(data)
split_idx = int(n * 0.8) 

train = data.iloc[:split_idx]
test = data.iloc[split_idx:]

# %%
del data, cat_cols, c #,fraud_indices, non_fraud_indices,
import gc
gc.collect()
# Out:
# 104

# %% [markdown]
# ## Some more features

# %%
NON_FRAUD_RATIO = 5   # keep 5 non-fraud per fraud
RANDOM_STATE = 42

#Save original index
train["original_index"] = train.index

fraud_df = train[train['isFraud'] == 1]
non_fraud_df = train[train['isFraud'] == 0]

# -----------------------------
# COMPUTE SAMPLE SIZE
# -----------------------------
target_non_fraud = min(
    len(non_fraud_df),
    NON_FRAUD_RATIO * len(fraud_df)
)

# -----------------------------
# DOWNSAMPLE
# -----------------------------
downsampled_non_fraud = non_fraud_df.sample(
    n=target_non_fraud,
    random_state=RANDOM_STATE
)

train = pd.concat([fraud_df, downsampled_non_fraud], ignore_index=True)

# Restore original order
train = train.sort_values("original_index")

# Optional: drop helper column
train = train.drop(columns=["original_index"])

print("Done.")
print(f"Fraud kept: {len(fraud_df)}")
print(f"Non-fraud kept: {len(downsampled_non_fraud)}")
print(f"Final size: {len(train)}")
# Out:
# Done.
# Fraud kept: 16599
# Non-fraud kept: 82995
# Final size: 99594

# %%
del downsampled_non_fraud, target_non_fraud, fraud_df, non_fraud_df
import gc
gc.collect()
# Out:
# 0

# %% [markdown]
# ## 1. Full Features

# %%
# split to X and y
X_train = train.drop(columns='isFraud', axis='columns')
X_test = test.drop(columns='isFraud', axis='columns')

y_train = train['isFraud']
y_test = test['isFraud']

del train, test

# %%
X_train.shape, X_test.shape
# Out:
# ((99594, 748), (118108, 748))

# %% [markdown]
# ### 1.0 Baseline models

# %%
from sklearn.preprocessing import OneHotEncoder

def encode_categoricals(
    X_train: pd.DataFrame,
    X_test: pd.DataFrame,
    cardinality_threshold: int = 10,
    drop_first: bool = False,
    missing_sentinel: str = "__MISSING__",
) -> tuple[pd.DataFrame, pd.DataFrame, dict[str, any]]:
    """Encode categorical features in `X_train` and `X_test`.

    - Categorical columns with unique values > `cardinality_threshold` are
      frequency-encoded (mapping categories to their training frequency).
    - Other categorical columns are one-hot-encoded (trained on `X_train`,
      `handle_unknown='ignore'` to allow unseen test categories).

    Returns (X_train_encoded, X_test_encoded, encoders) where `encoders` is a
    dict containing the fitted OneHotEncoder (if any) and frequency maps.

    Args:
      X_train, X_test: pandas DataFrames with identical columns.
      cardinality_threshold: threshold above which frequency encoding is used.
      drop_first: whether to drop the first level in one-hot encoding.
      missing_sentinel: placeholder used for NaN categories when fitting.

    Example:
      X_tr_enc, X_te_enc, enc = encode_categoricals(X_train, X_test)
    """
    if not isinstance(X_train, pd.DataFrame) or not isinstance(
        X_test, pd.DataFrame
    ):
        raise TypeError("X_train and X_test must be pandas DataFrame objects")

    # Copy inputs to avoid inplace changes
    X_train = X_train.copy()
    X_test = X_test.copy()

    # Identify categorical columns (object or category dtype)
    cat_cols = list(
        X_train.select_dtypes(include=["object", "category"]).columns
    )

    # Containers for outputs
    freq_maps: dict[str, dict[any, float]] = {}
    onehot_cols = []

    # Determine which columns get frequency encoding vs one-hot
    for col in cat_cols:
        n_unique = X_train[col].nunique(dropna=False)
        if n_unique > cardinality_threshold:
            # frequency encoding
            vc = X_train[col].astype(object).fillna(missing_sentinel).value_counts(normalize=True)
            freq_map = vc.to_dict()
            freq_maps[col] = freq_map
        else:
            onehot_cols.append(col)

    # Apply frequency encoding
    for col, fmap in freq_maps.items():
        X_train[col] = X_train[col].astype(object).fillna(missing_sentinel).map(fmap).fillna(0.0)
        X_test[col] = X_test[col].astype(object).fillna(missing_sentinel).map(fmap).fillna(0.0)

    # Apply one-hot encoding on remaining categorical columns
    ohe = None
    ohe_feature_names = []
    if onehot_cols:
        # Replace NaN with sentinel to treat as a category
        X_train_ohe_input = X_train[onehot_cols].astype(object).fillna(missing_sentinel)
        X_test_ohe_input = X_test[onehot_cols].astype(object).fillna(missing_sentinel)

        ohe = OneHotEncoder(sparse_output=False, handle_unknown="ignore", drop="first" if drop_first else None)
        ohe.fit(X_train_ohe_input)

        X_train_ohe = ohe.transform(X_train_ohe_input)
        X_test_ohe = ohe.transform(X_test_ohe_input)

        ohe_feature_names = list(ohe.get_feature_names_out(onehot_cols))

        X_train_ohe_df = pd.DataFrame(
            X_train_ohe, columns=ohe_feature_names, index=X_train.index
        )
        X_test_ohe_df = pd.DataFrame(
            X_test_ohe, columns=ohe_feature_names, index=X_test.index
        )

    # Build final DataFrames: start with non-categorical columns
    non_cat_cols = [c for c in X_train.columns if c not in cat_cols]

    X_train_final = X_train[non_cat_cols].copy()
    X_test_final = X_test[non_cat_cols].copy()

    # Add frequency-encoded columns (they replaced originals in-place above)
    for col in freq_maps.keys():
        X_train_final[col] = X_train[col]
        X_test_final[col] = X_test[col]

    # Add one-hot encoded columns
    if onehot_cols:
        X_train_final = pd.concat([X_train_final, X_train_ohe_df], axis=1)
        X_test_final = pd.concat([X_test_final, X_test_ohe_df], axis=1)
        
    return X_train_final, X_test_final

# %%
X_train_enc, X_test_enc = encode_categoricals(X_train, X_test)

# %%
X_train_enc.fillna(-1, inplace=True)
X_test_enc.fillna(-1,inplace=True)

# %%
# --- Baselines Table ---
from evaluate_models_util import run_baseline_table

results_dir = "ai-gen/results"
baseline_df = run_baseline_table(
    X_train=X_train_enc,
    y_train=y_train,
    X_test=X_test_enc,
    y_test=y_test,
    results_dir=results_dir,
    top_k_list=common_eval_kwargs["top_k_list"]
)
baseline_df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 12
#       2 from evaluate_models_util import run_baseline_table
#       4 results_dir = "ai-gen/results"
#       5 baseline_df = run_baseline_table(
#       6     X_train=X_train_enc,
#       7     y_train=y_train,
#       8     X_test=X_test_enc,
#       9     y_test=y_test,
#      10     results_dir=results_dir,
#      11     top_k_list=common_eval_kwargs["top_k_list"],
# ---> 12     top_k_percents=common_eval_kwargs["top_k_percents"],
#      13 )
#      14 baseline_df.head()
#
# KeyError: 'top_k_percents'

# %% [markdown]
# ### 1.1. XGBoost

# %%
model_xgboost_full, best_params_xgboost_full, hist_df, plot_paths = train_xgb_optuna(X_train, y_train)
# Out:
# [I 2026-01-29 18:44:43,982] A new study created in memory with name: xgboost_aucpr_optimization
# [Optuna XGBoost Tuning]:   0%|          | 0/30 [00:00<?, ?trial/s]
# [I 2026-01-29 18:47:03,026] Trial 0 finished with value: 0.8954892701646185 and parameters: {'learning_rate': 0.028362226043413374, 'max_depth': 4, 'subsample': 0.6341932046086788, 'colsample_bytree': 0.9561424522420965, 'min_child_weight': 0.03375612763551568, 'gamma': 0.34650701863593036}. Best is trial 0 with value: 0.8954892701646185.
# [I 2026-01-29 18:49:33,158] Trial 1 finished with value: 0.8994966873787614 and parameters: {'learning_rate': 0.01730797505545923, 'max_depth': 5, 'subsample': 0.7657086964887356, 'colsample_bytree': 0.8706190846574959, 'min_child_weight': 0.004856583732723209, 'gamma': 0.6776466470208725}. Best is trial 1 with value: 0.8994966873787614.
# [I 2026-01-29 18:52:08,182] Trial 2 finished with value: 0.9019918395200284 and parameters: {'learning_rate': 0.02136285678812265, 'max_depth': 5, 'subsample': 0.8377713271860381, 'colsample_bytree': 0.9632775488120147, 'min_child_weight': 0.023352076214908687, 'gamma': 2.910440958355813}. Best is trial 2 with value: 0.9019918395200284.
# [I 2026-01-29 18:55:19,471] Trial 3 finished with value: 0.9196694317568318 and parameters: {'learning_rate': 0.022791518622683048, 'max_depth': 8, 'subsample': 0.8877757295687976, 'colsample_bytree': 0.5402335979995667, 'min_child_weight': 0.00313193831020268, 'gamma': 0.004662333290324505}. Best is trial 3 with value: 0.9196694317568318.
# [I 2026-01-29 18:57:31,376] Trial 4 finished with value: 0.8815963374421797 and parameters: {'learning_rate': 0.017974471128133492, 'max_depth': 3, 'subsample': 0.9611607197525898, 'colsample_bytree': 0.9932612278348342, 'min_child_weight': 0.00895625922172782, 'gamma': 0.8432238661446873}. Best is trial 3 with value: 0.9196694317568318.
# [I 2026-01-29 19:00:20,370] Trial 5 finished with value: 0.9010078400110558 and parameters: {'learning_rate': 0.011222748789452654, 'max_depth': 6, 'subsample': 0.7925250476568604, 'colsample_bytree': 0.8371615362213474, 'min_child_weight': 0.008478544418890881, 'gamma': 1.2904429538224527}. Best is trial 3 with value: 0.9196694317568318.
# [I 2026-01-29 19:03:46,979] Trial 6 finished with value: 0.9148590620002865 and parameters: {'learning_rate': 0.014155514893683505, 'max_depth': 8, 'subsample': 0.6894390794299188, 'colsample_bytree': 0.5877746899164455, 'min_child_weight': 0.013964148798571361, 'gamma': 2.00924033174163}. Best is trial 3 with value: 0.9196694317568318.
# [I 2026-01-29 19:06:22,480] Trial 7 finished with value: 0.9087422533875236 and parameters: {'learning_rate': 0.01835852506491559, 'max_depth': 6, 'subsample': 0.758683526740741, 'colsample_bytree': 0.5395777977229641, 'min_child_weight': 0.0012752367938203384, 'gamma': 3.436881890895775}. Best is trial 3 with value: 0.9196694317568318.
# [I 2026-01-29 19:09:47,026] Trial 8 finished with value: 0.9159739253969729 and parameters: {'learning_rate': 0.01539285303727103, 'max_depth': 8, 'subsample': 0.8195253684271225, 'colsample_bytree': 0.6179806216688458, 'min_child_weight': 0.0018272028129618742, 'gamma': 2.9738478040699006}. Best is trial 3 with value: 0.9196694317568318.
# [I 2026-01-29 19:12:14,369] Trial 9 finished with value: 0.9054165749496814 and parameters: {'learning_rate': 0.018301145186022254, 'max_depth': 6, 'subsample': 0.5103371177923156, 'colsample_bytree': 0.6329383622448068, 'min_child_weight': 0.02375248418272254, 'gamma': 0.609496457902105}. Best is trial 3 with value: 0.9196694317568318.
# [I 2026-01-29 19:15:12,949] Trial 10 finished with value: 0.9084994086691953 and parameters: {'learning_rate': 0.023542717102504933, 'max_depth': 7, 'subsample': 0.9987482700076257, 'colsample_bytree': 0.7303847195821414, 'min_child_weight': 0.1743203032385839, 'gamma': 4.887214534049329}. Best is trial 3 with value: 0.9196694317568318.
# [I 2026-01-29 19:18:19,057] Trial 11 finished with value: 0.9194721706410688 and parameters: {'learning_rate': 0.025424817920827195, 'max_depth': 8, 'subsample': 0.878082231363998, 'colsample_bytree': 0.5018457820434447, 'min_child_weight': 0.0010177645230349838, 'gamma': 3.687618939379783}. Best is trial 3 with value: 0.9196694317568318.
# [I 2026-01-29 19:21:20,206] Trial 12 finished with value: 0.9208744174658117 and parameters: {'learning_rate': 0.02588331516017445, 'max_depth': 8, 'subsample': 0.8986338369394369, 'colsample_bytree': 0.5127208351125853, 'min_child_weight': 0.002711588219864906, 'gamma': 4.263824793203529}. Best is trial 12 with value: 0.9208744174658117.
# [I 2026-01-29 19:23:57,579] Trial 13 finished with value: 0.9130138439379377 and parameters: {'learning_rate': 0.028835641535921296, 'max_depth': 7, 'subsample': 0.9132059693903913, 'colsample_bytree': 0.6971075270399171, 'min_child_weight': 0.09888309028199369, 'gamma': 4.6663146861992875}. Best is trial 12 with value: 0.9208744174658117.
# [I 2026-01-29 19:26:34,243] Trial 14 finished with value: 0.9156168125286968 and parameters: {'learning_rate': 0.025211336712207023, 'max_depth': 7, 'subsample': 0.9008472364745167, 'colsample_bytree': 0.5631643957200578, 'min_child_weight': 0.003892135683723442, 'gamma': 1.8804206573297062}. Best is trial 12 with value: 0.9208744174658117.
# [I 2026-01-29 19:29:50,795] Trial 15 finished with value: 0.9170692930014243 and parameters: {'learning_rate': 0.02126644823313057, 'max_depth': 8, 'subsample': 0.9202832704505048, 'colsample_bytree': 0.6806676863829759, 'min_child_weight': 0.9540404694693321, 'gamma': 4.097851977174806}. Best is trial 12 with value: 0.9208744174658117.
# [I 2026-01-29 19:32:37,696] Trial 16 finished with value: 0.9111638107517503 and parameters: {'learning_rate': 0.026067540480268308, 'max_depth': 7, 'subsample': 0.6538030252761402, 'colsample_bytree': 0.8050923874676009, 'min_child_weight': 0.0028719449789020544, 'gamma': 0.011020594299802542}. Best is trial 12 with value: 0.9208744174658117.
# [I 2026-01-29 19:35:31,213] Trial 17 finished with value: 0.9184421703420916 and parameters: {'learning_rate': 0.022034679121289306, 'max_depth': 8, 'subsample': 0.8528905089599492, 'colsample_bytree': 0.5006104610293189, 'min_child_weight': 0.06807794868753614, 'gamma': 1.7404340308559845}. Best is trial 12 with value: 0.9208744174658117.
# [I 2026-01-29 19:38:20,382] Trial 18 finished with value: 0.9155992144649749 and parameters: {'learning_rate': 0.027512289299719914, 'max_depth': 7, 'subsample': 0.9720806537576423, 'colsample_bytree': 0.6529583953908458, 'min_child_weight': 0.002877239499609293, 'gamma': 2.6716496718716205}. Best is trial 12 with value: 0.9208744174658117.
# [I 2026-01-29 19:40:25,440] Trial 19 finished with value: 0.8841925560355673 and parameters: {'learning_rate': 0.023587968708359268, 'max_depth': 3, 'subsample': 0.7117959458933776, 'colsample_bytree': 0.7675251842003956, 'min_child_weight': 0.0066288547499650675, 'gamma': 3.972011356929389}. Best is trial 12 with value: 0.9208744174658117.
# [I 2026-01-29 19:42:23,273] Trial 20 finished with value: 0.8888294173301411 and parameters: {'learning_rate': 0.023420254777203782, 'max_depth': 4, 'subsample': 0.5514286944605027, 'colsample_bytree': 0.5801020386684415, 'min_child_weight': 0.35660105369481354, 'gamma': 4.42866750341601}. Best is trial 12 with value: 0.9208744174658117.
# [I 2026-01-29 19:45:16,300] Trial 21 finished with value: 0.9191686382016275 and parameters: {'learning_rate': 0.029962133634182056, 'max_depth': 8, 'subsample': 0.8773886375254886, 'colsample_bytree': 0.5091256030711792, 'min_child_weight': 0.0015719525221108942, 'gamma': 3.619670670922126}. Best is trial 12 with value: 0.9208744174658117.
# [I 2026-01-29 19:48:10,668] Trial 22 finished with value: 0.9191270596570918 and parameters: {'learning_rate': 0.025950105206861668, 'max_depth': 8, 'subsample': 0.9505189039702722, 'colsample_bytree': 0.5431586413115732, 'min_child_weight': 0.001102695179562402, 'gamma': 3.5408630031953523}. Best is trial 12 with value: 0.9208744174658117.
# [I 2026-01-29 19:50:52,171] Trial 23 finished with value: 0.9149544763598128 and parameters: {'learning_rate': 0.024789114194874305, 'max_depth': 7, 'subsample': 0.8675939681909771, 'colsample_bytree': 0.597188014318757, 'min_child_weight': 0.002271167384725889, 'gamma': 4.411241027117709}. Best is trial 12 with value: 0.9208744174658117.
# [I 2026-01-29 19:53:43,931] Trial 24 finished with value: 0.9191632023860284 and parameters: {'learning_rate': 0.02677966877433874, 'max_depth': 8, 'subsample': 0.8015218973146543, 'colsample_bytree': 0.5244668881746055, 'min_child_weight': 0.0010602273835872312, 'gamma': 2.3581864746037153}. Best is trial 12 with value: 0.9208744174658117.
# [I 2026-01-29 19:56:53,197] Trial 25 finished with value: 0.917851696844837 and parameters: {'learning_rate': 0.019786232777361346, 'max_depth': 8, 'subsample': 0.9209124672937669, 'colsample_bytree': 0.5053019452431587, 'min_child_weight': 0.00369940795073331, 'gamma': 3.1581213259591925}. Best is trial 12 with value: 0.9208744174658117.
# [I 2026-01-29 19:59:29,038] Trial 26 finished with value: 0.9144689263349326 and parameters: {'learning_rate': 0.02272572719799084, 'max_depth': 7, 'subsample': 0.8879139311976428, 'colsample_bytree': 0.5579637154922503, 'min_child_weight': 0.014442496461949901, 'gamma': 3.946509645388132}. Best is trial 12 with value: 0.9208744174658117.
# [I 2026-01-29 20:01:54,329] Trial 27 finished with value: 0.909297084881374 and parameters: {'learning_rate': 0.024816255294087222, 'max_depth': 6, 'subsample': 0.8426811753926721, 'colsample_bytree': 0.6529536020966822, 'min_child_weight': 0.002030553490362182, 'gamma': 4.994950600225945}. Best is trial 12 with value: 0.9208744174658117.
# [I 2026-01-29 20:05:03,551] Trial 28 finished with value: 0.9165867888948022 and parameters: {'learning_rate': 0.02072956604651008, 'max_depth': 8, 'subsample': 0.9996158208564739, 'colsample_bytree': 0.6026267702492657, 'min_child_weight': 0.0058503673352726625, 'gamma': 2.50500431252898}. Best is trial 12 with value: 0.9208744174658117.
# [I 2026-01-29 20:07:11,890] Trial 29 finished with value: 0.8967315079852297 and parameters: {'learning_rate': 0.02812172027950807, 'max_depth': 4, 'subsample': 0.735278669260302, 'colsample_bytree': 0.9179366875723065, 'min_child_weight': 0.045938919988559423, 'gamma': 1.347461197305584}. Best is trial 12 with value: 0.9208744174658117.
# [INFO] Best XGBoost params: {'learning_rate': 0.02588331516017445, 'max_depth': 8, 'subsample': 0.8986338369394369, 'colsample_bytree': 0.5127208351125853, 'min_child_weight': 0.002711588219864906, 'gamma': 4.263824793203529}
# [0]	validation_0-auc:0.82599
# [100]	validation_0-auc:0.92524
# [200]	validation_0-auc:0.93437
# [300]	validation_0-auc:0.93844
# [400]	validation_0-auc:0.93980
# [500]	validation_0-auc:0.94018
# [600]	validation_0-auc:0.94038
# [700]	validation_0-auc:0.94103
# [781]	validation_0-auc:0.94070

# %%
evaluate_and_log(model_xgboost_full, X_test, y_test, experiment_name=EXPERIMENT_NAME, run_name="XGBoost_Optuna_fullfeatures", hp_search_history=hist_df, hp_search_plots= plot_paths)
# Out:
# 2026/01/29 20:09:40 INFO mlflow.tracking.fluent: Experiment with name 'Fraud-detection-custom-thresholds_v11_downsample_auc_pr' does not exist. Creating a new experiment.
# [INFO] Logged metrics: {'roc_auc': np.float64(0.907029042328807), 'pr_auc': np.float64(0.5230998080480729), 'precision': 0.3000326832988343, 'recall': 0.6776574803149606, 'f1': 0.4159178433889602, 'custom_loss': np.float64(1.163553696616656), 'precision_at_100': 0.99, 'recall_at_100': 0.02436023622047244, 'precision_at_118': 0.9915254237288136, 'recall_at_118': 0.02878937007874016, 'precision_at_500': 0.92, 'recall_at_500': 0.11318897637795275, 'precision_at_591': 0.9103214890016921, 'recall_at_591': 0.13238188976377951, 'precision_at_1000': 0.87, 'recall_at_1000': 0.2140748031496063, 'precision_at_1181': 0.8543607112616427, 'recall_at_1181': 0.2482775590551181, 'cost_opt_threshold': 0.09852437502774768, 'cost_opt_custom_loss': 0.6023385376096454, 'cost_opt_precision': 0.08349036734874853, 'cost_opt_recall': 0.9266732283464567, 'cost_opt_f1': 0.15317971975351324}
# [INFO] Logged SHAP summary plot.
# 2026/01/29 20:10:03 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# [INFO] Evaluation complete and logged.
# {'roc_auc': np.float64(0.907029042328807),
#  'pr_auc': np.float64(0.5230998080480729),
#  'precision': 0.3000326832988343,
#  'recall': 0.6776574803149606,
#  'f1': 0.4159178433889602,
#  'custom_loss': np.float64(1.163553696616656),
#  'precision_at_100': 0.99,
#  'recall_at_100': 0.02436023622047244,
#  'precision_at_118': 0.9915254237288136,
#  'recall_at_118': 0.02878937007874016,
#  'precision_at_500': 0.92,
#  'recall_at_500': 0.11318897637795275,
#  'precision_at_591': 0.9103214890016921,
#  'recall_at_591': 0.13238188976377951,
#  'precision_at_1000': 0.87,
#  'recall_at_1000': 0.2140748031496063,
#  'precision_at_1181': 0.8543607112616427,
#  'recall_at_1181': 0.2482775590551181,
#  'cost_opt_threshold': 0.09852437502774768,
#  'cost_opt_custom_loss': 0.6023385376096454,
#  'cost_opt_precision': 0.08349036734874853,
#  'cost_opt_recall': 0.9266732283464567,
#  'cost_opt_f1': 0.15317971975351324}

# %% [markdown]
# ### 1.2. LightGBM

# %%
model_lgbm_full, best_params_lgbm_full, hist_df, plot_paths = train_lgbm_optuna(X_train, y_train)
# Out:
# [I 2026-01-29 20:10:14,946] A new study created in memory with name: lgbm_aucpr_optimization
# [Optuna LightGBM Tuning]:   0%|          | 0/30 [00:00<?, ?trial/s]
# [I 2026-01-29 20:12:39,597] Trial 0 finished with value: 0.9247920259067804 and parameters: {'num_leaves': 510, 'max_depth': 12, 'learning_rate': 0.023054056326316456, 'min_child_samples': 39, 'reg_alpha': 0.21007700109273109, 'reg_lambda': 0.001968938501320572, 'colsample_bytree': 0.9159739603131691, 'subsample': 0.9443053401673661}. Best is trial 0 with value: 0.9247920259067804.
# [I 2026-01-29 20:15:19,971] Trial 1 finished with value: 0.9290233249068569 and parameters: {'num_leaves': 226, 'max_depth': 18, 'learning_rate': 0.01840142079259877, 'min_child_samples': 40, 'reg_alpha': 0.35967006943856294, 'reg_lambda': 0.20956355077957317, 'colsample_bytree': 0.9061082723025669, 'subsample': 0.8358596957160151}. Best is trial 1 with value: 0.9290233249068569.
# [I 2026-01-29 20:17:31,320] Trial 2 finished with value: 0.9321449597845356 and parameters: {'num_leaves': 411, 'max_depth': 18, 'learning_rate': 0.017240478280515066, 'min_child_samples': 74, 'reg_alpha': 0.37124939512017807, 'reg_lambda': 0.28772085591890456, 'colsample_bytree': 0.8190832859008729, 'subsample': 0.8359467815531877}. Best is trial 2 with value: 0.9321449597845356.
# [I 2026-01-29 20:19:04,094] Trial 3 finished with value: 0.9299081884377469 and parameters: {'num_leaves': 375, 'max_depth': 13, 'learning_rate': 0.02070031523881566, 'min_child_samples': 87, 'reg_alpha': 0.41758699950358114, 'reg_lambda': 0.4351732948853641, 'colsample_bytree': 0.8026453301123916, 'subsample': 0.8532128195458054}. Best is trial 2 with value: 0.9321449597845356.
# [I 2026-01-29 20:20:36,445] Trial 4 finished with value: 0.9300795611318962 and parameters: {'num_leaves': 129, 'max_depth': 18, 'learning_rate': 0.028620702303850443, 'min_child_samples': 80, 'reg_alpha': 0.219449734500746, 'reg_lambda': 0.19763165268444083, 'colsample_bytree': 0.8486015737776885, 'subsample': 0.9943087764079378}. Best is trial 2 with value: 0.9321449597845356.
# [I 2026-01-29 20:21:59,605] Trial 5 finished with value: 0.925127425078139 and parameters: {'num_leaves': 492, 'max_depth': 10, 'learning_rate': 0.0258166262680133, 'min_child_samples': 33, 'reg_alpha': 0.2725589439730915, 'reg_lambda': 0.33248382373071816, 'colsample_bytree': 0.8854173760256754, 'subsample': 0.9337517529528614}. Best is trial 2 with value: 0.9321449597845356.
# [I 2026-01-29 20:24:33,307] Trial 6 finished with value: 0.9283707685182684 and parameters: {'num_leaves': 315, 'max_depth': 19, 'learning_rate': 0.0158204642556997, 'min_child_samples': 37, 'reg_alpha': 0.20433126767576332, 'reg_lambda': 0.3815393554083867, 'colsample_bytree': 0.9741148609269175, 'subsample': 0.8438148306361328}. Best is trial 2 with value: 0.9321449597845356.
# [I 2026-01-29 20:26:19,262] Trial 7 finished with value: 0.9230481738867101 and parameters: {'num_leaves': 410, 'max_depth': 14, 'learning_rate': 0.02085005099333581, 'min_child_samples': 11, 'reg_alpha': 0.4874240031218186, 'reg_lambda': 0.33337466351863126, 'colsample_bytree': 0.8738396234055921, 'subsample': 0.990343910336506}. Best is trial 2 with value: 0.9321449597845356.
# [I 2026-01-29 20:28:27,706] Trial 8 finished with value: 0.928318513409439 and parameters: {'num_leaves': 489, 'max_depth': 20, 'learning_rate': 0.02674409317480462, 'min_child_samples': 24, 'reg_alpha': 0.11618399136673824, 'reg_lambda': 0.042966583448160844, 'colsample_bytree': 0.8736238839246333, 'subsample': 0.8304984645419659}. Best is trial 2 with value: 0.9321449597845356.
# [I 2026-01-29 20:30:23,792] Trial 9 finished with value: 0.9311609074288575 and parameters: {'num_leaves': 176, 'max_depth': 18, 'learning_rate': 0.01673930950417482, 'min_child_samples': 59, 'reg_alpha': 0.4764066259643845, 'reg_lambda': 0.31759517356912953, 'colsample_bytree': 0.8322390390698551, 'subsample': 0.8129177869438302}. Best is trial 2 with value: 0.9321449597845356.
# [I 2026-01-29 20:32:55,636] Trial 10 finished with value: 0.9294085645069018 and parameters: {'num_leaves': 277, 'max_depth': 16, 'learning_rate': 0.011141547360994446, 'min_child_samples': 66, 'reg_alpha': 0.028567527630054962, 'reg_lambda': 0.4951600362870877, 'colsample_bytree': 0.951057832599038, 'subsample': 0.8843590759791295}. Best is trial 2 with value: 0.9321449597845356.
# [I 2026-01-29 20:34:42,474] Trial 11 finished with value: 0.9298811086913178 and parameters: {'num_leaves': 138, 'max_depth': 16, 'learning_rate': 0.014351882007619336, 'min_child_samples': 60, 'reg_alpha': 0.49049252855340614, 'reg_lambda': 0.26325953369310107, 'colsample_bytree': 0.8026763088125787, 'subsample': 0.8053215682373921}. Best is trial 2 with value: 0.9321449597845356.
# [I 2026-01-29 20:37:04,734] Trial 12 finished with value: 0.930948738939691 and parameters: {'num_leaves': 401, 'max_depth': 17, 'learning_rate': 0.016209901824891713, 'min_child_samples': 73, 'reg_alpha': 0.36377775173231774, 'reg_lambda': 0.15051022019914434, 'colsample_bytree': 0.8457619492199876, 'subsample': 0.8036203747526982}. Best is trial 2 with value: 0.9321449597845356.
# [I 2026-01-29 20:39:10,201] Trial 13 finished with value: 0.9306677944815104 and parameters: {'num_leaves': 198, 'max_depth': 20, 'learning_rate': 0.01210391537926727, 'min_child_samples': 98, 'reg_alpha': 0.3940661359007889, 'reg_lambda': 0.27808447547513826, 'colsample_bytree': 0.8320951900555617, 'subsample': 0.8744187347219607}. Best is trial 2 with value: 0.9321449597845356.
# [I 2026-01-29 20:41:11,965] Trial 14 finished with value: 0.9293448225891221 and parameters: {'num_leaves': 351, 'max_depth': 15, 'learning_rate': 0.018281470870818484, 'min_child_samples': 50, 'reg_alpha': 0.287526256904747, 'reg_lambda': 0.12054874420071923, 'colsample_bytree': 0.8247966427664157, 'subsample': 0.9123091067590846}. Best is trial 2 with value: 0.9321449597845356.
# [I 2026-01-29 20:43:58,443] Trial 15 finished with value: 0.9304486345501578 and parameters: {'num_leaves': 443, 'max_depth': 18, 'learning_rate': 0.013381548479534357, 'min_child_samples': 54, 'reg_alpha': 0.4514057714720694, 'reg_lambda': 0.34287610522769596, 'colsample_bytree': 0.9329074385637244, 'subsample': 0.815394386969491}. Best is trial 2 with value: 0.9321449597845356.
# [I 2026-01-29 20:46:10,634] Trial 16 finished with value: 0.9291993267781719 and parameters: {'num_leaves': 264, 'max_depth': 16, 'learning_rate': 0.01753038362422261, 'min_child_samples': 71, 'reg_alpha': 0.3306754336853849, 'reg_lambda': 0.407238380540663, 'colsample_bytree': 0.9990908902586779, 'subsample': 0.8606837515164873}. Best is trial 2 with value: 0.9321449597845356.
# [I 2026-01-29 20:48:14,241] Trial 17 finished with value: 0.931620244187587 and parameters: {'num_leaves': 320, 'max_depth': 19, 'learning_rate': 0.023422841808335666, 'min_child_samples': 90, 'reg_alpha': 0.4278186305665655, 'reg_lambda': 0.23370580239003874, 'colsample_bytree': 0.855143456970781, 'subsample': 0.9023641568660048}. Best is trial 2 with value: 0.9321449597845356.
# [I 2026-01-29 20:50:15,903] Trial 18 finished with value: 0.9308964428005654 and parameters: {'num_leaves': 317, 'max_depth': 19, 'learning_rate': 0.023060101108071652, 'min_child_samples': 96, 'reg_alpha': 0.3122854132292604, 'reg_lambda': 0.19469651040457936, 'colsample_bytree': 0.8661428176395917, 'subsample': 0.9199171453533499}. Best is trial 2 with value: 0.9321449597845356.
# [I 2026-01-29 20:52:25,456] Trial 19 finished with value: 0.9326224515339415 and parameters: {'num_leaves': 457, 'max_depth': 20, 'learning_rate': 0.02399971182510983, 'min_child_samples': 85, 'reg_alpha': 0.42899207087723207, 'reg_lambda': 0.13783757866935004, 'colsample_bytree': 0.8580478909567433, 'subsample': 0.9625121476885652}. Best is trial 19 with value: 0.9326224515339415.
# [I 2026-01-29 20:54:19,877] Trial 20 finished with value: 0.9314845003129983 and parameters: {'num_leaves': 451, 'max_depth': 20, 'learning_rate': 0.029476024056726807, 'min_child_samples': 81, 'reg_alpha': 0.14602453434558252, 'reg_lambda': 0.09704008001351722, 'colsample_bytree': 0.8193533173794433, 'subsample': 0.9678003591288808}. Best is trial 19 with value: 0.9326224515339415.
# [I 2026-01-29 20:56:25,263] Trial 21 finished with value: 0.9315627955208972 and parameters: {'num_leaves': 453, 'max_depth': 19, 'learning_rate': 0.02346558860119811, 'min_child_samples': 89, 'reg_alpha': 0.4200015298802088, 'reg_lambda': 0.24190765252955135, 'colsample_bytree': 0.8574306205651879, 'subsample': 0.898172422434448}. Best is trial 19 with value: 0.9326224515339415.
# [I 2026-01-29 20:58:16,864] Trial 22 finished with value: 0.9312938823588244 and parameters: {'num_leaves': 354, 'max_depth': 17, 'learning_rate': 0.0249791131323427, 'min_child_samples': 88, 'reg_alpha': 0.3829058448997286, 'reg_lambda': 0.14644035311471698, 'colsample_bytree': 0.8447339111778651, 'subsample': 0.9604457427162212}. Best is trial 19 with value: 0.9326224515339415.
# [I 2026-01-29 21:00:36,483] Trial 23 finished with value: 0.9314942926222208 and parameters: {'num_leaves': 411, 'max_depth': 20, 'learning_rate': 0.021659075403078546, 'min_child_samples': 77, 'reg_alpha': 0.44001057330551335, 'reg_lambda': 0.07967235419235913, 'colsample_bytree': 0.8970762480151905, 'subsample': 0.8936755021491967}. Best is trial 19 with value: 0.9326224515339415.
# [I 2026-01-29 21:02:32,207] Trial 24 finished with value: 0.9318505040496374 and parameters: {'num_leaves': 370, 'max_depth': 19, 'learning_rate': 0.02717213390109383, 'min_child_samples': 92, 'reg_alpha': 0.3447804200997588, 'reg_lambda': 0.291016959156822, 'colsample_bytree': 0.815722420963721, 'subsample': 0.8722142531484831}. Best is trial 19 with value: 0.9326224515339415.
# [I 2026-01-29 21:04:16,562] Trial 25 finished with value: 0.9313329939984536 and parameters: {'num_leaves': 378, 'max_depth': 17, 'learning_rate': 0.028434448374639418, 'min_child_samples': 100, 'reg_alpha': 0.31392133063464217, 'reg_lambda': 0.28959574724357995, 'colsample_bytree': 0.8148536568900259, 'subsample': 0.8720207702830169}. Best is trial 19 with value: 0.9326224515339415.
# [I 2026-01-29 21:05:59,426] Trial 26 finished with value: 0.9320172148439821 and parameters: {'num_leaves': 438, 'max_depth': 19, 'learning_rate': 0.026599242815108934, 'min_child_samples': 67, 'reg_alpha': 0.35571369909062456, 'reg_lambda': 0.3771990065420416, 'colsample_bytree': 0.8361351980428893, 'subsample': 0.863214568331237}. Best is trial 19 with value: 0.9326224515339415.
# [I 2026-01-29 21:08:07,490] Trial 27 finished with value: 0.9321861768416801 and parameters: {'num_leaves': 436, 'max_depth': 20, 'learning_rate': 0.02449882684262807, 'min_child_samples': 67, 'reg_alpha': 0.2557652676275112, 'reg_lambda': 0.46185231581898895, 'colsample_bytree': 0.8379579776123525, 'subsample': 0.8221346308765268}. Best is trial 19 with value: 0.9326224515339415.
# [I 2026-01-29 21:10:38,797] Trial 28 finished with value: 0.9325114872190797 and parameters: {'num_leaves': 478, 'max_depth': 20, 'learning_rate': 0.019590893387743204, 'min_child_samples': 65, 'reg_alpha': 0.15430569832334012, 'reg_lambda': 0.48924519311114856, 'colsample_bytree': 0.8888460203512718, 'subsample': 0.8236476386151806}. Best is trial 19 with value: 0.9326224515339415.
# [I 2026-01-29 21:12:09,645] Trial 29 finished with value: 0.9247219474625604 and parameters: {'num_leaves': 496, 'max_depth': 10, 'learning_rate': 0.01933118076887757, 'min_child_samples': 45, 'reg_alpha': 0.13343709726596473, 'reg_lambda': 0.478066990339314, 'colsample_bytree': 0.9255798877352186, 'subsample': 0.9445969486566431}. Best is trial 19 with value: 0.9326224515339415.
# [INFO] Best LightGBM params: {'num_leaves': 457, 'max_depth': 20, 'learning_rate': 0.02399971182510983, 'min_child_samples': 85, 'reg_alpha': 0.42899207087723207, 'reg_lambda': 0.13783757866935004, 'colsample_bytree': 0.8580478909567433, 'subsample': 0.9625121476885652}
# [50]	valid_0's auc: 0.93884	valid_0's binary_logloss: 0.281249
# [100]	valid_0's auc: 0.946361	valid_0's binary_logloss: 0.2362
# [150]	valid_0's auc: 0.948928	valid_0's binary_logloss: 0.217124
# [200]	valid_0's auc: 0.949761	valid_0's binary_logloss: 0.20804
# [250]	valid_0's auc: 0.950141	valid_0's binary_logloss: 0.201775
# [300]	valid_0's auc: 0.950195	valid_0's binary_logloss: 0.197032
# [350]	valid_0's auc: 0.950696	valid_0's binary_logloss: 0.193193
# [400]	valid_0's auc: 0.95096	valid_0's binary_logloss: 0.191318
# [450]	valid_0's auc: 0.951007	valid_0's binary_logloss: 0.191152
# [500]	valid_0's auc: 0.951341	valid_0's binary_logloss: 0.191859

# %%
evaluate_and_log(model_lgbm_full,  X_test, y_test, experiment_name=EXPERIMENT_NAME, run_name="LightGBM_Optuna_fullfeatures", hp_search_history=hist_df, hp_search_plots= plot_paths)
# Out:
# [INFO] Logged metrics: {'roc_auc': np.float64(0.9179631952213775), 'pr_auc': np.float64(0.5809006908092619), 'precision': 0.41517219488970003, 'recall': 0.6437007874015748, 'f1': 0.5047756874095514, 'custom_loss': np.float64(1.2571968029261353), 'precision_at_100': 1.0, 'recall_at_100': 0.024606299212598427, 'precision_at_118': 0.9915254237288136, 'recall_at_118': 0.02878937007874016, 'precision_at_500': 0.956, 'recall_at_500': 0.11761811023622047, 'precision_at_591': 0.9475465313028765, 'recall_at_591': 0.1377952755905512, 'precision_at_1000': 0.91, 'recall_at_1000': 0.22391732283464566, 'precision_at_1181': 0.9017781541066893, 'recall_at_1181': 0.2620570866141732, 'cost_opt_threshold': 0.029918124166915413, 'cost_opt_custom_loss': 0.5914417312967792, 'cost_opt_precision': 0.0783677159529876, 'cost_opt_recall': 0.9384842519685039, 'cost_opt_f1': 0.14465599635894713}
# [INFO] Logged SHAP summary plot.
# 2026/01/29 21:14:48 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# [INFO] Evaluation complete and logged.
# {'roc_auc': np.float64(0.9179631952213775),
#  'pr_auc': np.float64(0.5809006908092619),
#  'precision': 0.41517219488970003,
#  'recall': 0.6437007874015748,
#  'f1': 0.5047756874095514,
#  'custom_loss': np.float64(1.2571968029261353),
#  'precision_at_100': 1.0,
#  'recall_at_100': 0.024606299212598427,
#  'precision_at_118': 0.9915254237288136,
#  'recall_at_118': 0.02878937007874016,
#  'precision_at_500': 0.956,
#  'recall_at_500': 0.11761811023622047,
#  'precision_at_591': 0.9475465313028765,
#  'recall_at_591': 0.1377952755905512,
#  'precision_at_1000': 0.91,
#  'recall_at_1000': 0.22391732283464566,
#  'precision_at_1181': 0.9017781541066893,
#  'recall_at_1181': 0.2620570866141732,
#  'cost_opt_threshold': 0.029918124166915413,
#  'cost_opt_custom_loss': 0.5914417312967792,
#  'cost_opt_precision': 0.0783677159529876,
#  'cost_opt_recall': 0.9384842519685039,
#  'cost_opt_f1': 0.14465599635894713}

# %% [markdown]
# ### 1.3. CatBoost

# %%
model_catboost_full, best_params_catboost_full, hist_df, plot_paths = train_catboost_optuna(X_train, y_train)
# Out:
# [I 2026-01-29 21:15:01,716] A new study created in memory with name: catboost_aucpr_optimization
# [Optuna CatBoost Tuning]:   0%|          | 0/30 [00:00<?, ?trial/s]
# [I 2026-01-29 21:19:04,135] Trial 0 finished with value: 0.9019857408119293 and parameters: {'learning_rate': 0.026329316129956655, 'depth': 6, 'l2_leaf_reg': 6.390091503169519, 'subsample': 0.7119358155384238, 'border_count': 98}. Best is trial 0 with value: 0.9019857408119293.
# [I 2026-01-29 21:21:01,943] Trial 1 finished with value: 0.8769123368203581 and parameters: {'learning_rate': 0.018884046946516478, 'depth': 3, 'l2_leaf_reg': 1.9809452716964508, 'subsample': 0.8258719822142883, 'border_count': 60}. Best is trial 0 with value: 0.9019857408119293.
# [I 2026-01-29 21:26:33,894] Trial 2 finished with value: 0.9118110589136436 and parameters: {'learning_rate': 0.027604124537579412, 'depth': 8, 'l2_leaf_reg': 3.6954847918624645, 'subsample': 0.6773163225136984, 'border_count': 32}. Best is trial 2 with value: 0.9118110589136436.
# [I 2026-01-29 21:28:26,201] Trial 3 finished with value: 0.8733713329162383 and parameters: {'learning_rate': 0.01619946608129117, 'depth': 3, 'l2_leaf_reg': 5.326747956180264, 'subsample': 0.7063280366472001, 'border_count': 62}. Best is trial 2 with value: 0.9118110589136436.
# [I 2026-01-29 21:34:43,976] Trial 4 finished with value: 0.9080028335378046 and parameters: {'learning_rate': 0.023000740622117107, 'depth': 8, 'l2_leaf_reg': 9.514662854348284, 'subsample': 0.7475740407098924, 'border_count': 83}. Best is trial 2 with value: 0.9118110589136436.
# [I 2026-01-29 21:38:04,264] Trial 5 finished with value: 0.8983281918203673 and parameters: {'learning_rate': 0.029025093937640176, 'depth': 5, 'l2_leaf_reg': 2.148894430219416, 'subsample': 0.9310047116500464, 'border_count': 43}. Best is trial 2 with value: 0.9118110589136436.
# [I 2026-01-29 21:41:46,298] Trial 6 finished with value: 0.8990261599044178 and parameters: {'learning_rate': 0.025982433381882136, 'depth': 6, 'l2_leaf_reg': 7.40942003231321, 'subsample': 0.6179464140645302, 'border_count': 60}. Best is trial 2 with value: 0.9118110589136436.
# [I 2026-01-29 21:45:58,470] Trial 7 finished with value: 0.8964883767811894 and parameters: {'learning_rate': 0.01964368311041361, 'depth': 6, 'l2_leaf_reg': 9.22046781878568, 'subsample': 0.8222111452823744, 'border_count': 104}. Best is trial 2 with value: 0.9118110589136436.
# [I 2026-01-29 21:52:33,172] Trial 8 finished with value: 0.912869947463497 and parameters: {'learning_rate': 0.028844498816839356, 'depth': 8, 'l2_leaf_reg': 8.189349282112437, 'subsample': 0.7574521692209916, 'border_count': 112}. Best is trial 8 with value: 0.912869947463497.
# [I 2026-01-29 21:56:46,058] Trial 9 finished with value: 0.894169667546184 and parameters: {'learning_rate': 0.016281730110559903, 'depth': 6, 'l2_leaf_reg': 7.356296109867778, 'subsample': 0.8663744354045435, 'border_count': 95}. Best is trial 8 with value: 0.912869947463497.
# [I 2026-01-29 22:03:53,461] Trial 10 finished with value: 0.8976976925465827 and parameters: {'learning_rate': 0.010018095082347803, 'depth': 8, 'l2_leaf_reg': 4.800566466518539, 'subsample': 0.9725813009923616, 'border_count': 122}. Best is trial 8 with value: 0.912869947463497.
# [I 2026-01-29 22:10:10,222] Trial 11 finished with value: 0.9123812769512557 and parameters: {'learning_rate': 0.029883035164339208, 'depth': 8, 'l2_leaf_reg': 3.936084306521752, 'subsample': 0.6253557456855792, 'border_count': 124}. Best is trial 8 with value: 0.912869947463497.
# [I 2026-01-29 22:14:58,294] Trial 12 finished with value: 0.9074615477821588 and parameters: {'learning_rate': 0.029459777751156976, 'depth': 7, 'l2_leaf_reg': 3.8740244328545135, 'subsample': 0.605948453513963, 'border_count': 128}. Best is trial 8 with value: 0.912869947463497.
# [I 2026-01-29 22:20:03,367] Trial 13 finished with value: 0.9048339888671219 and parameters: {'learning_rate': 0.023238054053057323, 'depth': 7, 'l2_leaf_reg': 8.128884563704869, 'subsample': 0.7586079988512692, 'border_count': 112}. Best is trial 8 with value: 0.912869947463497.
# [I 2026-01-29 22:24:58,638] Trial 14 finished with value: 0.9041078655673003 and parameters: {'learning_rate': 0.023794565814602455, 'depth': 7, 'l2_leaf_reg': 3.535462370832607, 'subsample': 0.64586820569114, 'border_count': 116}. Best is trial 8 with value: 0.912869947463497.
# [I 2026-01-29 22:27:35,403] Trial 15 finished with value: 0.8926390659334981 and parameters: {'learning_rate': 0.029550112479566185, 'depth': 4, 'l2_leaf_reg': 6.046135140194579, 'subsample': 0.874292606928339, 'border_count': 85}. Best is trial 8 with value: 0.912869947463497.
# [I 2026-01-29 22:34:07,156] Trial 16 finished with value: 0.9102671218287397 and parameters: {'learning_rate': 0.025293341393391094, 'depth': 8, 'l2_leaf_reg': 1.341727821722992, 'subsample': 0.7729676026482464, 'border_count': 108}. Best is trial 8 with value: 0.912869947463497.
# [I 2026-01-29 22:39:01,862] Trial 17 finished with value: 0.8923357012952859 and parameters: {'learning_rate': 0.011524488479411696, 'depth': 7, 'l2_leaf_reg': 8.40008803289735, 'subsample': 0.678511134227457, 'border_count': 128}. Best is trial 8 with value: 0.912869947463497.
# [I 2026-01-29 22:42:08,948] Trial 18 finished with value: 0.8916249453174313 and parameters: {'learning_rate': 0.021113003596002256, 'depth': 5, 'l2_leaf_reg': 4.6809887780297625, 'subsample': 0.6506219739404655, 'border_count': 94}. Best is trial 8 with value: 0.912869947463497.
# [I 2026-01-29 22:48:13,486] Trial 19 finished with value: 0.912702792265157 and parameters: {'learning_rate': 0.027813342025311334, 'depth': 8, 'l2_leaf_reg': 6.730914674783728, 'subsample': 0.7240253224428306, 'border_count': 73}. Best is trial 8 with value: 0.912869947463497.
# [I 2026-01-29 22:53:06,414] Trial 20 finished with value: 0.906838302162858 and parameters: {'learning_rate': 0.02735048673981855, 'depth': 7, 'l2_leaf_reg': 6.668559618421674, 'subsample': 0.793802637486766, 'border_count': 69}. Best is trial 8 with value: 0.912869947463497.
# [I 2026-01-29 22:59:08,610] Trial 21 finished with value: 0.912693767430691 and parameters: {'learning_rate': 0.029990918305515837, 'depth': 8, 'l2_leaf_reg': 8.51903902682308, 'subsample': 0.7204157061758255, 'border_count': 73}. Best is trial 8 with value: 0.912869947463497.
# [I 2026-01-29 23:05:13,235] Trial 22 finished with value: 0.9113078390447904 and parameters: {'learning_rate': 0.02774376428447141, 'depth': 8, 'l2_leaf_reg': 8.567783980905679, 'subsample': 0.728021362431688, 'border_count': 73}. Best is trial 8 with value: 0.912869947463497.
# [I 2026-01-29 23:10:00,843] Trial 23 finished with value: 0.9052550970131689 and parameters: {'learning_rate': 0.02489588399412519, 'depth': 7, 'l2_leaf_reg': 9.886497254618824, 'subsample': 0.686524040880854, 'border_count': 76}. Best is trial 8 with value: 0.912869947463497.
# [I 2026-01-29 23:15:56,735] Trial 24 finished with value: 0.912040515101815 and parameters: {'learning_rate': 0.02794438404102804, 'depth': 8, 'l2_leaf_reg': 7.655997715450284, 'subsample': 0.7893260457921126, 'border_count': 51}. Best is trial 8 with value: 0.912869947463497.
# [I 2026-01-29 23:22:12,029] Trial 25 finished with value: 0.9076637419118345 and parameters: {'learning_rate': 0.0218338960436593, 'depth': 8, 'l2_leaf_reg': 8.805565640845561, 'subsample': 0.7372183248405679, 'border_count': 88}. Best is trial 8 with value: 0.912869947463497.
# [I 2026-01-29 23:27:12,308] Trial 26 finished with value: 0.9079059609154595 and parameters: {'learning_rate': 0.026858033876396775, 'depth': 7, 'l2_leaf_reg': 6.899761282132583, 'subsample': 0.8585287315131395, 'border_count': 68}. Best is trial 8 with value: 0.912869947463497.
# [I 2026-01-29 23:33:30,747] Trial 27 finished with value: 0.9099388749620877 and parameters: {'learning_rate': 0.024602205526521696, 'depth': 8, 'l2_leaf_reg': 5.8180072364516935, 'subsample': 0.8235663472058885, 'border_count': 78}. Best is trial 8 with value: 0.912869947463497.
# [I 2026-01-29 23:35:58,731] Trial 28 finished with value: 0.890481574471757 and parameters: {'learning_rate': 0.028705445193325668, 'depth': 4, 'l2_leaf_reg': 7.866816723014206, 'subsample': 0.7030635462604219, 'border_count': 51}. Best is trial 8 with value: 0.912869947463497.
# [I 2026-01-29 23:40:54,154] Trial 29 finished with value: 0.9061381471101161 and parameters: {'learning_rate': 0.025795490452724477, 'depth': 7, 'l2_leaf_reg': 6.91234297290168, 'subsample': 0.7208977885702337, 'border_count': 99}. Best is trial 8 with value: 0.912869947463497.
# [INFO] Best CatBoost params: {'learning_rate': 0.028844498816839356, 'depth': 8, 'l2_leaf_reg': 8.189349282112437, 'subsample': 0.7574521692209916, 'border_count': 112}
# 0:	test: 0.8495531	best: 0.8495531 (0)	total: 572ms	remaining: 47m 36s
# 100:	test: 0.9064482	best: 0.9064482 (100)	total: 56.6s	remaining: 45m 47s
# 200:	test: 0.9193467	best: 0.9193467 (200)	total: 1m 52s	remaining: 44m 43s
# 300:	test: 0.9273687	best: 0.9273687 (300)	total: 2m 47s	remaining: 43m 41s
# 400:	test: 0.9329173	best: 0.9329173 (400)	total: 3m 42s	remaining: 42m 36s
# 500:	test: 0.9376961	best: 0.9377004 (493)	total: 4m 39s	remaining: 41m 47s
# 600:	test: 0.9408244	best: 0.9409146 (598)	total: 5m 37s	remaining: 41m 9s
# 700:	test: 0.9432549	best: 0.9432549 (700)	total: 6m 33s	remaining: 40m 15s
# 800:	test: 0.9438793	best: 0.9439487 (764)	total: 7m 28s	remaining: 39m 10s
# 900:	test: 0.9444654	best: 0.9445548 (875)	total: 8m 23s	remaining: 38m 9s
# 1000:	test: 0.9448703	best: 0.9448703 (1000)	total: 9m 17s	remaining: 37m 6s
# 1100:	test: 0.9454142	best: 0.9454142 (1100)	total: 10m 12s	remaining: 36m 7s
# 1200:	test: 0.9456573	best: 0.9456824 (1139)	total: 11m 6s	remaining: 35m 6s
# 1300:	test: 0.9458513	best: 0.9458679 (1265)	total: 11m 59s	remaining: 34m 6s
# 1400:	test: 0.9463243	best: 0.9463311 (1392)	total: 12m 54s	remaining: 33m 8s
# 1500:	test: 0.9463489	best: 0.9464231 (1494)	total: 13m 48s	remaining: 32m 10s
# 1600:	test: 0.9466475	best: 0.9467002 (1590)	total: 14m 42s	remaining: 31m 13s
# 1700:	test: 0.9468442	best: 0.9469291 (1671)	total: 15m 36s	remaining: 30m 16s
# 1800:	test: 0.9471083	best: 0.9471225 (1768)	total: 16m 30s	remaining: 29m 18s
# 1900:	test: 0.9471128	best: 0.9471666 (1817)	total: 17m 24s	remaining: 28m 23s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.9471666338
# bestIteration = 1817
#
# Shrink model to first 1818 iterations.

# %%
evaluate_and_log(model_catboost_full,  X_test, y_test, experiment_name=EXPERIMENT_NAME, run_name="CATboost_Optuna_fullfeatures", hp_search_history=hist_df, hp_search_plots= plot_paths)
# Out:
# [INFO] Logged metrics: {'roc_auc': np.float64(0.9133210422376002), 'pr_auc': np.float64(0.5414351761160325), 'precision': 0.2965412004069176, 'recall': 0.7172736220472441, 'f1': 0.4196055851446668, 'custom_loss': np.float64(1.0313865275849223), 'precision_at_100': 0.92, 'recall_at_100': 0.022637795275590553, 'precision_at_118': 0.9152542372881356, 'recall_at_118': 0.0265748031496063, 'precision_at_500': 0.924, 'recall_at_500': 0.11368110236220473, 'precision_at_591': 0.9153976311336718, 'recall_at_591': 0.1331200787401575, 'precision_at_1000': 0.885, 'recall_at_1000': 0.21776574803149606, 'precision_at_1181': 0.8704487722269263, 'recall_at_1181': 0.2529527559055118, 'cost_opt_threshold': 0.10372506362241447, 'cost_opt_custom_loss': 0.5946421918921665, 'cost_opt_precision': 0.08368989292127607, 'cost_opt_recall': 0.9288877952755905, 'cost_opt_f1': 0.15354578918468204}
# [INFO] Logged SHAP summary plot.
# 2026/01/29 23:59:09 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# [INFO] Evaluation complete and logged.
# {'roc_auc': np.float64(0.9133210422376002),
#  'pr_auc': np.float64(0.5414351761160325),
#  'precision': 0.2965412004069176,
#  'recall': 0.7172736220472441,
#  'f1': 0.4196055851446668,
#  'custom_loss': np.float64(1.0313865275849223),
#  'precision_at_100': 0.92,
#  'recall_at_100': 0.022637795275590553,
#  'precision_at_118': 0.9152542372881356,
#  'recall_at_118': 0.0265748031496063,
#  'precision_at_500': 0.924,
#  'recall_at_500': 0.11368110236220473,
#  'precision_at_591': 0.9153976311336718,
#  'recall_at_591': 0.1331200787401575,
#  'precision_at_1000': 0.885,
#  'recall_at_1000': 0.21776574803149606,
#  'precision_at_1181': 0.8704487722269263,
#  'recall_at_1181': 0.2529527559055118,
#  'cost_opt_threshold': 0.10372506362241447,
#  'cost_opt_custom_loss': 0.5946421918921665,
#  'cost_opt_precision': 0.08368989292127607,
#  'cost_opt_recall': 0.9288877952755905,
#  'cost_opt_f1': 0.15354578918468204}

# %% [markdown]
# ## 2. Reduced Features

# %%
# ---- 1. Compute SHAP importance for each model ----
df_xgb = get_top_features_shap(model_xgboost_full, X_train, y_train).rename(
    columns={"importance": "importance_xgb"}
)
df_lgbm = get_top_features_shap(model_lgbm_full, X_train, y_train).rename(
    columns={"importance": "importance_lgbm"}
)
df_cat = get_top_features_shap(model_catboost_full, X_train, y_train).rename(
    columns={"importance": "importance_cat"}
)

# ---- 2. Merge all importance tables ----
df = (
    df_xgb.merge(df_lgbm, on="feature")
          .merge(df_cat, on="feature")
)

# ---- 3. Rank features within each model (1 = most important) ----
df["rank_xgb"] = df["importance_xgb"].rank(method="min", ascending=False)
df["rank_lgbm"] = df["importance_lgbm"].rank(method="min", ascending=False)
df["rank_cat"] = df["importance_cat"].rank(method="min", ascending=False)

# ---- 4. Determine the top 30% threshold ----
n_features = len(df)
top_30_cutoff = int(n_features * 0.30)

# ---- 5. Check if a feature appears in top 30% in each model ----
df["in_top_xgb"]  = df["rank_xgb"]  <= top_30_cutoff
df["in_top_lgbm"] = df["rank_lgbm"] <= top_30_cutoff
df["in_top_cat"]  = df["rank_cat"]  <= top_30_cutoff

# ---- 6. Apply the rule: “Top 30% for at least 2 models” ----
df["top_count"] = (
    df["in_top_xgb"].astype(int)
  + df["in_top_lgbm"].astype(int)
  + df["in_top_cat"].astype(int)
)

df_selected = df[df["top_count"] >= 2]  # final selected features

# %%
# ---- 7. Sort by mean importance (optional but nice) ----
df_selected["importance_mean"] = df_selected[["importance_xgb","importance_lgbm","importance_cat"]].mean(axis=1)
df_selected = df_selected.sort_values("importance_mean", ascending=False)

# ---- 8. Save to CSV ----
df.to_csv(f"{data_folder}/feature_importances_shap_fullmodels.csv", index=False)
df_selected.to_csv(f"{data_folder}/selected_features_shap.csv", index=False)

# ---- 9. List of selected feature names ----
selected_feature_list = df_selected["feature"].tolist()

# %%
del df_xgb, df_lgbm, df_cat, df_selected, df

# %%
X_train_reduced = X_train[selected_feature_list]
X_test_reduced = X_test[selected_feature_list]

# %%
X_train_reduced.shape, X_test_reduced.shape
# Out:
# ((99594, 211), (118108, 211))

# %% [markdown]
# ### 2.1. XGBoost

# %%
model_xgboost_reduced, best_params_xgboost_reduced, hist_df, plot_paths = train_xgb_optuna(X_train_reduced, y_train)
# Out:
# [I 2026-01-30 00:04:24,795] A new study created in memory with name: xgboost_aucpr_optimization
# [Optuna XGBoost Tuning]:   0%|          | 0/30 [00:00<?, ?trial/s]
# [I 2026-01-30 00:04:59,563] Trial 0 finished with value: 0.903197980027033 and parameters: {'learning_rate': 0.02679417360687513, 'max_depth': 5, 'subsample': 0.571793228223724, 'colsample_bytree': 0.5336768517885302, 'min_child_weight': 0.0015932654386896672, 'gamma': 3.966968728168012}. Best is trial 0 with value: 0.903197980027033.
# [I 2026-01-30 00:05:44,677] Trial 1 finished with value: 0.9135461402997592 and parameters: {'learning_rate': 0.028979191792595338, 'max_depth': 7, 'subsample': 0.6143413587951522, 'colsample_bytree': 0.781940084926311, 'min_child_weight': 0.013025850069595115, 'gamma': 2.411261595836509}. Best is trial 1 with value: 0.9135461402997592.
# [I 2026-01-30 00:06:18,189] Trial 2 finished with value: 0.8830152567401489 and parameters: {'learning_rate': 0.01898726283772133, 'max_depth': 3, 'subsample': 0.9042714177331028, 'colsample_bytree': 0.7409985913029409, 'min_child_weight': 0.0018864102583552487, 'gamma': 2.7227465078236923}. Best is trial 1 with value: 0.9135461402997592.
# [I 2026-01-30 00:07:08,710] Trial 3 finished with value: 0.9137474203041632 and parameters: {'learning_rate': 0.01594119370628959, 'max_depth': 7, 'subsample': 0.8730954119615753, 'colsample_bytree': 0.5373259448229448, 'min_child_weight': 0.015837267218606718, 'gamma': 1.2753939294661505}. Best is trial 3 with value: 0.9137474203041632.
# [I 2026-01-30 00:07:49,477] Trial 4 finished with value: 0.9043743614653591 and parameters: {'learning_rate': 0.026721299766888147, 'max_depth': 5, 'subsample': 0.7219326252216786, 'colsample_bytree': 0.8101616378309733, 'min_child_weight': 0.004159231207220084, 'gamma': 3.600319082809054}. Best is trial 3 with value: 0.9137474203041632.
# [I 2026-01-30 00:08:48,831] Trial 5 finished with value: 0.9133618014129333 and parameters: {'learning_rate': 0.01169079338240011, 'max_depth': 8, 'subsample': 0.6537722146402399, 'colsample_bytree': 0.6868096293774488, 'min_child_weight': 0.0017532088419648316, 'gamma': 1.6405757191905375}. Best is trial 3 with value: 0.9137474203041632.
# [I 2026-01-30 00:09:22,248] Trial 6 finished with value: 0.8864054375963649 and parameters: {'learning_rate': 0.0266485663644069, 'max_depth': 3, 'subsample': 0.6589889796769539, 'colsample_bytree': 0.6359433677238278, 'min_child_weight': 0.005358031758113346, 'gamma': 0.2976659748171223}. Best is trial 3 with value: 0.9137474203041632.
# [I 2026-01-30 00:09:56,358] Trial 7 finished with value: 0.8867744712669867 and parameters: {'learning_rate': 0.028412266639038154, 'max_depth': 3, 'subsample': 0.9357426663159303, 'colsample_bytree': 0.9702118398393678, 'min_child_weight': 0.0022694000978474085, 'gamma': 4.448592149634388}. Best is trial 3 with value: 0.9137474203041632.
# [I 2026-01-30 00:10:38,465] Trial 8 finished with value: 0.9070864170057439 and parameters: {'learning_rate': 0.019486303943037915, 'max_depth': 6, 'subsample': 0.6922246078969221, 'colsample_bytree': 0.6703640270952078, 'min_child_weight': 0.02315065722664712, 'gamma': 3.814522060578528}. Best is trial 3 with value: 0.9137474203041632.
# [I 2026-01-30 00:11:12,018] Trial 9 finished with value: 0.8849070354251315 and parameters: {'learning_rate': 0.0237373327350437, 'max_depth': 3, 'subsample': 0.7400352799548223, 'colsample_bytree': 0.7607816257840491, 'min_child_weight': 0.0016611962865600315, 'gamma': 2.751728478093025}. Best is trial 3 with value: 0.9137474203041632.
# [I 2026-01-30 00:12:11,880] Trial 10 finished with value: 0.9079377935273215 and parameters: {'learning_rate': 0.013644387310712524, 'max_depth': 8, 'subsample': 0.8626015001649261, 'colsample_bytree': 0.504044910921478, 'min_child_weight': 0.26312129262918066, 'gamma': 0.10218773059765462}. Best is trial 3 with value: 0.9137474203041632.
# [I 2026-01-30 00:13:07,080] Trial 11 finished with value: 0.9087369382545575 and parameters: {'learning_rate': 0.015318045642522692, 'max_depth': 7, 'subsample': 0.8207075693481137, 'colsample_bytree': 0.9137586696503286, 'min_child_weight': 0.02675808768537685, 'gamma': 1.2854324531002117}. Best is trial 3 with value: 0.9137474203041632.
# [I 2026-01-30 00:13:55,281] Trial 12 finished with value: 0.9068854501587259 and parameters: {'learning_rate': 0.01647708895545194, 'max_depth': 7, 'subsample': 0.5030279803707022, 'colsample_bytree': 0.8679626150653335, 'min_child_weight': 0.09755809674315623, 'gamma': 1.63312459229037}. Best is trial 3 with value: 0.9137474203041632.
# [I 2026-01-30 00:14:39,667] Trial 13 finished with value: 0.9098442768018783 and parameters: {'learning_rate': 0.022418147949964426, 'max_depth': 6, 'subsample': 0.9843829000955351, 'colsample_bytree': 0.5875674108350929, 'min_child_weight': 0.010839976001945863, 'gamma': 1.005904541440972}. Best is trial 3 with value: 0.9137474203041632.
# [I 2026-01-30 00:15:24,821] Trial 14 finished with value: 0.9118818544251686 and parameters: {'learning_rate': 0.02978524211046321, 'max_depth': 7, 'subsample': 0.8102968060959304, 'colsample_bytree': 0.8134269662055351, 'min_child_weight': 0.10065294857667986, 'gamma': 2.226012267635174}. Best is trial 3 with value: 0.9137474203041632.
# [I 2026-01-30 00:16:16,141] Trial 15 finished with value: 0.907970031220121 and parameters: {'learning_rate': 0.010160223372382966, 'max_depth': 7, 'subsample': 0.5939699041986428, 'colsample_bytree': 0.5928219897776386, 'min_child_weight': 0.010750959497688888, 'gamma': 2.2167033033074803}. Best is trial 3 with value: 0.9137474203041632.
# [I 2026-01-30 00:17:02,544] Trial 16 finished with value: 0.9070465072010522 and parameters: {'learning_rate': 0.022156436679484266, 'max_depth': 6, 'subsample': 0.7981538593780438, 'colsample_bytree': 0.7272805664395916, 'min_child_weight': 0.8027151511842304, 'gamma': 0.7982360325998543}. Best is trial 3 with value: 0.9137474203041632.
# [I 2026-01-30 00:17:56,712] Trial 17 finished with value: 0.9122005203629792 and parameters: {'learning_rate': 0.01756933954766335, 'max_depth': 8, 'subsample': 0.5006358935933717, 'colsample_bytree': 0.8092284163850709, 'min_child_weight': 0.05744319004138059, 'gamma': 3.1196845077585276}. Best is trial 3 with value: 0.9137474203041632.
# [I 2026-01-30 00:18:33,760] Trial 18 finished with value: 0.8867184914984709 and parameters: {'learning_rate': 0.013642300627561076, 'max_depth': 4, 'subsample': 0.5995931514573258, 'colsample_bytree': 0.9129520788377724, 'min_child_weight': 0.012513644440650135, 'gamma': 1.8613265863771846}. Best is trial 3 with value: 0.9137474203041632.
# [I 2026-01-30 00:19:18,648] Trial 19 finished with value: 0.9139961555589547 and parameters: {'learning_rate': 0.024223770884525292, 'max_depth': 7, 'subsample': 0.7712696336945395, 'colsample_bytree': 0.5767828494977134, 'min_child_weight': 0.04934285672960692, 'gamma': 4.854284918638168}. Best is trial 19 with value: 0.9139961555589547.
# [I 2026-01-30 00:19:57,878] Trial 20 finished with value: 0.9039874194696425 and parameters: {'learning_rate': 0.024182929542769134, 'max_depth': 5, 'subsample': 0.8772962229471715, 'colsample_bytree': 0.5628370718222562, 'min_child_weight': 0.06433940876922908, 'gamma': 4.943250304759987}. Best is trial 19 with value: 0.9139961555589547.
# [I 2026-01-30 00:20:53,501] Trial 21 finished with value: 0.9142061917215857 and parameters: {'learning_rate': 0.02122098197364515, 'max_depth': 7, 'subsample': 0.7782080891579557, 'colsample_bytree': 0.6402730343401128, 'min_child_weight': 0.017854168848908076, 'gamma': 3.157656522450544}. Best is trial 21 with value: 0.9142061917215857.
# [I 2026-01-30 00:21:49,241] Trial 22 finished with value: 0.9178075377131086 and parameters: {'learning_rate': 0.021440265039614492, 'max_depth': 8, 'subsample': 0.7808420486444444, 'colsample_bytree': 0.6292874531071644, 'min_child_weight': 0.030339317491330238, 'gamma': 3.3258611116601307}. Best is trial 22 with value: 0.9178075377131086.
# [I 2026-01-30 00:22:45,043] Trial 23 finished with value: 0.9120951412549948 and parameters: {'learning_rate': 0.02126614651623678, 'max_depth': 8, 'subsample': 0.7739817909877224, 'colsample_bytree': 0.6328763219115816, 'min_child_weight': 0.19324077529752118, 'gamma': 3.464407075091742}. Best is trial 22 with value: 0.9178075377131086.
# [I 2026-01-30 00:23:37,945] Trial 24 finished with value: 0.9179662105368482 and parameters: {'learning_rate': 0.024798836416265912, 'max_depth': 8, 'subsample': 0.7579928904512228, 'colsample_bytree': 0.6288599875753571, 'min_child_weight': 0.046422108685899625, 'gamma': 4.350708140099186}. Best is trial 24 with value: 0.9179662105368482.
# [I 2026-01-30 00:24:36,612] Trial 25 finished with value: 0.916293754634118 and parameters: {'learning_rate': 0.020517631282127854, 'max_depth': 8, 'subsample': 0.7111529346724762, 'colsample_bytree': 0.6879239307252158, 'min_child_weight': 0.03738411745122954, 'gamma': 4.158014872355741}. Best is trial 24 with value: 0.9179662105368482.
# [I 2026-01-30 00:25:29,339] Trial 26 finished with value: 0.9114913391826258 and parameters: {'learning_rate': 0.025305734616192038, 'max_depth': 8, 'subsample': 0.6924818168351895, 'colsample_bytree': 0.6997877326061801, 'min_child_weight': 0.1837925095646625, 'gamma': 4.20347979075181}. Best is trial 24 with value: 0.9179662105368482.
# [I 2026-01-30 00:26:25,382] Trial 27 finished with value: 0.9179042390074185 and parameters: {'learning_rate': 0.018212245661945316, 'max_depth': 8, 'subsample': 0.8317973231775615, 'colsample_bytree': 0.6200095340387322, 'min_child_weight': 0.03395936209593115, 'gamma': 4.466994060832265}. Best is trial 24 with value: 0.9179662105368482.
# [I 2026-01-30 00:27:20,151] Trial 28 finished with value: 0.9155796996524911 and parameters: {'learning_rate': 0.01840946558122996, 'max_depth': 8, 'subsample': 0.8412671664872566, 'colsample_bytree': 0.6280763158624664, 'min_child_weight': 0.10014169991879879, 'gamma': 4.517016015485076}. Best is trial 24 with value: 0.9179662105368482.
# [I 2026-01-30 00:28:06,049] Trial 29 finished with value: 0.9106404955666428 and parameters: {'learning_rate': 0.023176311443468055, 'max_depth': 6, 'subsample': 0.9253210660011748, 'colsample_bytree': 0.5404364373526075, 'min_child_weight': 0.005789544366380013, 'gamma': 3.858265888940166}. Best is trial 24 with value: 0.9179662105368482.
# [INFO] Best XGBoost params: {'learning_rate': 0.024798836416265912, 'max_depth': 8, 'subsample': 0.7579928904512228, 'colsample_bytree': 0.6288599875753571, 'min_child_weight': 0.046422108685899625, 'gamma': 4.350708140099186}
# [0]	validation_0-auc:0.82267
# [100]	validation_0-auc:0.92222
# [200]	validation_0-auc:0.93274
# [300]	validation_0-auc:0.93669
# [400]	validation_0-auc:0.93915
# [500]	validation_0-auc:0.94008
# [600]	validation_0-auc:0.94000
# [641]	validation_0-auc:0.94007

# %%
evaluate_and_log(model_xgboost_reduced, X_test_reduced, y_test, experiment_name=EXPERIMENT_NAME, run_name="XGBoost_Optuna_Reduced", hp_search_history=hist_df, hp_search_plots= plot_paths)
evaluate_and_log(model_xgboost_reduced, X_test_reduced, y_test, experiment_name=EXPERIMENT_NAME, run_name="XGBoost_Optuna_Reduced", hp_search_history=hist_df, hp_search_plots= plot_paths, prediction_threshold=0.10)
evaluate_and_log(model_xgboost_reduced, X_test_reduced, y_test, experiment_name=EXPERIMENT_NAME, run_name="XGBoost_Optuna_Reduced", hp_search_history=hist_df, hp_search_plots= plot_paths, prediction_threshold=0.02)
# Out:
# [INFO] Logged metrics: {'roc_auc': np.float64(0.9054796884584124), 'pr_auc': np.float64(0.5068867185854767), 'precision': 0.27855948046836565, 'recall': 0.6966043307086615, 'f1': 0.3979756800449849, 'custom_loss': np.float64(1.1060385409963762), 'precision_at_100': 0.98, 'recall_at_100': 0.024114173228346455, 'precision_at_118': 0.9745762711864406, 'recall_at_118': 0.028297244094488187, 'precision_at_500': 0.924, 'recall_at_500': 0.11368110236220473, 'precision_at_591': 0.9035532994923858, 'recall_at_591': 0.13139763779527558, 'precision_at_1000': 0.873, 'recall_at_1000': 0.21481299212598426, 'precision_at_1181': 0.8458933107535986, 'recall_at_1181': 0.24581692913385828, 'cost_opt_threshold': 0.12278212970075895, 'cost_opt_custom_loss': 0.600941511159278, 'cost_opt_precision': 0.08655310898767483, 'cost_opt_recall': 0.922736220472441, 'cost_opt_f1': 0.1582612365477949}
# [INFO] Logged SHAP summary plot.
# 2026/01/30 00:29:03 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# [INFO] Evaluation complete and logged.
# [INFO] Logged metrics: {'roc_auc': np.float64(0.9054796884584124), 'pr_auc': np.float64(0.5068867185854767), 'precision': 0.07552623186094722, 'recall': 0.9323326771653543, 'f1': 0.13973299896739932, 'custom_loss': np.float64(0.6255207098587733), 'precision_at_100': 0.98, 'recall_at_100': 0.024114173228346455, 'precision_at_118': 0.9745762711864406, 'recall_at_118': 0.028297244094488187, 'precision_at_500': 0.924, 'recall_at_500': 0.11368110236220473, 'precision_at_591': 0.9035532994923858, 'recall_at_591': 0.13139763779527558, 'precision_at_1000': 0.873, 'recall_at_1000': 0.21481299212598426, 'precision_at_1181': 0.8458933107535986, 'recall_at_1181': 0.24581692913385828, 'cost_opt_threshold': 0.12278212970075895, 'cost_opt_custom_loss': 0.600941511159278, 'cost_opt_precision': 0.08655310898767483, 'cost_opt_recall': 0.922736220472441, 'cost_opt_f1': 0.1582612365477949}
# [INFO] Logged SHAP summary plot.
# 2026/01/30 00:29:27 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# [INFO] Evaluation complete and logged.
# [INFO] Logged metrics: {'roc_auc': np.float64(0.9054796884584124), 'pr_auc': np.float64(0.5068867185854767), 'precision': 0.038601153509152004, 'recall': 0.9864665354330708, 'f1': 0.07429508622047609, 'custom_loss': np.float64(0.8919632878382497), 'precision_at_100': 0.98, 'recall_at_100': 0.024114173228346455, 'precision_at_118': 0.9745762711864406, 'recall_at_118': 0.028297244094488187, 'precision_at_500': 0.924, 'recall_at_500': 0.11368110236220473, 'precision_at_591': 0.9035532994923858, 'recall_at_591': 0.13139763779527558, 'precision_at_1000': 0.873, 'recall_at_1000': 0.21481299212598426, 'precision_at_1181': 0.8458933107535986, 'recall_at_1181': 0.24581692913385828, 'cost_opt_threshold': 0.12278212970075895, 'cost_opt_custom_loss': 0.600941511159278, 'cost_opt_precision': 0.08655310898767483, 'cost_opt_recall': 0.922736220472441, 'cost_opt_f1': 0.1582612365477949}
# [INFO] Logged SHAP summary plot.
# 2026/01/30 00:29:51 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# [INFO] Evaluation complete and logged.
# {'roc_auc': np.float64(0.9054796884584124),
#  'pr_auc': np.float64(0.5068867185854767),
#  'precision': 0.038601153509152004,
#  'recall': 0.9864665354330708,
#  'f1': 0.07429508622047609,
#  'custom_loss': np.float64(0.8919632878382497),
#  'precision_at_100': 0.98,
#  'recall_at_100': 0.024114173228346455,
#  'precision_at_118': 0.9745762711864406,
#  'recall_at_118': 0.028297244094488187,
#  'precision_at_500': 0.924,
#  'recall_at_500': 0.11368110236220473,
#  'precision_at_591': 0.9035532994923858,
#  'recall_at_591': 0.13139763779527558,
#  'precision_at_1000': 0.873,
#  'recall_at_1000': 0.21481299212598426,
#  'precision_at_1181': 0.8458933107535986,
#  'recall_at_1181': 0.24581692913385828,
#  'cost_opt_threshold': 0.12278212970075895,
#  'cost_opt_custom_loss': 0.600941511159278,
#  'cost_opt_precision': 0.08655310898767483,
#  'cost_opt_recall': 0.922736220472441,
#  'cost_opt_f1': 0.1582612365477949}

# %% [markdown]
# ### 2.2. LightGBM

# %%
model_lgmb_reduced, best_params_lgmb_reduced, hist_df, plot_paths = train_lgbm_optuna(X_train_reduced, y_train)
# Out:
# [I 2026-01-30 00:30:02,017] A new study created in memory with name: lgbm_aucpr_optimization
# [Optuna LightGBM Tuning]:   0%|          | 0/30 [00:00<?, ?trial/s]
# [I 2026-01-30 00:30:41,168] Trial 0 finished with value: 0.9287681441170804 and parameters: {'num_leaves': 354, 'max_depth': 12, 'learning_rate': 0.026348431403883966, 'min_child_samples': 45, 'reg_alpha': 0.46200626864651917, 'reg_lambda': 0.47466606411375284, 'colsample_bytree': 0.9467318458904157, 'subsample': 0.8640785804974399}. Best is trial 0 with value: 0.9287681441170804.
# [I 2026-01-30 00:31:14,954] Trial 1 finished with value: 0.927537743214362 and parameters: {'num_leaves': 232, 'max_depth': 12, 'learning_rate': 0.02277609045631688, 'min_child_samples': 57, 'reg_alpha': 0.4999589719214802, 'reg_lambda': 0.049950312961696886, 'colsample_bytree': 0.9798018551059209, 'subsample': 0.881748724889297}. Best is trial 0 with value: 0.9287681441170804.
# [I 2026-01-30 00:32:02,901] Trial 2 finished with value: 0.9288849201395548 and parameters: {'num_leaves': 413, 'max_depth': 18, 'learning_rate': 0.024447602284953344, 'min_child_samples': 17, 'reg_alpha': 0.38762046649600024, 'reg_lambda': 0.31560434160581197, 'colsample_bytree': 0.8049619365019175, 'subsample': 0.8976428338453324}. Best is trial 2 with value: 0.9288849201395548.
# [I 2026-01-30 00:33:05,152] Trial 3 finished with value: 0.9321630001773681 and parameters: {'num_leaves': 382, 'max_depth': 16, 'learning_rate': 0.01352152945462776, 'min_child_samples': 58, 'reg_alpha': 0.48112537347752804, 'reg_lambda': 0.2528174305471319, 'colsample_bytree': 0.8264488204680289, 'subsample': 0.9573098238834037}. Best is trial 3 with value: 0.9321630001773681.
# [I 2026-01-30 00:33:50,386] Trial 4 finished with value: 0.9234410857883741 and parameters: {'num_leaves': 365, 'max_depth': 14, 'learning_rate': 0.023258996119739667, 'min_child_samples': 17, 'reg_alpha': 0.2929397616129192, 'reg_lambda': 0.46304233854558585, 'colsample_bytree': 0.9938746558590825, 'subsample': 0.8603016820750718}. Best is trial 3 with value: 0.9321630001773681.
# [I 2026-01-30 00:34:59,114] Trial 5 finished with value: 0.9321221215395036 and parameters: {'num_leaves': 446, 'max_depth': 17, 'learning_rate': 0.013906486566357427, 'min_child_samples': 62, 'reg_alpha': 0.49693650185902116, 'reg_lambda': 0.11684465423646317, 'colsample_bytree': 0.9183924723422427, 'subsample': 0.986314600700983}. Best is trial 3 with value: 0.9321630001773681.
# [I 2026-01-30 00:35:36,471] Trial 6 finished with value: 0.9285767122517427 and parameters: {'num_leaves': 250, 'max_depth': 11, 'learning_rate': 0.017304742697670152, 'min_child_samples': 81, 'reg_alpha': 0.07210753345400972, 'reg_lambda': 0.3352850752638081, 'colsample_bytree': 0.8690064724097933, 'subsample': 0.9291589079052957}. Best is trial 3 with value: 0.9321630001773681.
# [I 2026-01-30 00:36:20,599] Trial 7 finished with value: 0.9314690176596413 and parameters: {'num_leaves': 425, 'max_depth': 14, 'learning_rate': 0.015427415599727485, 'min_child_samples': 72, 'reg_alpha': 0.45974246198064295, 'reg_lambda': 0.371441707470806, 'colsample_bytree': 0.8513978703557017, 'subsample': 0.8335533240731765}. Best is trial 3 with value: 0.9321630001773681.
# [I 2026-01-30 00:37:08,023] Trial 8 finished with value: 0.9315283253862997 and parameters: {'num_leaves': 212, 'max_depth': 15, 'learning_rate': 0.014684460934593907, 'min_child_samples': 62, 'reg_alpha': 0.40106612804696845, 'reg_lambda': 0.24076167777013324, 'colsample_bytree': 0.8034925518124755, 'subsample': 0.996439945498236}. Best is trial 3 with value: 0.9321630001773681.
# [I 2026-01-30 00:37:51,956] Trial 9 finished with value: 0.9273268922412307 and parameters: {'num_leaves': 407, 'max_depth': 12, 'learning_rate': 0.017865566404214786, 'min_child_samples': 43, 'reg_alpha': 0.38855752352835016, 'reg_lambda': 0.37972042584528365, 'colsample_bytree': 0.9625108506956412, 'subsample': 0.8230510099584118}. Best is trial 3 with value: 0.9321630001773681.
# [I 2026-01-30 00:38:58,812] Trial 10 finished with value: 0.9318643718152919 and parameters: {'num_leaves': 512, 'max_depth': 20, 'learning_rate': 0.010604193064717226, 'min_child_samples': 97, 'reg_alpha': 0.09851828280295577, 'reg_lambda': 0.1891345890440671, 'colsample_bytree': 0.8518740647631218, 'subsample': 0.9446579474211213}. Best is trial 3 with value: 0.9321630001773681.
# [I 2026-01-30 00:40:26,170] Trial 11 finished with value: 0.9305423467729828 and parameters: {'num_leaves': 509, 'max_depth': 17, 'learning_rate': 0.010136204853293633, 'min_child_samples': 41, 'reg_alpha': 0.24452153025265244, 'reg_lambda': 0.10338617416291482, 'colsample_bytree': 0.9138502182723555, 'subsample': 0.9981751591192468}. Best is trial 3 with value: 0.9321630001773681.
# [I 2026-01-30 00:41:24,862] Trial 12 finished with value: 0.9320777416874018 and parameters: {'num_leaves': 299, 'max_depth': 17, 'learning_rate': 0.013559466999930884, 'min_child_samples': 79, 'reg_alpha': 0.29137762974096926, 'reg_lambda': 0.15394332062715355, 'colsample_bytree': 0.9091876650950814, 'subsample': 0.959784975384541}. Best is trial 3 with value: 0.9321630001773681.
# [I 2026-01-30 00:42:08,345] Trial 13 finished with value: 0.9317759314100336 and parameters: {'num_leaves': 144, 'max_depth': 19, 'learning_rate': 0.019844747694127883, 'min_child_samples': 63, 'reg_alpha': 0.17661128437082457, 'reg_lambda': 0.006081207137600506, 'colsample_bytree': 0.8882643425212772, 'subsample': 0.9687707390010214}. Best is trial 3 with value: 0.9321630001773681.
# [I 2026-01-30 00:42:51,254] Trial 14 finished with value: 0.9289262319578597 and parameters: {'num_leaves': 457, 'max_depth': 16, 'learning_rate': 0.029295291000763925, 'min_child_samples': 34, 'reg_alpha': 0.3408236593580093, 'reg_lambda': 0.24309374369477849, 'colsample_bytree': 0.9326152848430377, 'subsample': 0.9217549964259091}. Best is trial 3 with value: 0.9321630001773681.
# [I 2026-01-30 00:43:45,754] Trial 15 finished with value: 0.931351382753754 and parameters: {'num_leaves': 319, 'max_depth': 16, 'learning_rate': 0.01278020504497078, 'min_child_samples': 94, 'reg_alpha': 0.4877033055707693, 'reg_lambda': 0.1457047054020013, 'colsample_bytree': 0.8350914077767002, 'subsample': 0.9716802944161715}. Best is trial 3 with value: 0.9321630001773681.
# [I 2026-01-30 00:45:01,250] Trial 16 finished with value: 0.9307188261465879 and parameters: {'num_leaves': 464, 'max_depth': 18, 'learning_rate': 0.01718353362493061, 'min_child_samples': 28, 'reg_alpha': 0.41184753753734216, 'reg_lambda': 0.07909563783761239, 'colsample_bytree': 0.8862250471535874, 'subsample': 0.9762190662639119}. Best is trial 3 with value: 0.9321630001773681.
# [I 2026-01-30 00:46:08,237] Trial 17 finished with value: 0.9293493502525672 and parameters: {'num_leaves': 378, 'max_depth': 14, 'learning_rate': 0.012469560374150361, 'min_child_samples': 53, 'reg_alpha': 0.2205153350716061, 'reg_lambda': 0.1940272102757558, 'colsample_bytree': 0.9362534665431386, 'subsample': 0.9242123378934601}. Best is trial 3 with value: 0.9321630001773681.
# [I 2026-01-30 00:47:02,510] Trial 18 finished with value: 0.9324486799466686 and parameters: {'num_leaves': 281, 'max_depth': 20, 'learning_rate': 0.02002267673648733, 'min_child_samples': 72, 'reg_alpha': 0.014877156392321123, 'reg_lambda': 0.2779387783542014, 'colsample_bytree': 0.8301550747906428, 'subsample': 0.8010620204832104}. Best is trial 18 with value: 0.9324486799466686.
# [I 2026-01-30 00:47:59,322] Trial 19 finished with value: 0.9330880448449806 and parameters: {'num_leaves': 275, 'max_depth': 20, 'learning_rate': 0.020564052986372733, 'min_child_samples': 85, 'reg_alpha': 0.027605335645877704, 'reg_lambda': 0.31582525137915296, 'colsample_bytree': 0.8245432831804018, 'subsample': 0.8033600811738678}. Best is trial 19 with value: 0.9330880448449806.
# [I 2026-01-30 00:48:51,833] Trial 20 finished with value: 0.9321174513288127 and parameters: {'num_leaves': 274, 'max_depth': 20, 'learning_rate': 0.020232182864486154, 'min_child_samples': 88, 'reg_alpha': 0.017483363981431688, 'reg_lambda': 0.4149582337008998, 'colsample_bytree': 0.8299498774671897, 'subsample': 0.8020646096154984}. Best is trial 19 with value: 0.9330880448449806.
# [I 2026-01-30 00:49:38,547] Trial 21 finished with value: 0.9326186485977216 and parameters: {'num_leaves': 178, 'max_depth': 19, 'learning_rate': 0.02029046059799639, 'min_child_samples': 75, 'reg_alpha': 0.01481742079036422, 'reg_lambda': 0.28707243927875925, 'colsample_bytree': 0.8214851430331137, 'subsample': 0.8037121758458143}. Best is trial 19 with value: 0.9330880448449806.
# [I 2026-01-30 00:50:24,943] Trial 22 finished with value: 0.932030285604427 and parameters: {'num_leaves': 150, 'max_depth': 19, 'learning_rate': 0.020594107491555644, 'min_child_samples': 73, 'reg_alpha': 0.008569651348532995, 'reg_lambda': 0.3032076556630311, 'colsample_bytree': 0.8150874438238834, 'subsample': 0.8059251641136644}. Best is trial 19 with value: 0.9330880448449806.
# [I 2026-01-30 00:51:13,630] Trial 23 finished with value: 0.9321536916983186 and parameters: {'num_leaves': 177, 'max_depth': 20, 'learning_rate': 0.021848959975728926, 'min_child_samples': 87, 'reg_alpha': 0.08491234737308381, 'reg_lambda': 0.2753560894205813, 'colsample_bytree': 0.8529614058684977, 'subsample': 0.8294810889690488}. Best is trial 19 with value: 0.9330880448449806.
# [I 2026-01-30 00:52:04,835] Trial 24 finished with value: 0.933520346764707 and parameters: {'num_leaves': 192, 'max_depth': 19, 'learning_rate': 0.018448459954135115, 'min_child_samples': 70, 'reg_alpha': 0.1426637631250489, 'reg_lambda': 0.3566705114234337, 'colsample_bytree': 0.8691021336357226, 'subsample': 0.8494047462159126}. Best is trial 24 with value: 0.933520346764707.
# [I 2026-01-30 00:52:54,696] Trial 25 finished with value: 0.9320362348898515 and parameters: {'num_leaves': 192, 'max_depth': 19, 'learning_rate': 0.018102925333030498, 'min_child_samples': 82, 'reg_alpha': 0.14354584219916644, 'reg_lambda': 0.4166432652427416, 'colsample_bytree': 0.8718893619759063, 'subsample': 0.8464354144103721}. Best is trial 24 with value: 0.933520346764707.
# [I 2026-01-30 00:53:37,121] Trial 26 finished with value: 0.9307565491604347 and parameters: {'num_leaves': 174, 'max_depth': 18, 'learning_rate': 0.025554436795699076, 'min_child_samples': 100, 'reg_alpha': 0.13313448740479325, 'reg_lambda': 0.35376299667016387, 'colsample_bytree': 0.8683799544147149, 'subsample': 0.81670063097776}. Best is trial 24 with value: 0.933520346764707.
# [I 2026-01-30 00:54:34,499] Trial 27 finished with value: 0.9327846311306635 and parameters: {'num_leaves': 240, 'max_depth': 19, 'learning_rate': 0.015898192041606644, 'min_child_samples': 69, 'reg_alpha': 0.04372717744092511, 'reg_lambda': 0.41445276689170296, 'colsample_bytree': 0.8435818701323606, 'subsample': 0.8508557899429972}. Best is trial 24 with value: 0.933520346764707.
# [I 2026-01-30 00:55:27,343] Trial 28 finished with value: 0.9314317147444097 and parameters: {'num_leaves': 246, 'max_depth': 18, 'learning_rate': 0.015946329441370526, 'min_child_samples': 67, 'reg_alpha': 0.05602019493631949, 'reg_lambda': 0.41876148746426844, 'colsample_bytree': 0.8458954093246843, 'subsample': 0.8451879371743598}. Best is trial 24 with value: 0.933520346764707.
# [I 2026-01-30 00:56:01,567] Trial 29 finished with value: 0.926653572707495 and parameters: {'num_leaves': 339, 'max_depth': 10, 'learning_rate': 0.019014231745181086, 'min_child_samples': 50, 'reg_alpha': 0.12739963635153007, 'reg_lambda': 0.49562036123033787, 'colsample_bytree': 0.8848157334618993, 'subsample': 0.8737311191634143}. Best is trial 24 with value: 0.933520346764707.
# [INFO] Best LightGBM params: {'num_leaves': 192, 'max_depth': 19, 'learning_rate': 0.018448459954135115, 'min_child_samples': 70, 'reg_alpha': 0.1426637631250489, 'reg_lambda': 0.3566705114234337, 'colsample_bytree': 0.8691021336357226, 'subsample': 0.8494047462159126}
# [50]	valid_0's auc: 0.932599	valid_0's binary_logloss: 0.310863
# [100]	valid_0's auc: 0.940993	valid_0's binary_logloss: 0.274041
# [150]	valid_0's auc: 0.944543	valid_0's binary_logloss: 0.253212
# [200]	valid_0's auc: 0.945688	valid_0's binary_logloss: 0.240188
# [250]	valid_0's auc: 0.946677	valid_0's binary_logloss: 0.229651
# [300]	valid_0's auc: 0.946779	valid_0's binary_logloss: 0.222634
# [350]	valid_0's auc: 0.947406	valid_0's binary_logloss: 0.216103
# [400]	valid_0's auc: 0.94797	valid_0's binary_logloss: 0.210011
# [450]	valid_0's auc: 0.947816	valid_0's binary_logloss: 0.205382

# %%
evaluate_and_log(model_lgmb_reduced, X_test_reduced, y_test, experiment_name=EXPERIMENT_NAME, run_name="LGBM_Optuna_Reduced", hp_search_history=hist_df, hp_search_plots= plot_paths)
evaluate_and_log(model_lgmb_reduced, X_test_reduced, y_test, experiment_name=EXPERIMENT_NAME, run_name="LGBM_Optuna_Reduced", hp_search_history=hist_df, hp_search_plots= plot_paths, prediction_threshold=0.1)
evaluate_and_log(model_lgmb_reduced, X_test_reduced, y_test, experiment_name=EXPERIMENT_NAME, run_name="LGBM_Optuna_Reduced", hp_search_history=hist_df, hp_search_plots= plot_paths, prediction_threshold=0.02)
# Out:
# [INFO] Logged metrics: {'roc_auc': np.float64(0.9163743472957115), 'pr_auc': np.float64(0.5634278329913448), 'precision': 0.30054238009146017, 'recall': 0.6953740157480315, 'f1': 0.4196925818667855, 'custom_loss': np.float64(1.1038795001185355), 'precision_at_100': 0.94, 'recall_at_100': 0.02312992125984252, 'precision_at_118': 0.9491525423728814, 'recall_at_118': 0.027559055118110236, 'precision_at_500': 0.95, 'recall_at_500': 0.11687992125984252, 'precision_at_591': 0.9441624365482234, 'recall_at_591': 0.13730314960629922, 'precision_at_1000': 0.896, 'recall_at_1000': 0.2204724409448819, 'precision_at_1181': 0.8873835732430144, 'recall_at_1181': 0.2578740157480315, 'cost_opt_threshold': 0.08998857374510306, 'cost_opt_custom_loss': 0.5838385206759915, 'cost_opt_precision': 0.08701472556894244, 'cost_opt_recall': 0.9276574803149606, 'cost_opt_f1': 0.1591052964760498}
# [INFO] Logged SHAP summary plot.
# 2026/01/30 00:57:01 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# [INFO] Evaluation complete and logged.
# [INFO] Logged metrics: {'roc_auc': np.float64(0.9163743472957115), 'pr_auc': np.float64(0.5634278329913448), 'precision': 0.09194639124554285, 'recall': 0.9200295275590551, 'f1': 0.16718460059469248, 'custom_loss': np.float64(0.5878179293527958), 'precision_at_100': 0.94, 'recall_at_100': 0.02312992125984252, 'precision_at_118': 0.9491525423728814, 'recall_at_118': 0.027559055118110236, 'precision_at_500': 0.95, 'recall_at_500': 0.11687992125984252, 'precision_at_591': 0.9441624365482234, 'recall_at_591': 0.13730314960629922, 'precision_at_1000': 0.896, 'recall_at_1000': 0.2204724409448819, 'precision_at_1181': 0.8873835732430144, 'recall_at_1181': 0.2578740157480315, 'cost_opt_threshold': 0.08998857374510306, 'cost_opt_custom_loss': 0.5838385206759915, 'cost_opt_precision': 0.08701472556894244, 'cost_opt_recall': 0.9276574803149606, 'cost_opt_f1': 0.1591052964760498}
# [INFO] Logged SHAP summary plot.
# 2026/01/30 00:57:36 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# [INFO] Evaluation complete and logged.
# [INFO] Logged metrics: {'roc_auc': np.float64(0.9163743472957115), 'pr_auc': np.float64(0.5634278329913448), 'precision': 0.045195068400608, 'recall': 0.9876968503937008, 'f1': 0.08643503913694162, 'custom_loss': np.float64(0.7603295289057472), 'precision_at_100': 0.94, 'recall_at_100': 0.02312992125984252, 'precision_at_118': 0.9491525423728814, 'recall_at_118': 0.027559055118110236, 'precision_at_500': 0.95, 'recall_at_500': 0.11687992125984252, 'precision_at_591': 0.9441624365482234, 'recall_at_591': 0.13730314960629922, 'precision_at_1000': 0.896, 'recall_at_1000': 0.2204724409448819, 'precision_at_1181': 0.8873835732430144, 'recall_at_1181': 0.2578740157480315, 'cost_opt_threshold': 0.08998857374510306, 'cost_opt_custom_loss': 0.5838385206759915, 'cost_opt_precision': 0.08701472556894244, 'cost_opt_recall': 0.9276574803149606, 'cost_opt_f1': 0.1591052964760498}
# [INFO] Logged SHAP summary plot.
# 2026/01/30 00:58:10 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# [INFO] Evaluation complete and logged.
# {'roc_auc': np.float64(0.9163743472957115),
#  'pr_auc': np.float64(0.5634278329913448),
#  'precision': 0.045195068400608,
#  'recall': 0.9876968503937008,
#  'f1': 0.08643503913694162,
#  'custom_loss': np.float64(0.7603295289057472),
#  'precision_at_100': 0.94,
#  'recall_at_100': 0.02312992125984252,
#  'precision_at_118': 0.9491525423728814,
#  'recall_at_118': 0.027559055118110236,
#  'precision_at_500': 0.95,
#  'recall_at_500': 0.11687992125984252,
#  'precision_at_591': 0.9441624365482234,
#  'recall_at_591': 0.13730314960629922,
#  'precision_at_1000': 0.896,
#  'recall_at_1000': 0.2204724409448819,
#  'precision_at_1181': 0.8873835732430144,
#  'recall_at_1181': 0.2578740157480315,
#  'cost_opt_threshold': 0.08998857374510306,
#  'cost_opt_custom_loss': 0.5838385206759915,
#  'cost_opt_precision': 0.08701472556894244,
#  'cost_opt_recall': 0.9276574803149606,
#  'cost_opt_f1': 0.1591052964760498}

# %% [markdown]
# ### 2.3. CatBoost

# %%
model_catoost_reduced, best_params_catoost_reduced, hist_df, plot_paths = train_catboost_optuna(X_train_reduced, y_train)
# Out:
# [I 2026-01-30 00:58:21,216] A new study created in memory with name: catboost_aucpr_optimization
# [Optuna CatBoost Tuning]:   0%|          | 0/30 [00:00<?, ?trial/s]
# [I 2026-01-30 01:00:09,218] Trial 0 finished with value: 0.8899758086869468 and parameters: {'learning_rate': 0.017543424864491584, 'depth': 5, 'l2_leaf_reg': 7.387533943932709, 'subsample': 0.6902736790999662, 'border_count': 54}. Best is trial 0 with value: 0.8899758086869468.
# [I 2026-01-30 01:03:32,041] Trial 1 finished with value: 0.906652720982594 and parameters: {'learning_rate': 0.016714959221088278, 'depth': 8, 'l2_leaf_reg': 9.64187361447379, 'subsample': 0.6031275433531864, 'border_count': 116}. Best is trial 1 with value: 0.906652720982594.
# [I 2026-01-30 01:06:23,075] Trial 2 finished with value: 0.9104955732104457 and parameters: {'learning_rate': 0.02577127872261281, 'depth': 7, 'l2_leaf_reg': 9.253815411110269, 'subsample': 0.9165183783266165, 'border_count': 114}. Best is trial 2 with value: 0.9104955732104457.
# [I 2026-01-30 01:07:39,856] Trial 3 finished with value: 0.8808381590268443 and parameters: {'learning_rate': 0.024465890295065768, 'depth': 3, 'l2_leaf_reg': 9.494366244019792, 'subsample': 0.9849159493647481, 'border_count': 104}. Best is trial 2 with value: 0.9104955732104457.
# [I 2026-01-30 01:09:53,055] Trial 4 finished with value: 0.9021323496985652 and parameters: {'learning_rate': 0.02413195591110303, 'depth': 6, 'l2_leaf_reg': 1.4793165991973012, 'subsample': 0.6978876929684659, 'border_count': 56}. Best is trial 2 with value: 0.9104955732104457.
# [I 2026-01-30 01:11:25,570] Trial 5 finished with value: 0.891493163558443 and parameters: {'learning_rate': 0.028496876835066375, 'depth': 4, 'l2_leaf_reg': 7.740757290009801, 'subsample': 0.7420420083701239, 'border_count': 46}. Best is trial 2 with value: 0.9104955732104457.
# [I 2026-01-30 01:13:46,547] Trial 6 finished with value: 0.8978989965132973 and parameters: {'learning_rate': 0.01835746168443384, 'depth': 6, 'l2_leaf_reg': 9.474545400258226, 'subsample': 0.8710283945659522, 'border_count': 90}. Best is trial 2 with value: 0.9104955732104457.
# [I 2026-01-30 01:16:35,187] Trial 7 finished with value: 0.9062215985390024 and parameters: {'learning_rate': 0.01969774765001581, 'depth': 7, 'l2_leaf_reg': 2.9832124574120105, 'subsample': 0.8609212754291347, 'border_count': 104}. Best is trial 2 with value: 0.9104955732104457.
# [I 2026-01-30 01:18:54,749] Trial 8 finished with value: 0.9040585191102463 and parameters: {'learning_rate': 0.025392419079649176, 'depth': 6, 'l2_leaf_reg': 7.190159119309771, 'subsample': 0.8946363326040667, 'border_count': 62}. Best is trial 2 with value: 0.9104955732104457.
# [I 2026-01-30 01:21:46,593] Trial 9 finished with value: 0.9078683427350422 and parameters: {'learning_rate': 0.020965698401216287, 'depth': 7, 'l2_leaf_reg': 1.3304974042894995, 'subsample': 0.9495269998494333, 'border_count': 109}. Best is trial 2 with value: 0.9104955732104457.
# [I 2026-01-30 01:25:09,481] Trial 10 finished with value: 0.8993090432228836 and parameters: {'learning_rate': 0.010379908934949424, 'depth': 8, 'l2_leaf_reg': 4.971888543203424, 'subsample': 0.7979133328558351, 'border_count': 80}. Best is trial 2 with value: 0.9104955732104457.
# [I 2026-01-30 01:28:06,304] Trial 11 finished with value: 0.9129642976523513 and parameters: {'learning_rate': 0.029614801547280967, 'depth': 7, 'l2_leaf_reg': 4.623657408389489, 'subsample': 0.9996869101181575, 'border_count': 127}. Best is trial 11 with value: 0.9129642976523513.
# [I 2026-01-30 01:31:03,938] Trial 12 finished with value: 0.912579624319824 and parameters: {'learning_rate': 0.02971714007245346, 'depth': 7, 'l2_leaf_reg': 4.748086039469564, 'subsample': 0.992051782379201, 'border_count': 128}. Best is trial 11 with value: 0.9129642976523513.
# [I 2026-01-30 01:34:43,417] Trial 13 finished with value: 0.9180073363822207 and parameters: {'learning_rate': 0.02978614542174841, 'depth': 8, 'l2_leaf_reg': 4.6935487839152055, 'subsample': 0.9957801021036417, 'border_count': 128}. Best is trial 13 with value: 0.9180073363822207.
# [I 2026-01-30 01:38:22,251] Trial 14 finished with value: 0.9179925935498036 and parameters: {'learning_rate': 0.027592404906876897, 'depth': 8, 'l2_leaf_reg': 3.510251662576306, 'subsample': 0.9977072305168887, 'border_count': 126}. Best is trial 13 with value: 0.9180073363822207.
# [I 2026-01-30 01:41:45,243] Trial 15 finished with value: 0.9162276237900001 and parameters: {'learning_rate': 0.02707528886062734, 'depth': 8, 'l2_leaf_reg': 3.3255078964883786, 'subsample': 0.824091865618742, 'border_count': 87}. Best is trial 13 with value: 0.9180073363822207.
# [I 2026-01-30 01:45:12,776] Trial 16 finished with value: 0.9130276386831229 and parameters: {'learning_rate': 0.022102181013349285, 'depth': 8, 'l2_leaf_reg': 3.074961833385615, 'subsample': 0.9378514532905439, 'border_count': 75}. Best is trial 13 with value: 0.9180073363822207.
# [I 2026-01-30 01:47:15,575] Trial 17 finished with value: 0.8877166140567837 and parameters: {'learning_rate': 0.014434086144219458, 'depth': 5, 'l2_leaf_reg': 6.112753045759605, 'subsample': 0.9504851842280524, 'border_count': 120}. Best is trial 13 with value: 0.9180073363822207.
# [I 2026-01-30 01:50:39,902] Trial 18 finished with value: 0.9162933509763121 and parameters: {'learning_rate': 0.027051215701686695, 'depth': 8, 'l2_leaf_reg': 3.8285694048805397, 'subsample': 0.8221841034198084, 'border_count': 98}. Best is trial 13 with value: 0.9180073363822207.
# [I 2026-01-30 01:51:53,864] Trial 19 finished with value: 0.879613751733049 and parameters: {'learning_rate': 0.02246568504463305, 'depth': 3, 'l2_leaf_reg': 5.984184108305111, 'subsample': 0.7693490757279431, 'border_count': 68}. Best is trial 13 with value: 0.9180073363822207.
# [I 2026-01-30 01:53:51,781] Trial 20 finished with value: 0.9000551221383475 and parameters: {'learning_rate': 0.02786232990634561, 'depth': 5, 'l2_leaf_reg': 2.0363727756379557, 'subsample': 0.902606313615343, 'border_count': 94}. Best is trial 13 with value: 0.9180073363822207.
# [I 2026-01-30 01:57:17,305] Trial 21 finished with value: 0.9152036712194768 and parameters: {'learning_rate': 0.02683968112136207, 'depth': 8, 'l2_leaf_reg': 3.868001783710463, 'subsample': 0.8459997994279732, 'border_count': 102}. Best is trial 13 with value: 0.9180073363822207.
# [I 2026-01-30 02:00:23,251] Trial 22 finished with value: 0.9169099800586807 and parameters: {'learning_rate': 0.02975100480743661, 'depth': 8, 'l2_leaf_reg': 3.873519903537683, 'subsample': 0.6114243356173673, 'border_count': 33}. Best is trial 13 with value: 0.9180073363822207.
# [I 2026-01-30 02:02:55,758] Trial 23 finished with value: 0.9120956920897677 and parameters: {'learning_rate': 0.02939040121683126, 'depth': 7, 'l2_leaf_reg': 2.409523987954105, 'subsample': 0.6087394495253486, 'border_count': 36}. Best is trial 13 with value: 0.9180073363822207.
# [I 2026-01-30 02:05:59,084] Trial 24 finished with value: 0.9130474167614472 and parameters: {'learning_rate': 0.023566340038034518, 'depth': 8, 'l2_leaf_reg': 4.146648400523029, 'subsample': 0.6541605323367756, 'border_count': 37}. Best is trial 13 with value: 0.9180073363822207.
# [I 2026-01-30 02:08:54,922] Trial 25 finished with value: 0.91160604885587 and parameters: {'learning_rate': 0.02819589056485944, 'depth': 7, 'l2_leaf_reg': 5.758054348814863, 'subsample': 0.961885753091144, 'border_count': 121}. Best is trial 13 with value: 0.9180073363822207.
# [I 2026-01-30 02:12:21,369] Trial 26 finished with value: 0.9151113385857604 and parameters: {'learning_rate': 0.025828805445786616, 'depth': 8, 'l2_leaf_reg': 5.246130842436727, 'subsample': 0.7266810646038278, 'border_count': 112}. Best is trial 13 with value: 0.9180073363822207.
# [I 2026-01-30 02:14:32,930] Trial 27 finished with value: 0.9047896374251511 and parameters: {'learning_rate': 0.028542084118120193, 'depth': 6, 'l2_leaf_reg': 2.7682605514327125, 'subsample': 0.6481264512075655, 'border_count': 46}. Best is trial 13 with value: 0.9180073363822207.
# [I 2026-01-30 02:16:11,312] Trial 28 finished with value: 0.8934716579509877 and parameters: {'learning_rate': 0.029960112115909147, 'depth': 4, 'l2_leaf_reg': 6.708762764635282, 'subsample': 0.9218048542694999, 'border_count': 71}. Best is trial 13 with value: 0.9180073363822207.
# [I 2026-01-30 02:19:50,965] Trial 29 finished with value: 0.9003500473736183 and parameters: {'learning_rate': 0.010730224831508955, 'depth': 8, 'l2_leaf_reg': 4.3467779103289255, 'subsample': 0.9676129058850951, 'border_count': 122}. Best is trial 13 with value: 0.9180073363822207.
# [INFO] Best CatBoost params: {'learning_rate': 0.02978614542174841, 'depth': 8, 'l2_leaf_reg': 4.6935487839152055, 'subsample': 0.9957801021036417, 'border_count': 128}
# 0:	test: 0.8458664	best: 0.8458664 (0)	total: 329ms	remaining: 27m 24s
# 100:	test: 0.9083112	best: 0.9083112 (100)	total: 31s	remaining: 25m 5s
# 200:	test: 0.9225701	best: 0.9225701 (200)	total: 1m 1s	remaining: 24m 31s
# 300:	test: 0.9313863	best: 0.9313863 (300)	total: 1m 32s	remaining: 24m 2s
# 400:	test: 0.9360449	best: 0.9360566 (398)	total: 2m 3s	remaining: 23m 32s
# 500:	test: 0.9404446	best: 0.9404446 (500)	total: 2m 33s	remaining: 22m 59s
# 600:	test: 0.9435975	best: 0.9435975 (600)	total: 3m 3s	remaining: 22m 26s
# 700:	test: 0.9451539	best: 0.9451539 (700)	total: 3m 34s	remaining: 21m 54s
# 800:	test: 0.9459546	best: 0.9459546 (800)	total: 4m 5s	remaining: 21m 24s
# 900:	test: 0.9461331	best: 0.9465154 (850)	total: 4m 35s	remaining: 20m 52s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.9465154485
# bestIteration = 850
#
# Shrink model to first 851 iterations.

# %%
evaluate_and_log(model_catoost_reduced, X_test_reduced, y_test, experiment_name=EXPERIMENT_NAME, run_name="CATBoost_Optuna_Reduced", hp_search_history=hist_df, hp_search_plots= plot_paths)
evaluate_and_log(model_catoost_reduced, X_test_reduced, y_test, experiment_name=EXPERIMENT_NAME, run_name="CATBoost_Optuna_Reduced", hp_search_history=hist_df, hp_search_plots= plot_paths, prediction_threshold=0.1)
evaluate_and_log(model_catoost_reduced, X_test_reduced, y_test, experiment_name=EXPERIMENT_NAME, run_name="CATBoost_Optuna_Reduced", hp_search_history=hist_df, hp_search_plots= plot_paths, prediction_threshold=0.02)
# Out:
# [INFO] Logged metrics: {'roc_auc': np.float64(0.9160549469855122), 'pr_auc': np.float64(0.5252558316087079), 'precision': 0.2627327010888655, 'recall': 0.7362204724409449, 'f1': 0.3872637846233497, 'custom_loss': np.float64(0.978731330646527), 'precision_at_100': 0.91, 'recall_at_100': 0.022391732283464565, 'precision_at_118': 0.9067796610169492, 'recall_at_118': 0.026328740157480313, 'precision_at_500': 0.908, 'recall_at_500': 0.11171259842519685, 'precision_at_591': 0.9086294416243654, 'recall_at_591': 0.13213582677165353, 'precision_at_1000': 0.876, 'recall_at_1000': 0.2155511811023622, 'precision_at_1181': 0.8475867908552075, 'recall_at_1181': 0.24630905511811024, 'cost_opt_threshold': 0.16174325454668673, 'cost_opt_custom_loss': 0.5827632336505572, 'cost_opt_precision': 0.09395196781088898, 'cost_opt_recall': 0.9192913385826772, 'cost_opt_f1': 0.1704807319354765}
# [INFO] Logged SHAP summary plot.
# 2026/01/30 02:25:02 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# [INFO] Evaluation complete and logged.
# [INFO] Logged metrics: {'roc_auc': np.float64(0.9160549469855122), 'pr_auc': np.float64(0.5252558316087079), 'precision': 0.06894953564234657, 'recall': 0.9517716535433071, 'f1': 0.12858401343018133, 'custom_loss': np.float64(0.608180648220273), 'precision_at_100': 0.91, 'recall_at_100': 0.022391732283464565, 'precision_at_118': 0.9067796610169492, 'recall_at_118': 0.026328740157480313, 'precision_at_500': 0.908, 'recall_at_500': 0.11171259842519685, 'precision_at_591': 0.9086294416243654, 'recall_at_591': 0.13213582677165353, 'precision_at_1000': 0.876, 'recall_at_1000': 0.2155511811023622, 'precision_at_1181': 0.8475867908552075, 'recall_at_1181': 0.24630905511811024, 'cost_opt_threshold': 0.16174325454668673, 'cost_opt_custom_loss': 0.5827632336505572, 'cost_opt_precision': 0.09395196781088898, 'cost_opt_recall': 0.9192913385826772, 'cost_opt_f1': 0.1704807319354765}
# [INFO] Logged SHAP summary plot.
# 2026/01/30 02:25:32 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# [INFO] Evaluation complete and logged.
# [INFO] Logged metrics: {'roc_auc': np.float64(0.9160549469855122), 'pr_auc': np.float64(0.5252558316087079), 'precision': 0.03801694867429765, 'recall': 0.9945866141732284, 'f1': 0.07323458803279431, 'custom_loss': np.float64(0.8846056151996478), 'precision_at_100': 0.91, 'recall_at_100': 0.022391732283464565, 'precision_at_118': 0.9067796610169492, 'recall_at_118': 0.026328740157480313, 'precision_at_500': 0.908, 'recall_at_500': 0.11171259842519685, 'precision_at_591': 0.9086294416243654, 'recall_at_591': 0.13213582677165353, 'precision_at_1000': 0.876, 'recall_at_1000': 0.2155511811023622, 'precision_at_1181': 0.8475867908552075, 'recall_at_1181': 0.24630905511811024, 'cost_opt_threshold': 0.16174325454668673, 'cost_opt_custom_loss': 0.5827632336505572, 'cost_opt_precision': 0.09395196781088898, 'cost_opt_recall': 0.9192913385826772, 'cost_opt_f1': 0.1704807319354765}
# [INFO] Logged SHAP summary plot.
# 2026/01/30 02:26:01 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# [INFO] Evaluation complete and logged.
# {'roc_auc': np.float64(0.9160549469855122),
#  'pr_auc': np.float64(0.5252558316087079),
#  'precision': 0.03801694867429765,
#  'recall': 0.9945866141732284,
#  'f1': 0.07323458803279431,
#  'custom_loss': np.float64(0.8846056151996478),
#  'precision_at_100': 0.91,
#  'recall_at_100': 0.022391732283464565,
#  'precision_at_118': 0.9067796610169492,
#  'recall_at_118': 0.026328740157480313,
#  'precision_at_500': 0.908,
#  'recall_at_500': 0.11171259842519685,
#  'precision_at_591': 0.9086294416243654,
#  'recall_at_591': 0.13213582677165353,
#  'precision_at_1000': 0.876,
#  'recall_at_1000': 0.2155511811023622,
#  'precision_at_1181': 0.8475867908552075,
#  'recall_at_1181': 0.24630905511811024,
#  'cost_opt_threshold': 0.16174325454668673,
#  'cost_opt_custom_loss': 0.5827632336505572,
#  'cost_opt_precision': 0.09395196781088898,
#  'cost_opt_recall': 0.9192913385826772,
#  'cost_opt_f1': 0.1704807319354765}

# %%
from pathlib import Path
importlib.reload(feature_importance)
from feature_importance import save_shap_case_studies

case_studies_dir = Path("ai-gen/results/shap_case_studies_xgb_full")
save_shap_case_studies(
    model=model_lgmb_reduced,
    X=X_test_reduced,
    y=y_test,
    out_dir=case_studies_dir
)
# Out:
#     case_id  row_index  true_label  pred_prob  pred_label bucket
# 11  case_12      72027           1   0.499701           0     FN
# 25  case_26      76575           1   0.498470           0     FN
# 17  case_18      93410           1   0.497761           0     FN
# 36  case_37     105177           1   0.496992           0     FN
# 22  case_23      79224           1   0.496327           0     FN
# 1   case_02      49630           1   0.008228           0     FN
# 9   case_10      93282           1   0.006592           0     FN
# 23  case_24      54387           1   0.005908           0     FN
# 14  case_15      56709           1   0.004942           0     FN
# 20  case_21      93320           1   0.004856           0     FN
# 30  case_31      66162           0   0.997993           1     FP
# 3   case_04      66163           0   0.997862           1     FP
# 15  case_16      92610           0   0.997604           1     FP
# 31  case_32     109384           0   0.997509           1     FP
# 12  case_13     109386           0   0.997465           1     FP
# 28  case_29        314           0   0.500066           1     FP
# 0   case_01     100838           0   0.500042           1     FP
# 27  case_28      31608           0   0.500014           1     FP
# 13  case_14      81708           0   0.500011           1     FP
# 35  case_36      12417           0   0.500006           1     FP
# 34  case_35     116623           0   0.499964           0     TN
# 39  case_40      50242           0   0.499899           0     TN
# 6   case_07      65503           0   0.499898           0     TN
# 16  case_17      96834           0   0.499894           0     TN
# 26  case_27      67598           0   0.499865           0     TN
# 2   case_03     117392           0   0.001117           0     TN
# 24  case_25     116386           0   0.001038           0     TN
# 18  case_19      84244           0   0.001011           0     TN
# 5   case_06     116389           0   0.001007           0     TN
# 8   case_09      84237           0   0.000948           0     TN
# 21  case_22      60361           1   0.998497           1     TP
# 7   case_08      40218           1   0.998491           1     TP
# 33  case_34      60395           1   0.998484           1     TP
# 32  case_33      60373           1   0.998483           1     TP
# 38  case_39      60383           1   0.998473           1     TP
# 10  case_11      75982           1   0.501275           1     TP
# 4   case_05      36264           1   0.501219           1     TP
# 19  case_20      41760           1   0.500770           1     TP
# 29  case_30      61223           1   0.500438           1     TP
# 37  case_38       7607           1   0.500244           1     TP
