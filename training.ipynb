# %% [markdown]
# # 0.Setup and data loading

# %%
import pandas as pd
import numpy as np
import os
import random

# ignore warnings
import warnings
warnings.filterwarnings('ignore')

import importlib
import train_models_util
import feature_importance
import evaluate_models_util
importlib.reload(train_models_util)
importlib.reload(feature_importance)
importlib.reload(evaluate_models_util)
from train_models_util import (
    train_xgb_optuna, 
    train_catboost_optuna, 
    train_lgbm_optuna,
    plot_fp_fn_rate_over_time
)
from evaluate_models_util import evaluate_and_log
from feature_importance import get_top_features_shap

# set all random seeds for reproducibility
np.random.seed(42)
random.seed(42)
os.environ['PYTHONHASHSEED'] = str(42)

# %%
EXPERIMENT_NAME = "Fraud-detection-custom-thresholds_v7"

# %%
data_folder = 'ieee-fraud-detection-data/processed/'

data = pd.read_csv(f'{data_folder}train_processed.csv')

# %%
data = data.drop(columns=['TransactionDT','uid'], axis='columns')

# %%
cat_cols = np.array(data.select_dtypes(include=['object']).columns)
for c in cat_cols:
    if c in data.columns:
        if data[c].isnull().sum()>0:
            data[c].fillna('missing', inplace=True)
        data[c] = data[c].astype('category')

# %%
# attempt without suffle, since the data have time relation
n = len(data)
split_idx = int(n * 0.8) 

train = data.iloc[:split_idx]
test = data.iloc[split_idx:]

# %%
del data, cat_cols, c #,fraud_indices, non_fraud_indices,
import gc
gc.collect()
# Out:
# 21950

# %% [markdown]
# ## Some more features

# %%
# # 0. Sort train by uid + time to ensure correct ordering

# train = train.sort_values(["uid", "TransactionDT"])


# # 1. count_seen_before
# #    = how many times we saw this user before this row

# train["count_seen_before"] = train.groupby("uid").cumcount()
# # Example: 0,1,2,... for each user


# # 2. cumulative_fraud_before
# #    = total fraud count for this user BEFORE this transaction

# train["cumulative_fraud_before"] = (
#     train.groupby("uid")["isFraud"]
#          .cumsum()                # running fraud count
#          .shift(1, fill_value=0)  # shift so we don't include current fraud
# )


# # 3. fraud_percentage_before
# #    = cumulative_fraud_before / count_seen_before

# train["fraud_percentage_before"] = (
#     train["cumulative_fraud_before"] / 
#     train["count_seen_before"].replace(0, pd.NA)
# )

# # Fill NaN for first-time users (count_seen_before == 0 → pct = 0)
# train["fraud_percentage_before"] = train["fraud_percentage_before"].fillna(0)



# # 4. Build TRAIN HISTORY LOOKUP
# #    Used to compute safe features for validation/test.

# user_tx_count = train.groupby("uid")["count_seen_before"].max().to_dict()
# user_cum_fraud = train.groupby("uid")["cumulative_fraud_before"].max().to_dict()

# train = train.sort_values('TransactionDT')
# Out:
#         TransactionDT  TransactionAmt ProductCD  card1  card2  card3  \
# 0               86400           68.50         W  13926    NaN  150.0
# 1               86401           29.00         W   2755  404.0  150.0
# 2               86469           59.00         W   4663  490.0  150.0
# 3               86499           50.00         W  18132  567.0  150.0
# 4               86506           50.00         H   4497  514.0  150.0
# ...               ...             ...       ...    ...    ...    ...
# 354319        8745488          226.00         W  15497  490.0  150.0
# 354320        8745617           59.00         W   4141  404.0  150.0
# 354321        8745766           50.00         W  12538  543.0  150.0
# 354322        8745770          159.95         W  12219    NaN  150.0
# 354323        8745772           34.00         W   9500  321.0  150.0
#
#              card4  card5   card6  addr1  ...  uid_P_emaildomain_3_freq  \
# 0         discover  142.0  credit  315.0  ...                       NaN
# 1       mastercard  102.0  credit  325.0  ...                       NaN
# 2             visa  166.0   debit  330.0  ...                       NaN
# 3       mastercard  117.0   debit  476.0  ...                       NaN
# 4       mastercard  102.0  credit  420.0  ...                       NaN
# ...            ...    ...     ...    ...  ...                       ...
# 354319        visa  226.0   debit  299.0  ...                       NaN
# 354320  mastercard  102.0  credit  143.0  ...                       NaN
# 354321  mastercard  224.0   debit  327.0  ...                       NaN
# 354322        visa  166.0   debit  143.0  ...                       NaN
# 354323        visa  226.0   debit  272.0  ...                       NaN
#
#         uid_R_emaildomain_1_ct uid_R_emaildomain_1_freq  \
# 0                          0.0                      NaN
# 1                          0.0                      NaN
# 2                          0.0                      NaN
# 3                          0.0                      NaN
# 4                          0.0                      NaN
# ...                        ...                      ...
# 354319                     0.0                      NaN
# 354320                     0.0                      NaN
# 354321                     0.0                      NaN
# 354322                     0.0                      NaN
# 354323                     0.0                      NaN
#
#        uid_R_emaildomain_2_ct  uid_R_emaildomain_2_freq  \
# 0                         0.0                       NaN
# 1                         0.0                       NaN
# 2                         0.0                       NaN
# 3                         0.0                       NaN
# 4                         0.0                       NaN
# ...                       ...                       ...
# 354319                    0.0                       NaN
# 354320                    0.0                       NaN
# 354321                    0.0                       NaN
# 354322                    0.0                       NaN
# 354323                    0.0                       NaN
#
#         uid_R_emaildomain_3_ct  uid_R_emaildomain_3_freq  count_seen_before  \
# 0                          0.0                       NaN                  0
# 1                          0.0                       NaN                  0
# 2                          0.0                       NaN                  0
# 3                          0.0                       NaN                  0
# 4                          0.0                       NaN                  0
# ...                        ...                       ...                ...
# 354319                     0.0                       NaN                 10
# 354320                     0.0                       NaN                  7
# 354321                     0.0                       NaN                  4
# 354322                     0.0                       NaN                  0
# 354323                     0.0                       NaN                  2
#
#         cumulative_fraud_before  fraud_percentage_before
# 0                             0                      0.0
# 1                             0                      0.0
# 2                             0                      0.0
# 3                             0                      0.0
# 4                             0                      0.0
# ...                         ...                      ...
# 354319                        0                      0.0
# 354320                        0                      0.0
# 354321                        0                      0.0
# 354322                        0                      0.0
# 354323                        0                      0.0
#
# [354324 rows x 754 columns]

# %%
# # 5. Function to compute history-based features for val/test
# #    Uses ONLY training history → no leakage
# def get_user_history(uid):
#     # Number of previous transactions in TRAIN
#     prev_seen = user_tx_count.get(uid, 0)
    
#     # Number of previous frauds in TRAIN
#     prev_fraud = user_cum_fraud.get(uid, 0)
    
#     # Fraud percentage history
#     fraud_pct = 0 if prev_seen == 0 else prev_fraud / prev_seen
    
#     return pd.Series([prev_seen, prev_fraud, fraud_pct])

# %%
# # 6. Apply to VALIDATION
# valid[[
#     "count_seen_before", 
#     "cumulative_fraud_before",
#     "fraud_percentage_before"
# ]] = valid.apply(lambda row: get_user_history(row["uid"]), axis=1)

# # 7. Apply to TEST
# test[[
#     "count_seen_before", 
#     "cumulative_fraud_before",
#     "fraud_percentage_before"
# ]] = test.apply(lambda row: get_user_history(row["uid"]), axis=1)

# %% [markdown]
# ## 1. Full Features

# %%
# split to X and y
X_train = train.drop(columns='isFraud', axis='columns')
X_test = test.drop(columns='isFraud', axis='columns')

y_train = train['isFraud']
y_test = test['isFraud']

del train, test

# %% [markdown]
# ### 1.1. XGBoost

# %%
model_xgboost_full, best_params_xgboost_full, hist_df, plot_paths = train_xgb_optuna(X_train, y_train)
# Out:
# [I 2025-12-10 20:23:15,876] A new study created in memory with name: xgboost_aucpr_optimization
# [Optuna XGBoost Tuning]:   0%|          | 0/30 [00:00<?, ?trial/s]
# [I 2025-12-10 20:34:12,636] Trial 0 finished with value: 0.5418969175306082 and parameters: {'learning_rate': 0.02008464906455329, 'max_depth': 7, 'subsample': 0.6200008408567017, 'colsample_bytree': 0.901637887545111, 'min_child_weight': 0.04523002904405033, 'gamma': 2.5843537499492313}. Best is trial 0 with value: 0.5418969175306082.
# [I 2025-12-10 20:43:25,313] Trial 1 finished with value: 0.4960168035592985 and parameters: {'learning_rate': 0.02410028239617086, 'max_depth': 3, 'subsample': 0.8357876387438774, 'colsample_bytree': 0.5606294566704293, 'min_child_weight': 0.34658968730683914, 'gamma': 1.604750142653607}. Best is trial 0 with value: 0.5418969175306082.
# [I 2025-12-10 20:53:16,103] Trial 2 finished with value: 0.5191261091250304 and parameters: {'learning_rate': 0.02635393575225079, 'max_depth': 4, 'subsample': 0.9533776467343262, 'colsample_bytree': 0.6757248726040863, 'min_child_weight': 0.001536459239612567, 'gamma': 2.05674534462281}. Best is trial 0 with value: 0.5418969175306082.
# [I 2025-12-10 21:03:57,359] Trial 3 finished with value: 0.5472646538075999 and parameters: {'learning_rate': 0.023774680344839032, 'max_depth': 7, 'subsample': 0.517195097137007, 'colsample_bytree': 0.960575110693833, 'min_child_weight': 0.00402932325775631, 'gamma': 3.2156316027696468}. Best is trial 3 with value: 0.5472646538075999.
# [I 2025-12-10 21:14:54,287] Trial 4 finished with value: 0.5544680574164842 and parameters: {'learning_rate': 0.02478461594807884, 'max_depth': 8, 'subsample': 0.7470706359482251, 'colsample_bytree': 0.5998885768231582, 'min_child_weight': 0.22046876197173004, 'gamma': 1.7905109358034588}. Best is trial 4 with value: 0.5544680574164842.
# [I 2025-12-10 21:24:28,147] Trial 5 finished with value: 0.5345146837835738 and parameters: {'learning_rate': 0.028828919307225177, 'max_depth': 5, 'subsample': 0.9844658361506646, 'colsample_bytree': 0.7475157411061358, 'min_child_weight': 0.0018414094674772525, 'gamma': 2.9491065206001683}. Best is trial 4 with value: 0.5544680574164842.
# [I 2025-12-10 21:35:45,396] Trial 6 finished with value: 0.5278369323351144 and parameters: {'learning_rate': 0.01279992621369619, 'max_depth': 8, 'subsample': 0.9135194818596568, 'colsample_bytree': 0.5829859373555173, 'min_child_weight': 0.26140639483668643, 'gamma': 0.7297513795251459}. Best is trial 4 with value: 0.5544680574164842.
# [I 2025-12-10 21:45:22,338] Trial 7 finished with value: 0.5310311004726123 and parameters: {'learning_rate': 0.02816380913396989, 'max_depth': 5, 'subsample': 0.6946779629551008, 'colsample_bytree': 0.7678287598880091, 'min_child_weight': 0.0036218500928619575, 'gamma': 2.3981081982202768}. Best is trial 4 with value: 0.5544680574164842.
# [I 2025-12-10 21:56:37,607] Trial 8 finished with value: 0.5407328094886957 and parameters: {'learning_rate': 0.013758886163381003, 'max_depth': 8, 'subsample': 0.8042316217838761, 'colsample_bytree': 0.7952056408198154, 'min_child_weight': 0.001097819254224766, 'gamma': 3.419278100653896}. Best is trial 4 with value: 0.5544680574164842.
# [I 2025-12-10 22:06:13,069] Trial 9 finished with value: 0.5285310910223006 and parameters: {'learning_rate': 0.020506757944636803, 'max_depth': 5, 'subsample': 0.7797401660342904, 'colsample_bytree': 0.5264436225059154, 'min_child_weight': 0.0012970992863554328, 'gamma': 2.2023805738102107}. Best is trial 4 with value: 0.5544680574164842.
# [I 2025-12-10 22:16:46,295] Trial 10 finished with value: 0.5386617885362334 and parameters: {'learning_rate': 0.016795387999055156, 'max_depth': 7, 'subsample': 0.6751569098623191, 'colsample_bytree': 0.656610334620441, 'min_child_weight': 0.07202121719028313, 'gamma': 4.630062372068041}. Best is trial 4 with value: 0.5544680574164842.
# [I 2025-12-10 22:27:42,490] Trial 11 finished with value: 0.5461397940350655 and parameters: {'learning_rate': 0.023221709933996137, 'max_depth': 7, 'subsample': 0.5560360790736636, 'colsample_bytree': 0.9795161064404461, 'min_child_weight': 0.008769326316866777, 'gamma': 3.8743797844983883}. Best is trial 4 with value: 0.5544680574164842.
# [I 2025-12-10 22:38:17,042] Trial 12 finished with value: 0.52289069900038 and parameters: {'learning_rate': 0.02434628367644541, 'max_depth': 6, 'subsample': 0.5458090430550144, 'colsample_bytree': 0.8794803872391691, 'min_child_weight': 0.8782791109006456, 'gamma': 0.008572492095731299}. Best is trial 4 with value: 0.5544680574164842.
# [I 2025-12-10 22:50:18,449] Trial 13 finished with value: 0.5466373028607604 and parameters: {'learning_rate': 0.022934670734435936, 'max_depth': 8, 'subsample': 0.5038605980273162, 'colsample_bytree': 0.9867359636229676, 'min_child_weight': 0.012328244354954896, 'gamma': 1.5738260871277834}. Best is trial 4 with value: 0.5544680574164842.
# [I 2025-12-10 23:00:20,369] Trial 14 finished with value: 0.5300047685815078 and parameters: {'learning_rate': 0.017461980395718803, 'max_depth': 6, 'subsample': 0.7073436395401353, 'colsample_bytree': 0.6166637092134186, 'min_child_weight': 0.14073454184097714, 'gamma': 4.110347922457242}. Best is trial 4 with value: 0.5544680574164842.
# [I 2025-12-10 23:10:52,345] Trial 15 finished with value: 0.5533009514687673 and parameters: {'learning_rate': 0.026474138765090124, 'max_depth': 7, 'subsample': 0.8716390819644745, 'colsample_bytree': 0.8707567916466584, 'min_child_weight': 0.014810848192466102, 'gamma': 0.995453046280959}. Best is trial 4 with value: 0.5544680574164842.
# [I 2025-12-10 23:22:00,082] Trial 16 finished with value: 0.5709498625956216 and parameters: {'learning_rate': 0.029742596648851545, 'max_depth': 8, 'subsample': 0.8469353033128059, 'colsample_bytree': 0.850902041776415, 'min_child_weight': 0.023357406099895485, 'gamma': 0.9451189694511664}. Best is trial 16 with value: 0.5709498625956216.
# [I 2025-12-10 23:33:10,680] Trial 17 finished with value: 0.5658223763232443 and parameters: {'learning_rate': 0.029447806105334953, 'max_depth': 8, 'subsample': 0.7557040209544589, 'colsample_bytree': 0.815654633966895, 'min_child_weight': 0.032913703836104494, 'gamma': 0.42687352550952207}. Best is trial 16 with value: 0.5709498625956216.
# [I 2025-12-10 23:43:11,459] Trial 18 finished with value: 0.5493898997621729 and parameters: {'learning_rate': 0.029617261032528375, 'max_depth': 6, 'subsample': 0.8728693340340947, 'colsample_bytree': 0.8195535817624588, 'min_child_weight': 0.026717675848379994, 'gamma': 0.018169194581643622}. Best is trial 16 with value: 0.5709498625956216.
# [I 2025-12-10 23:54:15,886] Trial 19 finished with value: 0.5615284101631065 and parameters: {'learning_rate': 0.029894751643095983, 'max_depth': 8, 'subsample': 0.7326053618706484, 'colsample_bytree': 0.8373229209387476, 'min_child_weight': 0.08956515040615348, 'gamma': 0.9079217460945919}. Best is trial 16 with value: 0.5709498625956216.
# [I 2025-12-11 00:03:17,040] Trial 20 finished with value: 0.49699501003552254 and parameters: {'learning_rate': 0.026995934196431332, 'max_depth': 3, 'subsample': 0.6351914640507422, 'colsample_bytree': 0.7323327002792441, 'min_child_weight': 0.04278176521344808, 'gamma': 0.5636251297779704}. Best is trial 16 with value: 0.5709498625956216.
# [I 2025-12-11 00:14:21,205] Trial 21 finished with value: 0.5645748413527587 and parameters: {'learning_rate': 0.029896981186236057, 'max_depth': 8, 'subsample': 0.7413355578937196, 'colsample_bytree': 0.8364611272681198, 'min_child_weight': 0.10645202524877498, 'gamma': 1.1683287565068812}. Best is trial 16 with value: 0.5709498625956216.
# [I 2025-12-11 00:25:37,865] Trial 22 finished with value: 0.5679661494014878 and parameters: {'learning_rate': 0.027757010100152718, 'max_depth': 8, 'subsample': 0.7933495083932762, 'colsample_bytree': 0.9260085591822549, 'min_child_weight': 0.022557118809793376, 'gamma': 1.4078303692377232}. Best is trial 16 with value: 0.5709498625956216.
# [I 2025-12-11 00:36:14,335] Trial 23 finished with value: 0.5559983888332459 and parameters: {'learning_rate': 0.02787939232185539, 'max_depth': 7, 'subsample': 0.8067644977292604, 'colsample_bytree': 0.9277413305308212, 'min_child_weight': 0.026115915139900886, 'gamma': 0.4192106229575165}. Best is trial 16 with value: 0.5709498625956216.
# [I 2025-12-11 00:47:27,025] Trial 24 finished with value: 0.5644742765027067 and parameters: {'learning_rate': 0.025592920612442012, 'max_depth': 8, 'subsample': 0.8570945269262599, 'colsample_bytree': 0.911379594272383, 'min_child_weight': 0.005679721769538222, 'gamma': 1.3226917235819653}. Best is trial 16 with value: 0.5709498625956216.
# [I 2025-12-11 00:58:15,267] Trial 25 finished with value: 0.5555348692567397 and parameters: {'learning_rate': 0.02165936594103783, 'max_depth': 7, 'subsample': 0.7847703619994265, 'colsample_bytree': 0.7127604145558819, 'min_child_weight': 0.021073465282429666, 'gamma': 0.4600382826274264}. Best is trial 16 with value: 0.5709498625956216.
# [I 2025-12-11 01:09:28,843] Trial 26 finished with value: 0.5619892747648058 and parameters: {'learning_rate': 0.02790084502530696, 'max_depth': 8, 'subsample': 0.895198064373995, 'colsample_bytree': 0.9465607980720111, 'min_child_weight': 0.04444318515687441, 'gamma': 1.3161871427640204}. Best is trial 16 with value: 0.5709498625956216.
# [I 2025-12-11 01:19:41,668] Trial 27 finished with value: 0.5312934962657655 and parameters: {'learning_rate': 0.018005168864165484, 'max_depth': 6, 'subsample': 0.8244367847082694, 'colsample_bytree': 0.858898797028049, 'min_child_weight': 0.008524132570258877, 'gamma': 0.2997676652563641}. Best is trial 16 with value: 0.5709498625956216.
# [I 2025-12-11 01:29:02,449] Trial 28 finished with value: 0.47538396742880956 and parameters: {'learning_rate': 0.010482634066714146, 'max_depth': 4, 'subsample': 0.9322119221763219, 'colsample_bytree': 0.8003535758804079, 'min_child_weight': 0.015467925355297724, 'gamma': 1.8400663594577442}. Best is trial 16 with value: 0.5709498625956216.
# [I 2025-12-11 01:39:33,447] Trial 29 finished with value: 0.5541154794666655 and parameters: {'learning_rate': 0.02719553745206786, 'max_depth': 7, 'subsample': 0.6091865766498759, 'colsample_bytree': 0.8878842311102096, 'min_child_weight': 0.054489779307935915, 'gamma': 2.628672157370559}. Best is trial 16 with value: 0.5709498625956216.
# [INFO] Best XGBoost params: {'learning_rate': 0.029742596648851545, 'max_depth': 8, 'subsample': 0.8469353033128059, 'colsample_bytree': 0.850902041776415, 'min_child_weight': 0.023357406099895485, 'gamma': 0.9451189694511664}
# [0]	validation_0-aucpr:0.34212
# [100]	validation_0-aucpr:0.54983
# [200]	validation_0-aucpr:0.60059
# [300]	validation_0-aucpr:0.61733
# [400]	validation_0-aucpr:0.62851
# [500]	validation_0-aucpr:0.63590
# [600]	validation_0-aucpr:0.64362
# [700]	validation_0-aucpr:0.64710
# [800]	validation_0-aucpr:0.64898
# [900]	validation_0-aucpr:0.64894
# [934]	validation_0-aucpr:0.64942

# %%
evaluate_and_log(model_xgboost_full, X_test, y_test, experiment_name=EXPERIMENT_NAME, run_name="XGBoost_Optuna_fullfeatures", hp_search_history=hist_df, hp_search_plots= plot_paths)
# Out:
# 2025/12/12 20:04:25 INFO mlflow.tracking.fluent: Experiment with name 'Fraud-detection-custom-thresholds_v7' does not exist. Creating a new experiment.
# [INFO] Logged metrics: {'roc_auc': np.float64(0.8807625525871076), 'pr_auc': np.float64(0.5165338821447129), 'precision': 0.496701685805033, 'recall': 0.500246062992126, 'f1': 0.49846757386293983, 'custom_loss': np.float64(1.7370542215599283)}
# [INFO] Logged SHAP summary plot.
# 2025/12/12 20:04:42 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# [INFO] Evaluation complete and logged.
# {'roc_auc': np.float64(0.8807625525871076),
#  'pr_auc': np.float64(0.5165338821447129),
#  'precision': 0.496701685805033,
#  'recall': 0.500246062992126,
#  'f1': 0.49846757386293983,
#  'custom_loss': np.float64(1.7370542215599283)}

# %% [markdown]
# ### 1.2. LightGBM

# %%
model_lgbm_full, best_params_lgbm_full, hist_df, plot_paths = train_lgbm_optuna(X_train, y_train)
# Out:
# [I 2025-12-11 01:50:33,421] A new study created in memory with name: lgbm_aucpr_optimization
# [Optuna LightGBM Tuning]:   0%|          | 0/30 [00:00<?, ?trial/s]
# [I 
# [I 2025-12-11 02:49:47,500] Trial 15 finished with value: 0.6498033459604667 and parameters: {'num_leaves': 461, 'max_depth': 20, 'learning_rate': 0.026153154699380163, 'min_child_samples': 60, 'reg_alpha': 0.17994959779243747, 'reg_lambda': 0.16557423962662024, 'colsample_bytree': 0.9667020006865467, 'subsample': 0.9645318956042908}. Best is trial 14 with value: 0.6547745289793007.
# [I 2025-12-11 02:56:22,778] Trial 16 finished with value: 0.6524664788389464 and parameters: {'num_leaves': 445, 'max_depth': 20, 'learning_rate': 0.02605770830125854, 'min_child_samples': 68, 'reg_alpha': 0.18003540227577328, 'reg_lambda': 0.08894826035000977, 'colsample_bytree': 0.9634289070923414, 'subsample': 0.920139615799462}. Best is trial 14 with value: 0.6547745289793007.
# [I 2025-12-11 03:00:30,639] Trial 17 finished with value: 0.6062200917131578 and parameters: {'num_leaves': 350, 'max_depth': 19, 'learning_rate': 0.025979385364305867, 'min_child_samples': 48, 'reg_alpha': 0.11677298690719826, 'reg_lambda': 0.23128349817975433, 'colsample_bytree': 0.9685541599636867, 'subsample': 0.9960955672328983}. Best is trial 14 with value: 0.6547745289793007.
# [I 2025-12-11 03:06:48,742] Trial 18 finished with value: 0.6558420139055025 and parameters: {'num_leaves': 447, 'max_depth': 20, 'learning_rate': 0.024240466897141592, 'min_child_samples': 84, 'reg_alpha': 0.12397436518223405, 'reg_lambda': 0.18265070503065436, 'colsample_bytree': 0.8789896850185078, 'subsample': 0.9710956914825437}. Best is trial 18 with value: 0.6558420139055025.
# [I 2025-12-11 03:13:27,429] Trial 19 finished with value: 0.6510501012888928 and parameters: {'num_leaves': 451, 'max_depth': 18, 'learning_rate': 0.01789978773628571, 'min_child_samples': 84, 'reg_alpha': 0.12213362407767897, 'reg_lambda': 0.1926817553454202, 'colsample_bytree': 0.8838259384488619, 'subsample': 0.964199644643107}. Best is trial 18 with value: 0.6558420139055025.
# [I 2025-12-11 03:21:08,489] Trial 20 finished with value: 0.6468460906971597 and parameters: {'num_leaves': 468, 'max_depth': 19, 'learning_rate': 0.01386196903443699, 'min_child_samples': 64, 'reg_alpha': 0.000501268341011829, 'reg_lambda': 0.10299804858961611, 'colsample_bytree': 0.8900617207746753, 'subsample': 0.9231379022181557}. Best is trial 18 with value: 0.6558420139055025.
# [I 2025-12-11 03:25:38,839] Trial 21 finished with value: 0.6096260874302027 and parameters: {'num_leaves': 355, 'max_depth': 20, 'learning_rate': 0.024183177544334047, 'min_child_samples': 88, 'reg_alpha': 0.12726147655122086, 'reg_lambda': 0.055069958078588166, 'colsample_bytree': 0.977863339372051, 'subsample': 0.9727377455829199}. Best is trial 18 with value: 0.6558420139055025.
# [I 2025-12-11 03:31:45,589] Trial 22 finished with value: 0.6496090930223859 and parameters: {'num_leaves': 424, 'max_depth': 20, 'learning_rate': 0.0246505240699406, 'min_child_samples': 74, 'reg_alpha': 0.22676662044310256, 'reg_lambda': 0.1973521324539695, 'colsample_bytree': 0.8693372233894381, 'subsample': 0.9996887450314592}. Best is trial 18 with value: 0.6558420139055025.
# [I 2025-12-11 03:33:50,835] Trial 23 finished with value: 0.5245422789558459 and parameters: {'num_leaves': 129, 'max_depth': 19, 'learning_rate': 0.02752667342313781, 'min_child_samples': 89, 'reg_alpha': 0.2098815600731869, 'reg_lambda': 0.13762972515660443, 'colsample_bytree': 0.9042724652293246, 'subsample': 0.953267796024265}. Best is trial 18 with value: 0.6558420139055025.
# [I 2025-12-11 03:37:51,343] Trial 24 finished with value: 0.609295474413687 and parameters: {'num_leaves': 359, 'max_depth': 17, 'learning_rate': 0.02464921705534893, 'min_child_samples': 71, 'reg_alpha': 0.26967060538135335, 'reg_lambda': 0.05624336617136508, 'colsample_bytree': 0.952537942042444, 'subsample': 0.9780933062853483}. Best is trial 18 with value: 0.6558420139055025.
# [I 2025-12-11 03:44:34,956] Trial 25 finished with value: 0.6493264657219617 and parameters: {'num_leaves': 429, 'max_depth': 20, 'learning_rate': 0.026977782098503687, 'min_child_samples': 53, 'reg_alpha': 0.0962756483619527, 'reg_lambda': 0.21839951743674602, 'colsample_bytree': 0.9823095342534227, 'subsample': 0.9832582814408333}. Best is trial 18 with value: 0.6558420139055025.
# [I 2025-12-11 03:51:14,950] Trial 26 finished with value: 0.6510275210350008 and parameters: {'num_leaves': 488, 'max_depth': 18, 'learning_rate': 0.01894364245062468, 'min_child_samples': 88, 'reg_alpha': 0.15504485075657226, 'reg_lambda': 0.28367612147477084, 'colsample_bytree': 0.9203587532873609, 'subsample': 0.9282976248479835}. Best is trial 18 with value: 0.6558420139055025.
# [I 2025-12-11 03:57:11,868] Trial 27 finished with value: 0.6462298733503683 and parameters: {'num_leaves': 429, 'max_depth': 17, 'learning_rate': 0.02369213216570821, 'min_child_samples': 78, 'reg_alpha': 0.41830190728226546, 'reg_lambda': 0.15923610125520063, 'colsample_bytree': 0.9834699916852938, 'subsample': 0.9671109442754021}. Best is trial 18 with value: 0.6558420139055025.
# [I 2025-12-11 04:03:44,207] Trial 28 finished with value: 0.6544287296933536 and parameters: {'num_leaves': 476, 'max_depth': 19, 'learning_rate': 0.021787536633738374, 'min_child_samples': 65, 'reg_alpha': 0.24330319864324723, 'reg_lambda': 0.04678963936036554, 'colsample_bytree': 0.8624273424387084, 'subsample': 0.9560279468375663}. Best is trial 18 with value: 0.6558420139055025.
# [I 2025-12-11 04:10:20,458] Trial 29 finished with value: 0.6484801707174928 and parameters: {'num_leaves': 479, 'max_depth': 19, 'learning_rate': 0.02134069644127226, 'min_child_samples': 48, 'reg_alpha': 0.23658493126003197, 'reg_lambda': 0.05677279340265684, 'colsample_bytree': 0.8285246410344823, 'subsample': 0.9068347168145177}. Best is trial 18 with value: 0.6558420139055025.
# [INFO] Best LightGBM params: {'num_leaves': 447, 'max_depth': 20, 'learning_rate': 0.024240466897141592, 'min_child_samples': 84, 'reg_alpha': 0.12397436518223405, 'reg_lambda': 0.18265070503065436, 'colsample_bytree': 0.8789896850185078, 'subsample': 0.9710956914825437}
# [50]	valid_0's binary_logloss: 0.122919
# [100]	valid_0's binary_logloss: 0.116016
# [150]	valid_0's binary_logloss: 0.106728
# [200]	valid_0's binary_logloss: 0.0997755
# [250]	valid_0's binary_logloss: 0.0938943
# [300]	valid_0's binary_logloss: 0.088788
# [350]	valid_0's binary_logloss: 0.0842811
# [400]	valid_0's binary_logloss: 0.080808
# [450]	valid_0's binary_logloss: 0.078805
# [500]	valid_0's binary_logloss: 0.078362
# [550]	valid_0's binary_logloss: 0.0784578
# [600]	valid_0's binary_logloss: 0.0791059

# %%
evaluate_and_log(model_lgbm_full,  X_test, y_test, experiment_name=EXPERIMENT_NAME, run_name="LightGBM_Optuna_fullfeatures", hp_search_history=hist_df, hp_search_plots= plot_paths)
# Out:
# [INFO] Logged metrics: {'roc_auc': np.float64(0.907969739611483), 'pr_auc': np.float64(0.5812353671424075), 'precision': 0.6744031830238727, 'recall': 0.500492125984252, 'f1': 0.5745762711864407, 'custom_loss': np.float64(1.7270802993870018)}
# [INFO] Logged SHAP summary plot.
# 2025/12/12 20:05:48 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# [INFO] Evaluation complete and logged.
# {'roc_auc': np.float64(0.907969739611483),
#  'pr_auc': np.float64(0.5812353671424075),
#  'precision': 0.6744031830238727,
#  'recall': 0.500492125984252,
#  'f1': 0.5745762711864407,
#  'custom_loss': np.float64(1.7270802993870018)}

# %% [markdown]
# ### 1.3. CatBoost

# %%
model_catboost_full, best_params_catboost_full, hist_df, plot_paths = train_catboost_optuna(X_train, y_train)
# Out:
# [I 2025-12-11 04:16:55,284] A new study created in memory with name: catboost_aucpr_optimization
# [Optuna CatBoost Tuning]:   0%|          | 0/30 [00:00<?, ?trial/s]
# [I 2025-12-11 04:31:24,201] Trial 0 finished with value: 0.5287053124530988 and parameters: {'learning_rate': 0.01900374826476142, 'depth': 6, 'l2_leaf_reg': 9.904870924520075, 'subsample': 0.7066417028196362, 'border_count': 111}. Best is trial 0 with value: 0.5287053124530988.
# [I 2025-12-11 04:51:32,869] Trial 1 finished with value: 0.5421848547393376 and parameters: {'learning_rate': 0.01424323267912269, 'depth': 8, 'l2_leaf_reg': 9.912432061918471, 'subsample': 0.7766886006649043, 'border_count': 38}. Best is trial 1 with value: 0.5421848547393376.
# [I 2025-12-11 05:08:38,826] Trial 2 finished with value: 0.5511386737465074 and parameters: {'learning_rate': 0.02567731813242579, 'depth': 7, 'l2_leaf_reg': 8.678681159414351, 'subsample': 0.727595773473682, 'border_count': 114}. Best is trial 2 with value: 0.5511386737465074.
# [I 2025-12-11 05:26:51,595] Trial 3 finished with value: 0.5504744441433648 and parameters: {'learning_rate': 0.020145512675280988, 'depth': 7, 'l2_leaf_reg': 8.454083024180171, 'subsample': 0.8761071252023334, 'border_count': 97}. Best is trial 2 with value: 0.5511386737465074.
# [I 2025-12-11 05:39:06,154] Trial 4 finished with value: 0.5277758508318845 and parameters: {'learning_rate': 0.027405703664641075, 'depth': 5, 'l2_leaf_reg': 9.098508563660541, 'subsample': 0.8227907216169753, 'border_count': 74}. Best is trial 2 with value: 0.5511386737465074.
# [I 2025-12-11 05:57:37,693] Trial 5 finished with value: 0.5410641351035393 and parameters: {'learning_rate': 0.017663287754799258, 'depth': 7, 'l2_leaf_reg': 6.181245353202578, 'subsample': 0.9507896608807143, 'border_count': 48}. Best is trial 2 with value: 0.5511386737465074.
# [I 2025-12-11 12:45:02,687] Trial 28 finished with value: 0.565258922094081 and parameters: {'learning_rate': 0.02504979179179291, 'depth': 8, 'l2_leaf_reg': 8.34120201314984, 'subsample': 0.8341545153698682, 'border_count': 118}. Best is trial 21 with value: 0.5743951151173962.
# [I 2025-12-11 13:01:03,828] Trial 29 finished with value: 0.5288989711865221 and parameters: {'learning_rate': 0.017042538770222656, 'depth': 6, 'l2_leaf_reg': 9.281789000747999, 'subsample': 0.9999781083834313, 'border_count': 109}. Best is trial 21 with value: 0.5743951151173962.
# [INFO] Best CatBoost params: {'learning_rate': 0.026880459534529604, 'depth': 8, 'l2_leaf_reg': 7.314549860868977, 'subsample': 0.94911421218717, 'border_count': 108}
# 0:	learn: 0.8642463	test: 0.8767199	best: 0.8767199 (0)	total: 2.17s	remaining: 3h 43s
# 100:	learn: 0.9309533	test: 0.9256100	best: 0.9256100 (100)	total: 3m 46s	remaining: 3h 3m 24s
# 200:	learn: 0.9482742	test: 0.9362463	best: 0.9362463 (200)	total: 7m 20s	remaining: 2h 55m 24s
# 300:	learn: 0.9588261	test: 0.9425871	best: 0.9425871 (300)	total: 10m 54s	remaining: 2h 50m 17s
# 400:	learn: 0.9656646	test: 0.9464478	best: 0.9464478 (400)	total: 14m 25s	remaining: 2h 45m 29s
# 500:	learn: 0.9721868	test: 0.9503005	best: 0.9503005 (500)	total: 17m 59s	remaining: 2h 41m 30s
# 600:	learn: 0.9778644	test: 0.9519834	best: 0.9520888 (593)	total: 21m 32s	remaining: 2h 37m 37s
# 700:	learn: 0.9821839	test: 0.9535039	best: 0.9535196 (699)	total: 25m 5s	remaining: 2h 33m 54s
# 800:	learn: 0.9853483	test: 0.9542686	best: 0.9542689 (796)	total: 28m 41s	remaining: 2h 30m 23s
# 900:	learn: 0.9878719	test: 0.9548933	best: 0.9550401 (882)	total: 32m 14s	remaining: 2h 26m 40s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.9550400946
# bestIteration = 882
#
# Shrink model to first 883 iterations.

# %%
evaluate_and_log(model_catboost_full,  X_test, y_test, experiment_name=EXPERIMENT_NAME, run_name="CATboost_Optuna_fullfeatures", hp_search_history=hist_df, hp_search_plots= plot_paths)
# Out:
# [INFO] Logged metrics: {'roc_auc': np.float64(0.9163916125272273), 'pr_auc': np.float64(0.5282549675325425), 'precision': 0.2752046130952381, 'recall': 0.7281003937007874, 'f1': 0.3994330453563715, 'custom_loss': np.float64(1.001566362989806)}
# [INFO] Logged SHAP summary plot.
# 2025/12/12 20:06:08 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# [INFO] Evaluation complete and logged.
# {'roc_auc': np.float64(0.9163916125272273),
#  'pr_auc': np.float64(0.5282549675325425),
#  'precision': 0.2752046130952381,
#  'recall': 0.7281003937007874,
#  'f1': 0.3994330453563715,
#  'custom_loss': np.float64(1.001566362989806)}

# %% [markdown]
# ## 2. Reduced Features

# %%
# ---- 1. Compute SHAP importance for each model ----
df_xgb = get_top_features_shap(model_xgboost_full, X_train, y_train).rename(
    columns={"importance": "importance_xgb"}
)
df_lgbm = get_top_features_shap(model_lgbm_full, X_train, y_train).rename(
    columns={"importance": "importance_lgbm"}
)
df_cat = get_top_features_shap(model_catboost_full, X_train, y_train).rename(
    columns={"importance": "importance_cat"}
)

# ---- 2. Merge all importance tables ----
df = (
    df_xgb.merge(df_lgbm, on="feature")
          .merge(df_cat, on="feature")
)

# ---- 3. Rank features within each model (1 = most important) ----
df["rank_xgb"] = df["importance_xgb"].rank(method="min", ascending=False)
df["rank_lgbm"] = df["importance_lgbm"].rank(method="min", ascending=False)
df["rank_cat"] = df["importance_cat"].rank(method="min", ascending=False)

# ---- 4. Determine the top 30% threshold ----
n_features = len(df)
top_30_cutoff = int(n_features * 0.30)

# ---- 5. Check if a feature appears in top 30% in each model ----
df["in_top_xgb"]  = df["rank_xgb"]  <= top_30_cutoff
df["in_top_lgbm"] = df["rank_lgbm"] <= top_30_cutoff
df["in_top_cat"]  = df["rank_cat"]  <= top_30_cutoff

# ---- 6. Apply the rule: “Top 30% for at least 2 models” ----
df["top_count"] = (
    df["in_top_xgb"].astype(int)
  + df["in_top_lgbm"].astype(int)
  + df["in_top_cat"].astype(int)
)

df_selected = df[df["top_count"] >= 2]  # final selected features

# %%
# ---- 7. Sort by mean importance (optional but nice) ----
df_selected["importance_mean"] = df_selected[["importance_xgb","importance_lgbm","importance_cat"]].mean(axis=1)
df_selected = df_selected.sort_values("importance_mean", ascending=False)

# ---- 8. Save to CSV ----
df.to_csv(f"{data_folder}/feature_importances_shap_fullmodels.csv", index=False)
df_selected.to_csv(f"{data_folder}/selected_features_shap.csv", index=False)

# ---- 9. List of selected feature names ----
selected_feature_list = df_selected["feature"].tolist()

# %%
del df_xgb, df_lgbm, df_cat, df_selected, df

# %%
X_train_reduced = X_train[selected_feature_list]
X_test_reduced = X_test[selected_feature_list]

# %%
X_train_reduced.shape, X_test_reduced.shape
# Out:
# ((472432, 221), (118108, 221))

# %% [markdown]
# ### 2.1. XGBoost

# %%
model_xgboost_reduced, best_params_xgboost_reduced, hist_df, plot_paths = train_xgb_optuna(X_train_reduced, y_train)
# Out:
# [I 2025-12-11 15:00:16,610] A new study created in memory with name: xgboost_aucpr_optimization
# [Optuna XGBoost Tuning]:   0%|          | 0/30 [00:00<?, ?trial/s]
# [I 2025-12-11 15:03:28,039] Trial 0 finished with value: 0.5244601983248465 and parameters: {'learning_rate': 0.017994541804272207, 'max_depth': 7, 'subsample': 0.7337572314337377, 'colsample_bytree': 0.8417596492512893, 'min_child_weight': 0.41951568270366846, 'gamma': 1.8941924359571067}. Best is trial 0 with value: 0.5244601983248465.
# [I 2025-12-11 15:06:21,471] Trial 1 finished with value: 0.48068645567072243 and parameters: {'learning_rate': 0.012252498129860038, 'max_depth': 4, 'subsample': 0.7689312832226267, 'colsample_bytree': 0.7834723911952979, 'min_child_weight': 0.0012403217423212734, 'gamma': 0.3563880447072021}. Best is trial 0 with value: 0.5244601983248465.
# [I 2025-12-11 15:09:44,129] Trial 2 finished with value: 0.5633477566709145 and parameters: {'learning_rate': 0.024813671267022053, 'max_depth': 7, 'subsample': 0.7708397375547158, 'colsample_bytree': 0.5275431295827882, 'min_child_weight': 0.0028988818485861305, 'gamma': 0.3461782223692256}. Best is trial 2 with value: 0.5633477566709145.
# [I 2025-12-11 15:12:44,591] Trial 3 finished with value: 0.5313082986695591 and parameters: {'learning_rate': 0.02644466144183784, 'max_depth': 5, 'subsample': 0.7455481685700307, 'colsample_bytree': 0.7422456723743971, 'min_child_weight': 0.0011889636194607183, 'gamma': 0.44243328399560133}. Best is trial 2 with value: 0.5633477566709145.
# [I 2025-12-11 15:16:07,416] Trial 4 finished with value: 0.5519539275601805 and parameters: {'learning_rate': 0.017131437136834335, 'max_depth': 7, 'subsample': 0.8109560815294785, 'colsample_bytree': 0.5525788984329935, 'min_child_weight': 0.03969977488207764, 'gamma': 4.278419277949925}. Best is trial 2 with value: 0.5633477566709145.
# [I 2025-12-11 15:19:20,899] Trial 5 finished with value: 0.4920209701343035 and parameters: {'learning_rate': 0.01057496376914471, 'max_depth': 6, 'subsample': 0.7393458913531583, 'colsample_bytree': 0.8890236694763637, 'min_child_weight': 0.29481655478010727, 'gamma': 1.2386278583271921}. Best is trial 2 with value: 0.5633477566709145.
# [I 2025-12-11 15:21:59,882] Trial 6 finished with value: 0.4801514406910414 and parameters: {'learning_rate': 0.017354143454128064, 'max_depth': 3, 'subsample': 0.9664545249254781, 'colsample_bytree': 0.5118741610851225, 'min_child_weight': 0.2774849927431492, 'gamma': 3.128533653409215}. Best is trial 2 with value: 0.5633477566709145.
# [I 2025-12-11 15:25:25,353] Trial 7 finished with value: 0.5444433283539251 and parameters: {'learning_rate': 0.018493229718650903, 'max_depth': 7, 'subsample': 0.5299175797438338, 'colsample_bytree': 0.5775248171978533, 'min_child_weight': 0.03698596816975458, 'gamma': 3.130760114621407}. Best is trial 2 with value: 0.5633477566709145.
# [I 2025-12-11 15:28:50,126] Trial 8 finished with value: 0.5639660496908995 and parameters: {'learning_rate': 0.025186312798963717, 'max_depth': 7, 'subsample': 0.8722229395707497, 'colsample_bytree': 0.7903347652383905, 'min_child_weight': 0.026349300483451778, 'gamma': 1.2737944343714513}. Best is trial 8 with value: 0.5639660496908995.
# [I 2025-12-11 15:32:03,782] Trial 9 finished with value: 0.5006358940124479 and parameters: {'learning_rate': 0.015823618817129084, 'max_depth': 6, 'subsample': 0.5295069232946406, 'colsample_bytree': 0.9908367240277764, 'min_child_weight': 0.413326150772732, 'gamma': 0.6151795073641214}. Best is trial 8 with value: 0.5639660496908995.
# [I 2025-12-11 15:35:37,455] Trial 10 finished with value: 0.566093539659358 and parameters: {'learning_rate': 0.023255464873640212, 'max_depth': 8, 'subsample': 0.9998705091837662, 'colsample_bytree': 0.6623336669894129, 'min_child_weight': 0.009753580340121073, 'gamma': 1.896175169336658}. Best is trial 10 with value: 0.566093539659358.
# [I 2025-12-11 15:39:06,784] Trial 11 finished with value: 0.579109116820524 and parameters: {'learning_rate': 0.029899390106657563, 'max_depth': 8, 'subsample': 0.9782130596003938, 'colsample_bytree': 0.6616402823996086, 'min_child_weight': 0.010534704780316506, 'gamma': 1.8996545457491134}. Best is trial 11 with value: 0.579109116820524.
# [I 2025-12-11 16:11:31,151] Trial 21 finished with value: 0.5817754273694695 and parameters: {'learning_rate': 0.029852929297199737, 'max_depth': 8, 'subsample': 0.9313235608246717, 'colsample_bytree': 0.6628118634953293, 'min_child_weight': 0.008187715727995192, 'gamma': 2.4230709105648502}. Best is trial 13 with value: 0.5841117049173359.
# [I 2025-12-11 16:15:03,338] Trial 22 finished with value: 0.5778074892612785 and parameters: {'learning_rate': 0.025632746162722098, 'max_depth': 8, 'subsample': 0.9263043301794255, 'colsample_bytree': 0.7164414233900561, 'min_child_weight': 0.006643396613682374, 'gamma': 3.014158101474716}. Best is trial 13 with value: 0.5841117049173359.
# [I 2025-12-11 16:18:20,012] Trial 23 finished with value: 0.5667614985485853 and parameters: {'learning_rate': 0.02823186968337696, 'max_depth': 7, 'subsample': 0.8556480841916511, 'colsample_bytree': 0.6498772591378441, 'min_child_weight': 0.01671428939316878, 'gamma': 2.3330767177576557}. Best is trial 13 with value: 0.5841117049173359.
# [I 2025-12-11 16:21:48,676] Trial 24 finished with value: 0.5818517547745813 and parameters: {'learning_rate': 0.029847819075422423, 'max_depth': 8, 'subsample': 0.9288003838056266, 'colsample_bytree': 0.5745079199392232, 'min_child_weight': 0.006350339551208493, 'gamma': 2.284074019932531}. Best is trial 13 with value: 0.5841117049173359.
# [I 2025-12-11 16:25:19,025] Trial 25 finished with value: 0.5810600998192006 and parameters: {'learning_rate': 0.02702543836888078, 'max_depth': 8, 'subsample': 0.8164101320437414, 'colsample_bytree': 0.5735290173951355, 'min_child_weight': 0.005046707889135003, 'gamma': 3.5203121593138125}. Best is trial 13 with value: 0.5841117049173359.
# [I 2025-12-11 16:28:34,832] Trial 26 finished with value: 0.5588016404873494 and parameters: {'learning_rate': 0.023994676750462074, 'max_depth': 7, 'subsample': 0.9489967565157063, 'colsample_bytree': 0.561608952597356, 'min_child_weight': 0.0021523734627185076, 'gamma': 1.3861331309239358}. Best is trial 13 with value: 0.5841117049173359.
# [I 2025-12-11 16:31:37,830] Trial 27 finished with value: 0.5541499311992627 and parameters: {'learning_rate': 0.02838798729002785, 'max_depth': 6, 'subsample': 0.9008518763937804, 'colsample_bytree': 0.6223283074613922, 'min_child_weight': 0.014348430703080995, 'gamma': 2.795625363549612}. Best is trial 13 with value: 0.5841117049173359.
# [I 2025-12-11 16:35:14,214] Trial 28 finished with value: 0.5682979959749631 and parameters: {'learning_rate': 0.02646118994192513, 'max_depth': 8, 'subsample': 0.5827076252065817, 'colsample_bytree': 0.7513702208449115, 'min_child_weight': 0.0018948294530156144, 'gamma': 2.3109133597820257}. Best is trial 13 with value: 0.5841117049173359.
# [I 2025-12-11 16:38:35,880] Trial 29 finished with value: 0.5564727663118617 and parameters: {'learning_rate': 0.028845741493361575, 'max_depth': 7, 'subsample': 0.6940584867820965, 'colsample_bytree': 0.8601084094615173, 'min_child_weight': 0.07002289237438891, 'gamma': 1.5528226273199226}. Best is trial 13 with value: 0.5841117049173359.
# [INFO] Best XGBoost params: {'learning_rate': 0.02997644798218643, 'max_depth': 8, 'subsample': 0.9071771096154924, 'colsample_bytree': 0.651104590726605, 'min_child_weight': 0.007770956127743196, 'gamma': 2.8226394772597523}
# [0]	validation_0-aucpr:0.32120
# [100]	validation_0-aucpr:0.55662
# [200]	validation_0-aucpr:0.59386
# [300]	validation_0-aucpr:0.61023
# [400]	validation_0-aucpr:0.62326
# [500]	validation_0-aucpr:0.63135
# [600]	validation_0-aucpr:0.63731
# [700]	validation_0-aucpr:0.64283
# [800]	validation_0-aucpr:0.64550
# [900]	validation_0-aucpr:0.64896
# [1000]	validation_0-aucpr:0.64942
# [1100]	validation_0-aucpr:0.65250
# [1200]	validation_0-aucpr:0.65463
# [1300]	validation_0-aucpr:0.65691
# [1400]	validation_0-aucpr:0.65816
# [1500]	validation_0-aucpr:0.66057
# [1600]	validation_0-aucpr:0.66260
# [1700]	validation_0-aucpr:0.66406
# [1800]	validation_0-aucpr:0.66533
# [1900]	validation_0-aucpr:0.66765
# [2000]	validation_0-aucpr:0.66857
# [2100]	validation_0-aucpr:0.66955
# [2200]	validation_0-aucpr:0.67014
# [2300]	validation_0-aucpr:0.67044
# [2400]	validation_0-aucpr:0.67082
# [2500]	validation_0-aucpr:0.67127
# [2600]	validation_0-aucpr:0.67163
# [2700]	validation_0-aucpr:0.67182
# [2800]	validation_0-aucpr:0.67189
# [2900]	validation_0-aucpr:0.67195
# [3000]	validation_0-aucpr:0.67216
# [3100]	validation_0-aucpr:0.67223
# [3200]	validation_0-aucpr:0.67247
# [3300]	validation_0-aucpr:0.67269
# [3400]	validation_0-aucpr:0.67282
# [3500]	validation_0-aucpr:0.67295
# [3600]	validation_0-aucpr:0.67304
# [3700]	validation_0-aucpr:0.67306
# [3800]	validation_0-aucpr:0.67302
# [3847]	validation_0-aucpr:0.67302
# [INFO] Logged metrics: {'roc_auc': np.float64(0.8857356965863707), 'pr_auc': np.float64(0.5368939873917031), 'precision': 0.7011115685467271, 'recall': 0.41904527559055116, 'f1': 0.5245649160634529, 'custom_loss': np.float64(2.0051647644528736)}
# [INFO] Logged SHAP summary plot.
# 2025/12/11 16:50:07 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# [INFO] Evaluation complete and logged.
# {'roc_auc': np.float64(0.8857356965863707),
#  'pr_auc': np.float64(0.5368939873917031),
#  'precision': 0.7011115685467271,
#  'recall': 0.41904527559055116,
#  'f1': 0.5245649160634529,
#  'custom_loss': np.float64(2.0051647644528736)}

# %%
evaluate_and_log(model_xgboost_reduced, X_test_reduced, y_test, experiment_name=EXPERIMENT_NAME, run_name="XGBoost_Optuna_Reduced", hp_search_history=hist_df, hp_search_plots= plot_paths)
evaluate_and_log(model_xgboost_reduced, X_test_reduced, y_test, experiment_name=EXPERIMENT_NAME, run_name="XGBoost_Optuna_Reduced", hp_search_history=hist_df, hp_search_plots= plot_paths, prediction_threshold=0.10)
evaluate_and_log(model_xgboost_reduced, X_test_reduced, y_test, experiment_name=EXPERIMENT_NAME, run_name="XGBoost_Optuna_Reduced", hp_search_history=hist_df, hp_search_plots= plot_paths, prediction_threshold=0.02)
# Out:
# [INFO] Logged metrics: {'roc_auc': np.float64(0.8857356965863707), 'pr_auc': np.float64(0.5368939873917031), 'precision': 0.7011115685467271, 'recall': 0.41904527559055116, 'f1': 0.5245649160634529, 'custom_loss': np.float64(2.0051647644528736)}
# [INFO] Logged SHAP summary plot.
# 2025/12/12 20:06:35 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# [INFO] Evaluation complete and logged.
# [INFO] Logged metrics: {'roc_auc': np.float64(0.8857356965863707), 'pr_auc': np.float64(0.5368939873917031), 'precision': 0.374085033483881, 'recall': 0.5910433070866141, 'f1': 0.4581783500238436, 'custom_loss': np.float64(1.4412148203339317)}
# [INFO] Logged SHAP summary plot.
# 2025/12/12 20:07:05 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# [INFO] Evaluation complete and logged.
# [INFO] Logged metrics: {'roc_auc': np.float64(0.8857356965863707), 'pr_auc': np.float64(0.5368939873917031), 'precision': 0.18553921568627452, 'recall': 0.7450787401574803, 'f1': 0.29709576138147564, 'custom_loss': np.float64(0.9897043384021404)}
# [INFO] Logged SHAP summary plot.
# 2025/12/12 20:07:32 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# [INFO] Evaluation complete and logged.
# {'roc_auc': np.float64(0.8857356965863707),
#  'pr_auc': np.float64(0.5368939873917031),
#  'precision': 0.18553921568627452,
#  'recall': 0.7450787401574803,
#  'f1': 0.29709576138147564,
#  'custom_loss': np.float64(0.9897043384021404)}

# %% [markdown]
# ### 2.2. LightGBM

# %%
model_lgmb_reduced, best_params_lgmb_reduced, hist_df, plot_paths = train_lgbm_optuna(X_train_reduced, y_train)
# Out:
# [I 2025-12-11 16:50:07,622] A new study created in memory with name: lgbm_aucpr_optimization
# [Optuna LightGBM Tuning]:   0%|          | 0/30 [00:00<?, ?trial/s]
# [I 2025-12-11 16:51:03,669] Trial 0 finished with value: 0.5634378125206297 and parameters: {'num_leaves': 264, 'max_depth': 16, 'learning_rate': 0.018293192691062665, 'min_child_samples': 30, 'reg_alpha': 0.48079858062459807, 'reg_lambda': 0.26484858878890344, 'colsample_bytree': 0.9232861666339274, 'subsample': 0.9422738362625773}. Best is trial 0 with value: 0.5634378125206297.
# [I 2025-12-11 16:52:36,820] Trial 1 finished with value: 0.5991882894882278 and parameters: {'num_leaves': 332, 'max_depth': 19, 'learning_rate': 0.027520189729079186, 'min_child_samples': 17, 'reg_alpha': 0.46525859511456985, 'reg_lambda': 0.19942834493664757, 'colsample_bytree': 0.9874646372937979, 'subsample': 0.9001351298079069}. Best is trial 1 with value: 0.5991882894882278.
# [I 2025-12-11 16:53:26,954] Trial 2 finished with value: 0.5470175631074912 and parameters: {'num_leaves': 189, 'max_depth': 14, 'learning_rate': 0.0205651128068471, 'min_child_samples': 37, 'reg_alpha': 0.35912106922397735, 'reg_lambda': 0.3385650559754896, 'colsample_bytree': 0.9642486471979158, 'subsample': 0.9421881155839729}. Best is trial 1 with value: 0.5991882894882278.
# [I 2025-12-11 16:54:17,109] Trial 3 finished with value: 0.5397748788272795 and parameters: {'num_leaves': 156, 'max_depth': 11, 'learning_rate': 0.021814071668323196, 'min_child_samples': 86, 'reg_alpha': 0.13677684081328306, 'reg_lambda': 0.19863922861561562, 'colsample_bytree': 0.9359602339267425, 'subsample': 0.9888345329115994}. Best is trial 1 with value: 0.5991882894882278.
# [I 2025-12-11 16:57:28,952] Trial 4 finished with value: 0.6387260411845758 and parameters: {'num_leaves': 476, 'max_depth': 16, 'learning_rate': 0.010877056580906526, 'min_child_samples': 46, 'reg_alpha': 0.025947849954865987, 'reg_lambda': 0.4610061076043692, 'colsample_bytree': 0.9735777330204797, 'subsample': 0.8022789146721779}. Best is trial 4 with value: 0.6387260411845758.
# [I 2025-12-11 17:32:49,289] Trial 21 finished with value: 0.6616555475936755 and parameters: {'num_leaves': 511, 'max_depth': 19, 'learning_rate': 0.01637900290429961, 'min_child_samples': 100, 'reg_alpha': 0.2773391464321868, 'reg_lambda': 0.0020235875920862397, 'colsample_bytree': 0.842071408956967, 'subsample': 0.8155984584130539}. Best is trial 21 with value: 0.6616555475936755.
# [I 2025-12-11 17:35:41,424] Trial 22 finished with value: 0.6605986707919693 and parameters: {'num_leaves': 507, 'max_depth': 19, 'learning_rate': 0.017257716810943714, 'min_child_samples': 100, 'reg_alpha': 0.2930990240107273, 'reg_lambda': 0.0037510464006673266, 'colsample_bytree': 0.8415093933637257, 'subsample': 0.8285313059373932}. Best is trial 21 with value: 0.6616555475936755.
# [I 2025-12-11 17:38:24,610] Trial 23 finished with value: 0.6567579743493607 and parameters: {'num_leaves': 510, 'max_depth': 17, 'learning_rate': 0.01674246338042828, 'min_child_samples': 91, 'reg_alpha': 0.19571587346617197, 'reg_lambda': 0.001923577204716892, 'colsample_bytree': 0.8002276868056518, 'subsample': 0.8382524492041317}. Best is trial 21 with value: 0.6616555475936755.
# [I 2025-12-11 17:41:13,041] Trial 24 finished with value: 0.6624979074864095 and parameters: {'num_leaves': 508, 'max_depth': 19, 'learning_rate': 0.019454075552920863, 'min_child_samples': 92, 'reg_alpha': 0.4092744648236445, 'reg_lambda': 0.05973388416757987, 'colsample_bytree': 0.8302640766705726, 'subsample': 0.8645191927839543}. Best is trial 24 with value: 0.6624979074864095.
# [I 2025-12-11 17:43:48,067] Trial 25 finished with value: 0.6623242999908103 and parameters: {'num_leaves': 510, 'max_depth': 18, 'learning_rate': 0.020654753515685804, 'min_child_samples': 100, 'reg_alpha': 0.3978853490190254, 'reg_lambda': 0.07222644764250417, 'colsample_bytree': 0.828932686285185, 'subsample': 0.8636226349814814}. Best is trial 24 with value: 0.6624979074864095.
# [I 2025-12-11 17:46:08,411] Trial 26 finished with value: 0.6561266705376344 and parameters: {'num_leaves': 481, 'max_depth': 16, 'learning_rate': 0.02488625561593918, 'min_child_samples': 91, 'reg_alpha': 0.41257075744680016, 'reg_lambda': 0.06366224097277189, 'colsample_bytree': 0.8177197286379218, 'subsample': 0.8659707625331725}. Best is trial 24 with value: 0.6624979074864095.
# [I 2025-12-11 17:47:50,561] Trial 27 finished with value: 0.6204059150055868 and parameters: {'num_leaves': 392, 'max_depth': 18, 'learning_rate': 0.020476233702637476, 'min_child_samples': 87, 'reg_alpha': 0.4252653674047473, 'reg_lambda': 0.07458157022936192, 'colsample_bytree': 0.8156495165589447, 'subsample': 0.921803538333705}. Best is trial 24 with value: 0.6624979074864095.
# [I 2025-12-11 17:50:18,243] Trial 28 finished with value: 0.655730903795333 and parameters: {'num_leaves': 474, 'max_depth': 17, 'learning_rate': 0.022080818164826464, 'min_child_samples': 95, 'reg_alpha': 0.376889842950198, 'reg_lambda': 0.14852467089451038, 'colsample_bytree': 0.8294877096688834, 'subsample': 0.8795968147906904}. Best is trial 24 with value: 0.6624979074864095.
# [I 2025-12-11 17:50:59,435] Trial 29 finished with value: 0.5484669641176999 and parameters: {'num_leaves': 247, 'max_depth': 10, 'learning_rate': 0.019101518257245164, 'min_child_samples': 76, 'reg_alpha': 0.4953445362955816, 'reg_lambda': 0.2275886375429434, 'colsample_bytree': 0.8405735169157311, 'subsample': 0.9772570871958803}. Best is trial 24 with value: 0.6624979074864095.
# [INFO] Best LightGBM params: {'num_leaves': 508, 'max_depth': 19, 'learning_rate': 0.019454075552920863, 'min_child_samples': 92, 'reg_alpha': 0.4092744648236445, 'reg_lambda': 0.05973388416757987, 'colsample_bytree': 0.8302640766705726, 'subsample': 0.8645191927839543}
# [50]	valid_0's binary_logloss: 0.121277
# [100]	valid_0's binary_logloss: 0.116532
# [150]	valid_0's binary_logloss: 0.109386
# [200]	valid_0's binary_logloss: 0.102873
# [250]	valid_0's binary_logloss: 0.0981379
# [300]	valid_0's binary_logloss: 0.0941949
# [350]	valid_0's binary_logloss: 0.0897915
# [400]	valid_0's binary_logloss: 0.0856726
# [450]	valid_0's binary_logloss: 0.0822549
# [500]	valid_0's binary_logloss: 0.0801475
# [550]	valid_0's binary_logloss: 0.0786734
# [600]	valid_0's binary_logloss: 0.0779737
# [650]	valid_0's binary_logloss: 0.0779971
# [700]	valid_0's binary_logloss: 0.0784638

# %%
evaluate_and_log(model_lgmb_reduced, X_test_reduced, y_test, experiment_name=EXPERIMENT_NAME, run_name="LGBM_Optuna_Reduced", hp_search_history=hist_df, hp_search_plots= plot_paths)
evaluate_and_log(model_lgmb_reduced, X_test_reduced, y_test, experiment_name=EXPERIMENT_NAME, run_name="LGBM_Optuna_Reduced", hp_search_history=hist_df, hp_search_plots= plot_paths, prediction_threshold=0.1)
evaluate_and_log(model_lgmb_reduced, X_test_reduced, y_test, experiment_name=EXPERIMENT_NAME, run_name="LGBM_Optuna_Reduced", hp_search_history=hist_df, hp_search_plots= plot_paths, prediction_threshold=0.02)
# Out:
# [INFO] Logged metrics: {'roc_auc': np.float64(0.9105656023390061), 'pr_auc': np.float64(0.5839596356146002), 'precision': 0.6734492943879226, 'recall': 0.5049212598425197, 'f1': 0.5771340177190268, 'custom_loss': np.float64(1.7119500795881735)}
# [INFO] Logged SHAP summary plot.
# 2025/12/12 20:08:49 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# [INFO] Evaluation complete and logged.
# [INFO] Logged metrics: {'roc_auc': np.float64(0.9105656023390061), 'pr_auc': np.float64(0.5839596356146002), 'precision': 0.32843313015417713, 'recall': 0.6761811023622047, 'f1': 0.4421205051886413, 'custom_loss': np.float64(1.1618095302604396)}
# [INFO] Logged SHAP summary plot.
# 2025/12/12 20:10:07 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# [INFO] Evaluation complete and logged.
# [INFO] Logged metrics: {'roc_auc': np.float64(0.9105656023390061), 'pr_auc': np.float64(0.5839596356146002), 'precision': 0.14773780622379165, 'recall': 0.8235728346456693, 'f1': 0.25053332834312664, 'custom_loss': np.float64(0.7705489890608596)}
# [INFO] Logged SHAP summary plot.
# 2025/12/12 20:11:25 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# [INFO] Evaluation complete and logged.
# {'roc_auc': np.float64(0.9105656023390061),
#  'pr_auc': np.float64(0.5839596356146002),
#  'precision': 0.14773780622379165,
#  'recall': 0.8235728346456693,
#  'f1': 0.25053332834312664,
#  'custom_loss': np.float64(0.7705489890608596)}

# %% [markdown]
# ### 2.3. CatBoost

# %%
model_catoost_reduced, best_params_catoost_reduced, hist_df, plot_paths = train_catboost_optuna(X_train_reduced, y_train)
# Out:
# [I 2025-12-12 09:20:56,825] A new study created in memory with name: catboost_aucpr_optimization
# [Optuna CatBoost Tuning]:   0%|          | 0/30 [00:00<?, ?trial/s]
# [I 
# [I 2025-12-12 11:03:24,002] Trial 12 finished with value: 0.5834865286024054 and parameters: {'learning_rate': 0.029941763415569072, 'depth': 8, 'l2_leaf_reg': 3.624977955604138, 'subsample': 0.997877946170313, 'border_count': 113}. Best is trial 12 with value: 0.5834865286024054.
# [I 2025-12-12 11:15:22,841] Trial 13 finished with value: 0.5805218698559583 and parameters: {'learning_rate': 0.02999351819161193, 'depth': 8, 'l2_leaf_reg': 2.871030675755614, 'subsample': 0.9797019575734744, 'border_count': 121}. Best is trial 12 with value: 0.5834865286024054.
# [I 2025-12-12 11:25:31,324] Trial 14 finished with value: 0.5694066861529555 and parameters: {'learning_rate': 0.029657378813391866, 'depth': 7, 'l2_leaf_reg': 2.670199120972366, 'subsample': 0.9263283888133188, 'border_count': 125}. Best is trial 12 with value: 0.5834865286024054.
# [I 2025-12-12 11:35:42,832] Trial 15 finished with value: 0.5199622187096254 and parameters: {'learning_rate': 0.010994383667409978, 'depth': 7, 'l2_leaf_reg': 6.055056715541406, 'subsample': 0.9347193929674623, 'border_count': 127}. Best is trial 12 with value: 0.5834865286024054.
# [I 2025-12-12 11:47:41,222] Trial 16 finished with value: 0.572766640019947 and parameters: {'learning_rate': 0.02338004377665996, 'depth': 8, 'l2_leaf_reg': 2.7478058807536225, 'subsample': 0.9996155970152008, 'border_count': 113}. Best is trial 12 with value: 0.5834865286024054.
# [I 2025-12-12 11:57:38,202] Trial 17 finished with value: 0.562487638241958 and parameters: {'learning_rate': 0.028278630468662153, 'depth': 7, 'l2_leaf_reg': 2.114893972127198, 'subsample': 0.8757970528376424, 'border_count': 116}. Best is trial 12 with value: 0.5834865286024054.
# [I 2025-12-12 12:09:25,288] Trial 18 finished with value: 0.5801330195144213 and parameters: {'learning_rate': 0.027756043092066342, 'depth': 8, 'l2_leaf_reg': 3.5167832079020176, 'subsample': 0.9483597199220678, 'border_count': 108}. Best is trial 12 with value: 0.5834865286024054.
# [I 2025-12-12 12:17:58,528] Trial 19 finished with value: 0.5448737232924876 and parameters: {'learning_rate': 0.023087715722656284, 'depth': 6, 'l2_leaf_reg': 5.211231786082376, 'subsample': 0.8883639273959559, 'border_count': 96}. Best is trial 12 with value: 0.5834865286024054.
# [I 2025-12-12 12:28:33,805] Trial 20 finished with value: 0.5741087262966946 and parameters: {'learning_rate': 0.027978958484483982, 'depth': 8, 'l2_leaf_reg': 7.280711471384393, 'subsample': 0.6405104453160331, 'border_count': 80}. Best is trial 12 with value: 0.5834865286024054.
# [I 2025-12-12 12:40:21,866] Trial 21 finished with value: 0.5820226885661134 and parameters: {'learning_rate': 0.02813562826897558, 'depth': 8, 'l2_leaf_reg': 3.5166712349704907, 'subsample': 0.955596668319534, 'border_count': 110}. Best is trial 12 with value: 0.5834865286024054.
# [I 2025-12-12 12:50:37,882] Trial 22 finished with value: 0.569069099682183 and parameters: {'learning_rate': 0.02937471529429024, 'depth': 7, 'l2_leaf_reg': 3.449476070089773, 'subsample': 0.974092771745147, 'border_count': 117}. Best is trial 12 with value: 0.5834865286024054.
# [I 2025-12-12 13:02:25,288] Trial 23 finished with value: 0.578023892748801 and parameters: {'learning_rate': 0.026846238482700433, 'depth': 8, 'l2_leaf_reg': 1.9287105044317046, 'subsample': 0.9570141662000995, 'border_count': 103}. Best is trial 12 with value: 0.5834865286024054.
# [I 2025-12-12 13:12:27,676] Trial 24 finished with value: 0.5615940004039389 and parameters: {'learning_rate': 0.024695736310211047, 'depth': 7, 'l2_leaf_reg': 3.4215099356696577, 'subsample': 0.8916186189616809, 'border_count': 121}. Best is trial 12 with value: 0.5834865286024054.
# [I 2025-12-12 13:23:49,133] Trial 25 finished with value: 0.58017220398469 and parameters: {'learning_rate': 0.028592134677707985, 'depth': 8, 'l2_leaf_reg': 2.0083671427016854, 'subsample': 0.8397525016601534, 'border_count': 89}. Best is trial 12 with value: 0.5834865286024054.
# [I 2025-12-12 13:34:00,303] Trial 26 finished with value: 0.5687011291175647 and parameters: {'learning_rate': 0.029858722577893345, 'depth': 7, 'l2_leaf_reg': 4.489662009457176, 'subsample': 0.9575996727142003, 'border_count': 107}. Best is trial 12 with value: 0.5834865286024054.
# [I 2025-12-12 13:45:51,916] Trial 27 finished with value: 0.5737362122759883 and parameters: {'learning_rate': 0.026986760641600913, 'depth': 8, 'l2_leaf_reg': 2.9230986828423458, 'subsample': 0.9082053868705147, 'border_count': 111}. Best is trial 12 with value: 0.5834865286024054.
# [I 2025-12-12 13:54:53,152] Trial 28 finished with value: 0.5460162807020543 and parameters: {'learning_rate': 0.024174828663181394, 'depth': 6, 'l2_leaf_reg': 5.814250449751501, 'subsample': 0.9972412221789835, 'border_count': 74}. Best is trial 12 with value: 0.5834865286024054.
# [I 2025-12-12 14:06:33,542] Trial 29 finished with value: 0.5660727263881197 and parameters: {'learning_rate': 0.020358882958379333, 'depth': 8, 'l2_leaf_reg': 6.706886748748325, 'subsample': 0.8328594217120922, 'border_count': 128}. Best is trial 12 with value: 0.5834865286024054.
# [INFO] Best CatBoost params: {'learning_rate': 0.029941763415569072, 'depth': 8, 'l2_leaf_reg': 3.624977955604138, 'subsample': 0.997877946170313, 'border_count': 113}
# 0:	learn: 0.8638560	test: 0.8793277	best: 0.8793277 (0)	total: 1.06s	remaining: 1h 28m 3s
# 100:	learn: 0.9356353	test: 0.9279100	best: 0.9279100 (100)	total: 1m 50s	remaining: 1h 29m 39s
# 200:	learn: 0.9545904	test: 0.9391483	best: 0.9392168 (199)	total: 3m 40s	remaining: 1h 27m 39s
# 300:	learn: 0.9653813	test: 0.9451395	best: 0.9451395 (300)	total: 5m 28s	remaining: 1h 25m 21s
# 400:	learn: 0.9730892	test: 0.9485074	best: 0.9485074 (400)	total: 7m 16s	remaining: 1h 23m 22s
# 500:	learn: 0.9790718	test: 0.9509152	best: 0.9509160 (499)	total: 9m 4s	remaining: 1h 21m 31s
# 600:	learn: 0.9838914	test: 0.9533165	best: 0.9533165 (600)	total: 10m 53s	remaining: 1h 19m 41s
# 700:	learn: 0.9873886	test: 0.9542882	best: 0.9544693 (675)	total: 12m 41s	remaining: 1h 17m 50s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.9544693326
# bestIteration = 675
#
# Shrink model to first 676 iterations.
# [INFO] Logged metrics: {'roc_auc': np.float64(0.912118695355391), 'pr_auc': np.float64(0.5265946509511543), 'precision': 0.2813680844879372, 'recall': 0.7145669291338582, 'f1': 0.40375391032325336, 'custom_loss': np.float64(1.0449503843939445)}
# [INFO] Logged SHAP summary plot.
# 2025/12/12 14:21:05 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# [INFO] Evaluation complete and logged.
# {'roc_auc': np.float64(0.912118695355391),
#  'pr_auc': np.float64(0.5265946509511543),
#  'precision': 0.2813680844879372,
#  'recall': 0.7145669291338582,
#  'f1': 0.40375391032325336,
#  'custom_loss': np.float64(1.0449503843939445)}

# %%
evaluate_and_log(model_catoost_reduced, X_test_reduced, y_test, experiment_name=EXPERIMENT_NAME, run_name="CATBoost_Optuna_Reduced", hp_search_history=hist_df, hp_search_plots= plot_paths)
evaluate_and_log(model_catoost_reduced, X_test_reduced, y_test, experiment_name=EXPERIMENT_NAME, run_name="CATBoost_Optuna_Reduced", hp_search_history=hist_df, hp_search_plots= plot_paths, prediction_threshold=0.1)
evaluate_and_log(model_catoost_reduced, X_test_reduced, y_test, experiment_name=EXPERIMENT_NAME, run_name="CATBoost_Optuna_Reduced", hp_search_history=hist_df, hp_search_plots= plot_paths, prediction_threshold=0.02)
# Out:
# [INFO] Logged metrics: {'roc_auc': np.float64(0.912118695355391), 'pr_auc': np.float64(0.5265946509511543), 'precision': 0.2813680844879372, 'recall': 0.7145669291338582, 'f1': 0.40375391032325336, 'custom_loss': np.float64(1.0449503843939445)}
# [INFO] Logged SHAP summary plot.
# 2025/12/12 20:11:44 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# [INFO] Evaluation complete and logged.
# [INFO] Logged metrics: {'roc_auc': np.float64(0.912118695355391), 'pr_auc': np.float64(0.5265946509511543), 'precision': 0.06814946619217081, 'recall': 0.9424212598425197, 'f1': 0.12710739413248373, 'custom_loss': np.float64(0.6415314796626816)}
# [INFO] Logged SHAP summary plot.
# 2025/12/12 20:12:03 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# [INFO] Evaluation complete and logged.
# [INFO] Logged metrics: {'roc_auc': np.float64(0.912118695355391), 'pr_auc': np.float64(0.5265946509511543), 'precision': 0.03768666443227945, 'recall': 0.9960629921259843, 'f1': 0.07262549786501131, 'custom_loss': np.float64(0.888712026281031)}
# [INFO] Logged SHAP summary plot.
# 2025/12/12 20:12:20 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# [INFO] Evaluation complete and logged.
# {'roc_auc': np.float64(0.912118695355391),
#  'pr_auc': np.float64(0.5265946509511543),
#  'precision': 0.03768666443227945,
#  'recall': 0.9960629921259843,
#  'f1': 0.07262549786501131,
#  'custom_loss': np.float64(0.888712026281031)}

# %% [markdown]
# ## 3. Ensemble

# %%
# Build train meta features
X_meta = pd.DataFrame(np.column_stack([m.predict_proba(X_train_reduced)[:, 1] for m in [model_xgboost_reduced, model_lgmb_reduced, model_catoost_reduced]]))
X_meta_val = pd.DataFrame(np.column_stack([m.predict_proba(X_valid_reduced)[:, 1] for m in  [model_xgboost_reduced, model_lgmb_reduced, model_catoost_reduced]]))

# %% [markdown]
# ### 3.1. Logistic

# %%
ensemble, best_params_log, hist_df, plot_paths = train_ensemble(
    X_meta, y_train, X_meta_val, y_valid
)
# Out:
# [I 2025-12-07 01:53:06,192] A new study created in memory with name: ensemble_meta_learner_pr_auc_optimization
# [INFO] Generating meta-features...
# [INFO] Optimizing meta-learner with Optuna...
# [Optuna Ensemble Meta-Learner Tuning]:   0%|          | 0/30 [00:00<?, ?trial/s]
# [I 2025-12-07 01:53:07,195] Trial 0 finished with value: 1.0 and parameters: {'C': 0.046716728199023554, 'class_weight': 'balanced', 'solver': 'liblinear', 'penalty_liblinear': 'l2'}. Best is trial 0 with value: 1.0.
# [I 2025-12-07 01:53:08,054] Trial 1 finished with value: 1.0 and parameters: {'C': 4.337626067012835, 'class_weight': None, 'solver': 'lbfgs', 'penalty_lbfgs': 'l2'}. Best is trial 0 with value: 1.0.
# [I 2025-12-07 01:53:10,020] Trial 2 finished with value: 0.9999999702398065 and parameters: {'C': 0.0013868610323151099, 'class_weight': None, 'solver': 'sag', 'penalty_sag': 'l2'}. Best is trial 0 with value: 1.0.
# [I 2025-12-07 01:53:11,438] Trial 3 finished with value: 1.0 and parameters: {'C': 0.07981434458108105, 'class_weight': 'balanced', 'solver': 'newton-cg', 'penalty_newton-cg': 'l2'}. Best is trial 0 with value: 1.0.
# [I 2025-12-07 01:53:12,957] Trial 4 finished with value: 1.0 and parameters: {'C': 0.569471423184438, 'class_weight': 'balanced', 'solver': 'liblinear', 'penalty_liblinear': 'l1'}. Best is trial 0 with value: 1.0.
# [I 2025-12-07 01:53:14,715] Trial 5 finished with value: 1.0 and parameters: {'C': 0.2944665598940547, 'class_weight': None, 'solver': 'liblinear', 'penalty_liblinear': 'l1'}. Best is trial 0 with value: 1.0.
# [I 2025-12-07 01:53:15,850] Trial 6 finished with value: 1.0 and parameters: {'C': 0.19823549303393048, 'class_weight': 'balanced', 'solver': 'liblinear', 'penalty_liblinear': 'l2'}. Best is trial 0 with value: 1.0.
# [I 2025-12-07 01:53:18,084] Trial 7 finished with value: 1.0 and parameters: {'C': 0.0016740320739062537, 'class_weight': None, 'solver': 'liblinear', 'penalty_liblinear': 'l1'}. Best is trial 0 with value: 1.0.
# [I 2025-12-07 01:53:27,979] Trial 8 finished with value: 1.0 and parameters: {'C': 1.3897278438289766, 'class_weight': 'balanced', 'solver': 'saga', 'penalty_saga': 'elasticnet', 'l1_ratio': 0.32014474669443227}. Best is trial 0 with value: 1.0.
# [I 2025-12-07 01:53:28,902] Trial 9 finished with value: 1.0 and parameters: {'C': 28.28448217304735, 'class_weight': 'balanced', 'solver': 'lbfgs', 'penalty_lbfgs': 'l2'}. Best is trial 0 with value: 1.0.
# [I 2025-12-07 01:53:37,904] Trial 10 finished with value: 1.0 and parameters: {'C': 0.008980585193969257, 'class_weight': 'balanced', 'solver': 'sag', 'penalty_sag': None}. Best is trial 0 with value: 1.0.
# [I 2025-12-07 01:53:38,690] Trial 11 finished with value: 1.0 and parameters: {'C': 18.63619507187001, 'class_weight': None, 'solver': 'lbfgs', 'penalty_lbfgs': 'l2'}. Best is trial 0 with value: 1.0.
# [I 2025-12-07 01:53:39,472] Trial 12 finished with value: 1.0 and parameters: {'C': 4.027090061087179, 'class_weight': None, 'solver': 'lbfgs', 'penalty_lbfgs': None}. Best is trial 0 with value: 1.0.
# [I 2025-12-07 01:53:42,478] Trial 13 finished with value: 0.35919102290558924 and parameters: {'C': 0.00013041454825601025, 'class_weight': None, 'solver': 'saga', 'penalty_saga': 'l1'}. Best is trial 0 with value: 1.0.
# [I 2025-12-07 01:53:43,894] Trial 14 finished with value: 1.0 and parameters: {'C': 0.04675185192316339, 'class_weight': 'balanced', 'solver': 'newton-cg', 'penalty_newton-cg': None}. Best is trial 0 with value: 1.0.
# [I 2025-12-07 01:53:44,678] Trial 15 finished with value: 1.0 and parameters: {'C': 6.1509913019950675, 'class_weight': None, 'solver': 'lbfgs', 'penalty_lbfgs': 'l2'}. Best is trial 0 with value: 1.0.
# [I 2025-12-07 01:53:45,462] Trial 16 finished with value: 1.0 and parameters: {'C': 74.92635735005578, 'class_weight': None, 'solver': 'lbfgs', 'penalty_lbfgs': None}. Best is trial 0 with value: 1.0.
# [I 2025-12-07 01:53:46,507] Trial 17 finished with value: 0.9999999702398065 and parameters: {'C': 0.013839770336826616, 'class_weight': 'balanced', 'solver': 'liblinear', 'penalty_liblinear': 'l2'}. Best is trial 0 with value: 1.0.
# [I 2025-12-07 01:53:55,515] Trial 18 finished with value: 1.0 and parameters: {'C': 1.7615746273793396, 'class_weight': 'balanced', 'solver': 'sag', 'penalty_sag': None}. Best is trial 0 with value: 1.0.
# [I 2025-12-07 01:53:56,841] Trial 19 finished with value: 1.0 and parameters: {'C': 0.013182128081942968, 'class_weight': None, 'solver': 'newton-cg', 'penalty_newton-cg': None}. Best is trial 0 with value: 1.0.
# [I 2025-12-07 01:54:28,184] Trial 20 finished with value: 0.9999999702398065 and parameters: {'C': 0.0016346343773153244, 'class_weight': 'balanced', 'solver': 'saga', 'penalty_saga': 'l2'}. Best is trial 0 with value: 1.0.
# [I 2025-12-07 01:54:29,595] Trial 21 finished with value: 0.9999999851167592 and parameters: {'C': 0.06016124432187205, 'class_weight': 'balanced', 'solver': 'newton-cg', 'penalty_newton-cg': 'l2'}. Best is trial 0 with value: 1.0.
# [I 2025-12-07 01:54:31,038] Trial 22 finished with value: 1.0 and parameters: {'C': 0.09658435900009472, 'class_weight': 'balanced', 'solver': 'newton-cg', 'penalty_newton-cg': 'l2'}. Best is trial 0 with value: 1.0.
# [I 2025-12-07 01:54:32,451] Trial 23 finished with value: 1.0 and parameters: {'C': 0.5324072273549084, 'class_weight': 'balanced', 'solver': 'newton-cg', 'penalty_newton-cg': 'l2'}. Best is trial 0 with value: 1.0.
# [I 2025-12-07 01:54:33,845] Trial 24 finished with value: 0.9999999702398065 and parameters: {'C': 0.0262662112753912, 'class_weight': 'balanced', 'solver': 'newton-cg', 'penalty_newton-cg': 'l2'}. Best is trial 0 with value: 1.0.
# [I 2025-12-07 01:54:34,787] Trial 25 finished with value: 1.0 and parameters: {'C': 0.15484975555301086, 'class_weight': 'balanced', 'solver': 'lbfgs', 'penalty_lbfgs': 'l2'}. Best is trial 0 with value: 1.0.
# [I 2025-12-07 01:54:35,717] Trial 26 finished with value: 0.9999999702398065 and parameters: {'C': 0.0030165769986043385, 'class_weight': None, 'solver': 'liblinear', 'penalty_liblinear': 'l2'}. Best is trial 0 with value: 1.0.
# [I 2025-12-07 01:54:36,844] Trial 27 finished with value: 0.9999999702398065 and parameters: {'C': 0.0002729302874722503, 'class_weight': 'balanced', 'solver': 'newton-cg', 'penalty_newton-cg': 'l2'}. Best is trial 0 with value: 1.0.
# [I 2025-12-07 01:54:37,630] Trial 28 finished with value: 1.0 and parameters: {'C': 1.2484639523439098, 'class_weight': None, 'solver': 'lbfgs', 'penalty_lbfgs': 'l2'}. Best is trial 0 with value: 1.0.
# [I 2025-12-07 01:54:39,364] Trial 29 finished with value: 0.9999999702398065 and parameters: {'C': 0.004003804481134856, 'class_weight': None, 'solver': 'sag', 'penalty_sag': 'l2'}. Best is trial 0 with value: 1.0.
# [INFO] Best meta-learner params: {'C': 0.046716728199023554, 'class_weight': 'balanced', 'solver': 'liblinear', 'penalty_liblinear': 'l2'}
# [INFO] Ensemble validation PR-AUC: 0.6603
# [INFO] Ensemble validation ROC-AUC: 0.9385

# %%
evaluate_and_log(ensemble, X_meta_val, y_valid, experiment_name=EXPERIMENT_NAME, run_name="Ensemble_from_best_base_models", hp_search_history=hist_df)
# Out:
# [INFO] Logged metrics: {'roc_auc': np.float64(0.938545198106298), 'pr_auc': np.float64(0.6602538927983681), 'precision': 0.77322206095791, 'recall': 0.5243602362204725, 'f1': 0.6249266862170088, 'custom_loss': np.float64(1.641929420530362)}
# [WARN] SHAP skipped: Model type not yet supported by TreeExplainer: <class 'sklearn.linear_model._logistic.LogisticRegression'>
# 2025/12/07 01:54:46 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# [INFO] Evaluation complete and logged.
# {'roc_auc': np.float64(0.938545198106298),
#  'pr_auc': np.float64(0.6602538927983681),
#  'precision': 0.77322206095791,
#  'recall': 0.5243602362204725,
#  'f1': 0.6249266862170088,
#  'custom_loss': np.float64(1.641929420530362)}

# %% [markdown]
# ## 4. create submission on test

# %%
import mlflow.pyfunc

model = mlflow.pyfunc.load_model("mlruns/306298534761506969/models/m-13e4ef05880a4806b656985753497758/artifacts").get_raw_model()

# %%
expected_features = [
    'C1', 'R_emaildomain', 'C14', 'P_emaildomain', 'id_31', 'uid_D3_mean', 
    'DeviceInfo', 'C13', 'ProductCD_TransactionAmt_rel', 'card1', 
    'uid_M4_freq', 'uid_C13_mean', 'uid_C13_std', 'uid_D2_mean', 
    'uid_C13_rel', 'uid_TransactionAmt_mean', 'card2', 'uid_C11_mean', 
    'uid_C1_mean', 'addr1', 'uid_V_PCA_4_mean', 'uid_D11_mean', 
    'uid_V_PCA_13_mean', 'uid_C2_mean', 'uid_C6_mean', 'C5', 'D3', 
    'uid_D2_std', 'card6', 'C8', 'uid_D11_std', 'M5', 'uid_card2_mean', 
    'uid_C14_mean', 'card6_TransactionAmt_mean', 'uid_dist1_mean', 'C11', 
    'hour_of_day', 'uid_TransactionAmt_std', 'uid_V_PCA_12_mean', 'id_30', 
    'uid_M5_freq', 'uid_card5_mean', 'uid_V_PCA_2_mean', 'uid_V_PCA_9_std', 
    'uid_V_PCA_5_mean', 'uid_V_PCA_11_mean', 'uid_D15_mean', 
    'uid_V_PCA_3_std', 'M4', 'uid_V_PCA_9_mean', 'uid_D10_mean', 
    'uid_M6_freq', 'uid_D5_mean', 'C2', 'uid_V_PCA_13_std', 
    'uid_DecimalPlaces_mean', 'card5', 'uid_V_PCA_4_std', 'D8', 
    'uid_C9_mean', 'uid_C1_std', 'uid_D10_std', 'uid_C14_rel', 'M6', 
    'uid_V_PCA_1_mean', 'D2', 'uid_P_emaildomain_freq', 'uid_C5_mean', 
    'uid_V_PCA_10_mean', 'id_02', 'uid_V_PCA_10_std', 'uid_V_PCA_3_mean', 
    'id_20', 'M3', 'V_PCA_2', 'uid_V_PCA_6_mean', 'uid_V_PCA_11_std', 
    'uid_V_PCA_7_std', 'card4', 'uid_V_PCA_8_mean', 'V_PCA_4', 
    'card6_TransactionAmt_rel', 'V_PCA_9', 'uid_D4_mean', 'uid_C6_std', 
    'C6', 'uid_hour_of_day_TransactionAmt_mean', 'dist1', 
    'TransactionAmt_Scaled', 'uid_V_PCA_5_std', 'uid_V_PCA_1_std', 'D4', 
    'uid_C9_std', 'D15', 'uid_C1_rel', 'day_of_week', 'uid_V_PCA_7_mean', 
    'id_05', 'uid_day_of_week_TransactionAmt_mean', 'uid_D5_std', 
    'uid_D3_std', 'uid_id_02_mean', 'uid_D4_std', 'uid_DecimalPlaces_rel', 
    'uid_V_PCA_12_std', 'uid_V_PCA_2_std', 'uid_C11_std', 'D10', 
    'uid_V_PCA_6_std', 'uid_C6_rel', 'uid_day_of_week_TransactionAmt_rel'
]

df_aligned = test[expected_features]

# %%
train = train[expected_features]

# %%
preds = model.predict_proba(df_aligned)

# %%
test['isFraud']=preds[:,1]

# %%
test[['TransactionID', 'isFraud']].to_csv(data_folder + "submission.csv", index=False)

# %%
test = pd.read_csv(f'test_processed.csv')
