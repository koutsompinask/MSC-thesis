# %% [markdown]
# # Training

# %%
import pandas as pd
import numpy as np
import os
import random

# ignore warnings
import warnings
warnings.filterwarnings('ignore')

import importlib
import train_models_util
import feature_importance
importlib.reload(train_models_util)
importlib.reload(feature_importance)
from train_models_util import (
    train_xgb_optuna, 
    train_catboost_optuna, 
    train_lgbm_optuna,
    train_best_base_models_from_mlflow,
    train_ensemble, 
    train_neural_network_ensemble,
    train_tree_optuna,
    minimize_eval_metric_with_threshold
)
from evaluate_models_util import evaluate_and_log
from feature_importance import select_important_features, get_top_features_shap
from sklearn.model_selection import train_test_split

# set all random seeds for reproducibility
np.random.seed(42)
random.seed(42)
os.environ['PYTHONHASHSEED'] = str(42)

# %%
EXPERIMENT_NAME = "Fraud-detection-custom-thresholds_v2"

# %%
data_folder = 'ieee-fraud-detection-data/processed/'

train = pd.read_csv(f'{data_folder}train_processed.csv')
test = pd.read_csv(f'{data_folder}test_processed.csv')
target = pd.read_csv(f'{data_folder}target.csv')['isFraud']

# %%
cat_cols = np.array(train.select_dtypes(include=['object']).columns)
for c in cat_cols:
    if c in train.columns:
        if train[c].isnull().sum()>0 or test[c].isnull().sum()>0:
            train[c].fillna('missing', inplace=True)
            test[c].fillna('missing', inplace=True)
        train[c] = train[c].astype('category')
        test[c] = test[c].astype('category')

# %% [markdown]
# ## 0. Create tuning, training , validation, and test sets

# %%
# get all fraud samples
fraud_indices = target[target == 1].index

# sample 5× non-fraud, without replacement
non_fraud_indices = target[target == 0].sample(
    n=len(fraud_indices) * 3,
    random_state=42
).index

# build tuning dataset
X_tune = pd.concat([train.loc[fraud_indices], train.loc[non_fraud_indices]], axis=0)
y_tune = pd.concat([target.loc[fraud_indices], target.loc[non_fraud_indices]], axis=0)

# %%
X_train, X_valid, y_train, y_valid = train_test_split(train, target, test_size=0.2, stratify=target, random_state=42)

# %%
X_train.shape, X_valid.shape, X_tune.shape
# Out:
# ((472432, 398), (118108, 398), (82652, 398))

# %%
del train, target, fraud_indices, non_fraud_indices, cat_cols, c
import gc
gc.collect()
# Out:
# 21

# %% [markdown]
# ## 1. Full Features

# %% [markdown]
# ### 1.1. XGBoost

# %%
model_xgboost_full, best_params_xgboost_full, hist_df, plot_paths = train_xgb_optuna(X_train, y_train, X_tune, y_tune, X_valid, y_valid, early_stopping_rounds=10)
# Out:
# [I 2025-11-30 11:52:51,503] A new study created in memory with name: xgboost_aucpr_optimization
# [Optuna XGBoost Tuning]:   0%|          | 0/30 [00:00<?, ?trial/s]
# [I 2025-11-30 11:54:10,902] Trial 0 finished with value: 0.9438730674951549 and parameters: {'learning_rate': 0.19105628024524834, 'max_depth': 11, 'subsample': 0.6656717060834552, 'colsample_bytree': 0.6447858685514625, 'min_child_weight': 0.04822036256991612, 'gamma': 1.346076192732022}. Best is trial 0 with value: 0.9438730674951549.
# [I 2025-11-30 11:57:12,887] Trial 1 finished with value: 0.9483650900704378 and parameters: {'learning_rate': 0.049469965577439115, 'max_depth': 12, 'subsample': 0.7897089283395412, 'colsample_bytree': 0.8860897411723251, 'min_child_weight': 0.013579128280901189, 'gamma': 1.8938526849680586}. Best is trial 1 with value: 0.9483650900704378.
# [I 2025-11-30 11:59:48,272] Trial 2 finished with value: 0.9364268743984301 and parameters: {'learning_rate': 0.025994831802352212, 'max_depth': 10, 'subsample': 0.8869131377110315, 'colsample_bytree': 0.8160569661595771, 'min_child_weight': 0.011656132067452092, 'gamma': 3.8530385006234042}. Best is trial 1 with value: 0.9483650900704378.
# [I 2025-11-30 12:02:01,158] Trial 3 finished with value: 0.9366847962760022 and parameters: {'learning_rate': 0.03649411054363472, 'max_depth': 10, 'subsample': 0.5888669376776159, 'colsample_bytree': 0.5270217527361298, 'min_child_weight': 0.00516802565053699, 'gamma': 3.3323422360054513}. Best is trial 1 with value: 0.9483650900704378.
# [I 2025-11-30 12:08:48,358] Trial 4 finished with value: 0.9429702793162787 and parameters: {'learning_rate': 0.014539027869076756, 'max_depth': 15, 'subsample': 0.7893295694129638, 'colsample_bytree': 0.9331506050722633, 'min_child_weight': 0.03937733709913801, 'gamma': 2.238179377117227}. Best is trial 1 with value: 0.9483650900704378.
# [I 2025-11-30 12:09:54,506] Trial 5 finished with value: 0.9391076939190214 and parameters: {'learning_rate': 0.12848745452969973, 'max_depth': 13, 'subsample': 0.6964943277205831, 'colsample_bytree': 0.6397614129199787, 'min_child_weight': 0.031332296985975595, 'gamma': 4.852470721512544}. Best is trial 1 with value: 0.9483650900704378.
# [I 2025-11-30 12:10:57,255] Trial 6 finished with value: 0.9394199173111568 and parameters: {'learning_rate': 0.17906554750903042, 'max_depth': 14, 'subsample': 0.6060493019324215, 'colsample_bytree': 0.8287149313010814, 'min_child_weight': 0.0020153365706481086, 'gamma': 2.446800863131156}. Best is trial 1 with value: 0.9483650900704378.
# [I 2025-11-30 12:14:22,741] Trial 7 finished with value: 0.9303872760096453 and parameters: {'learning_rate': 0.011913232255246866, 'max_depth': 11, 'subsample': 0.8984667222501138, 'colsample_bytree': 0.6426342834406378, 'min_child_weight': 0.014783091884215394, 'gamma': 4.068597343170655}. Best is trial 1 with value: 0.9483650900704378.
# [I 2025-11-30 12:16:06,498] Trial 8 finished with value: 0.943887738128326 and parameters: {'learning_rate': 0.15762837876792754, 'max_depth': 12, 'subsample': 0.5267341639505883, 'colsample_bytree': 0.5281009891473053, 'min_child_weight': 0.12644762369544987, 'gamma': 0.5421653335522297}. Best is trial 1 with value: 0.9483650900704378.
# [I 2025-11-30 12:17:06,190] Trial 9 finished with value: 0.9457661322423728 and parameters: {'learning_rate': 0.22411929160395128, 'max_depth': 12, 'subsample': 0.938700612930939, 'colsample_bytree': 0.9450375141509162, 'min_child_weight': 0.053777746851429754, 'gamma': 1.1923430864451545}. Best is trial 1 with value: 0.9483650900704378.
# [I 2025-11-30 12:19:06,903] Trial 10 finished with value: 0.9444565582083603 and parameters: {'learning_rate': 0.06902562546320747, 'max_depth': 8, 'subsample': 0.7993495485779065, 'colsample_bytree': 0.9871436507260516, 'min_child_weight': 0.5063199057857953, 'gamma': 0.18517376209639513}. Best is trial 1 with value: 0.9483650900704378.
# [I 2025-11-30 12:21:01,293] Trial 11 finished with value: 0.9482248224304786 and parameters: {'learning_rate': 0.07728759942296357, 'max_depth': 13, 'subsample': 0.9983079002992568, 'colsample_bytree': 0.8995579998305261, 'min_child_weight': 0.2610301381678238, 'gamma': 1.474666645390418}. Best is trial 1 with value: 0.9483650900704378.
# [I 2025-11-30 12:23:07,771] Trial 12 finished with value: 0.9477821232774835 and parameters: {'learning_rate': 0.06557536489301803, 'max_depth': 14, 'subsample': 0.9958663060841142, 'colsample_bytree': 0.8617734719259217, 'min_child_weight': 0.8367790376884816, 'gamma': 1.767231057805629}. Best is trial 1 with value: 0.9483650900704378.
# [I 2025-11-30 12:26:04,868] Trial 13 finished with value: 0.9470759721003118 and parameters: {'learning_rate': 0.04139917501832696, 'max_depth': 13, 'subsample': 0.8278032877817325, 'colsample_bytree': 0.8891466725954852, 'min_child_weight': 0.17590333615946793, 'gamma': 2.985079883724923}. Best is trial 1 with value: 0.9483650900704378.
# [I 2025-11-30 12:27:56,596] Trial 14 finished with value: 0.9500999124509177 and parameters: {'learning_rate': 0.091317103457521, 'max_depth': 13, 'subsample': 0.9938533504935735, 'colsample_bytree': 0.7494433774358047, 'min_child_weight': 0.23384757342694099, 'gamma': 0.9482289325840254}. Best is trial 14 with value: 0.9500999124509177.
# [I 2025-11-30 12:29:51,246] Trial 15 finished with value: 0.9465815789667352 and parameters: {'learning_rate': 0.09843131240996356, 'max_depth': 8, 'subsample': 0.726087062051222, 'colsample_bytree': 0.727512119311831, 'min_child_weight': 0.0020147086304276147, 'gamma': 0.6903139959887565}. Best is trial 14 with value: 0.9500999124509177.
# [I 2025-11-30 12:35:04,172] Trial 16 finished with value: 0.9478356045833353 and parameters: {'learning_rate': 0.022399914745196963, 'max_depth': 15, 'subsample': 0.8698188916684771, 'colsample_bytree': 0.7563910932549505, 'min_child_weight': 0.0069206978692019335, 'gamma': 1.9958455061047844}. Best is trial 14 with value: 0.9500999124509177.
# [I 2025-11-30 12:35:57,186] Trial 17 finished with value: 0.9448071882288206 and parameters: {'learning_rate': 0.29759889477827456, 'max_depth': 10, 'subsample': 0.9238563241930833, 'colsample_bytree': 0.7537283386330302, 'min_child_weight': 0.1424946178197264, 'gamma': 0.9346664584884292}. Best is trial 14 with value: 0.9500999124509177.
# [I 2025-11-30 12:41:17,930] Trial 18 finished with value: 0.9531916499161767 and parameters: {'learning_rate': 0.047977461787374734, 'max_depth': 14, 'subsample': 0.7449890839436284, 'colsample_bytree': 0.70110582598937, 'min_child_weight': 0.0010226677164813366, 'gamma': 0.14922602556210918}. Best is trial 18 with value: 0.9531916499161767.
# [I 2025-11-30 12:45:42,153] Trial 19 finished with value: 0.9520545613659347 and parameters: {'learning_rate': 0.09408421769189337, 'max_depth': 14, 'subsample': 0.6435873327366822, 'colsample_bytree': 0.7028852052742087, 'min_child_weight': 0.001259798604495754, 'gamma': 0.0719644816512621}. Best is trial 18 with value: 0.9531916499161767.
# [I 2025-11-30 12:51:39,785] Trial 20 finished with value: 0.9498402177449137 and parameters: {'learning_rate': 0.03239581549191143, 'max_depth': 14, 'subsample': 0.6439600926070587, 'colsample_bytree': 0.6920707916310119, 'min_child_weight': 0.001150046174400853, 'gamma': 0.05457302134279097}. Best is trial 18 with value: 0.9531916499161767.
# [I 2025-11-30 12:54:23,519] Trial 21 finished with value: 0.9511915535087367 and parameters: {'learning_rate': 0.10587457099644379, 'max_depth': 14, 'subsample': 0.7372027479727685, 'colsample_bytree': 0.6883431572359759, 'min_child_weight': 0.0010498074078152371, 'gamma': 0.3563121492990321}. Best is trial 18 with value: 0.9531916499161767.
# [I 2025-11-30 12:57:07,724] Trial 22 finished with value: 0.9511681658304821 and parameters: {'learning_rate': 0.10296155238016357, 'max_depth': 15, 'subsample': 0.7299611231254242, 'colsample_bytree': 0.5894415487853333, 'min_child_weight': 0.0010198605396302966, 'gamma': 0.38631072815524053}. Best is trial 18 with value: 0.9531916499161767.
# [I 2025-11-30 13:03:16,142] Trial 23 finished with value: 0.9526730822404827 and parameters: {'learning_rate': 0.05011986836987192, 'max_depth': 14, 'subsample': 0.6813563676452042, 'colsample_bytree': 0.6940744161192149, 'min_child_weight': 0.002880140131319499, 'gamma': 0.025111105541882422}. Best is trial 18 with value: 0.9531916499161767.
# [I 2025-11-30 13:08:58,439] Trial 24 finished with value: 0.9505805215953482 and parameters: {'learning_rate': 0.05122636225280231, 'max_depth': 15, 'subsample': 0.5492346893552523, 'colsample_bytree': 0.6878604681870379, 'min_child_weight': 0.002846314233469982, 'gamma': 0.09633888824502926}. Best is trial 18 with value: 0.9531916499161767.
# [I 2025-11-30 13:14:36,900] Trial 25 finished with value: 0.9458099886556024 and parameters: {'learning_rate': 0.0213195345344516, 'max_depth': 14, 'subsample': 0.6636238805321961, 'colsample_bytree': 0.7868936600812333, 'min_child_weight': 0.004063137213897729, 'gamma': 0.7330166269122753}. Best is trial 18 with value: 0.9531916499161767.
# [I 2025-11-30 13:17:52,052] Trial 26 finished with value: 0.948828630788031 and parameters: {'learning_rate': 0.05226613285805754, 'max_depth': 13, 'subsample': 0.6149258171676613, 'colsample_bytree': 0.5846553683751307, 'min_child_weight': 0.002478042395337462, 'gamma': 1.0860598557169965}. Best is trial 18 with value: 0.9531916499161767.
# [I 2025-11-30 13:23:51,926] Trial 27 finished with value: 0.950012719724043 and parameters: {'learning_rate': 0.0290414577354507, 'max_depth': 14, 'subsample': 0.6936954461188947, 'colsample_bytree': 0.5864174165687394, 'min_child_weight': 0.0018008145684444738, 'gamma': 0.0454894789045309}. Best is trial 18 with value: 0.9531916499161767.
# [I 2025-11-30 13:28:30,095] Trial 28 finished with value: 0.9494155151777575 and parameters: {'learning_rate': 0.04146704629513471, 'max_depth': 15, 'subsample': 0.5641642068081051, 'colsample_bytree': 0.6987646668386999, 'min_child_weight': 0.00627789720620884, 'gamma': 0.6495578842687482}. Best is trial 18 with value: 0.9531916499161767.
# [I 2025-11-30 13:30:58,804] Trial 29 finished with value: 0.9428804587484866 and parameters: {'learning_rate': 0.06876066623973441, 'max_depth': 12, 'subsample': 0.5002117575629956, 'colsample_bytree': 0.614189105568332, 'min_child_weight': 0.0037561183925062316, 'gamma': 2.9880231334009193}. Best is trial 18 with value: 0.9531916499161767.
# [INFO] Best XGBoost params: {'learning_rate': 0.047977461787374734, 'max_depth': 14, 'subsample': 0.7449890839436284, 'colsample_bytree': 0.70110582598937, 'min_child_weight': 0.0010226677164813366, 'gamma': 0.14922602556210918}

# %%
evaluate_and_log(model_xgboost_full, X_valid, y_valid, experiment_name=EXPERIMENT_NAME, run_name="XGBoost_Optuna_fullfeatures", hp_search_history=hist_df, hp_search_plots= plot_paths)
# Out:
# [INFO] Logged metrics: {'roc_auc': np.float64(0.978296886263691), 'pr_auc': np.float64(0.9170423426563677), 'precision': 0.9559659090909091, 'recall': 0.8141785627873216, 'f1': 0.8793937018162812, 'custom_loss': np.float64(0.6515646696244115)}
# [INFO] Logged SHAP summary plot.
# 2025/11/30 13:42:55 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# [INFO] Evaluation complete and logged.
# {'roc_auc': np.float64(0.978296886263691),
#  'pr_auc': np.float64(0.9170423426563677),
#  'precision': 0.9559659090909091,
#  'recall': 0.8141785627873216,
#  'f1': 0.8793937018162812,
#  'custom_loss': np.float64(0.6515646696244115)}

# %%
evaluate_and_log(model_xgboost_full,  X_valid, y_valid, experiment_name=EXPERIMENT_NAME, run_name="XGBoost_Optuna_fullfeatures", hp_search_history=hist_df, hp_search_plots= plot_paths, prediction_threshold=0.25)
# Out:
# [INFO] Logged metrics: {'roc_auc': np.float64(0.978296886263691), 'pr_auc': np.float64(0.9170423426563677), 'precision': 0.9217231415812976, 'recall': 0.8490200822646987, 'f1': 0.8838790931989925, 'custom_loss': np.float64(0.5308531174856911)}
# [INFO] Logged SHAP summary plot.
# 2025/11/30 13:44:13 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# [INFO] Evaluation complete and logged.
# {'roc_auc': np.float64(0.978296886263691),
#  'pr_auc': np.float64(0.9170423426563677),
#  'precision': 0.9217231415812976,
#  'recall': 0.8490200822646987,
#  'f1': 0.8838790931989925,
#  'custom_loss': np.float64(0.5308531174856911)}

# %%
evaluate_and_log(model_xgboost_full, X_valid, y_valid, experiment_name=EXPERIMENT_NAME, run_name="XGBoost_Optuna_fullfeatures", hp_search_history=hist_df, hp_search_plots= plot_paths, prediction_threshold=0.10)
# Out:
# [INFO] Logged metrics: {'roc_auc': np.float64(0.978296886263691), 'pr_auc': np.float64(0.9170423426563677), 'precision': 0.8589378852536748, 'recall': 0.8766029518509557, 'f1': 0.867680517303317, 'custom_loss': np.float64(0.4368459376164189)}
# [INFO] Logged SHAP summary plot.
# 2025/11/30 13:45:29 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# [INFO] Evaluation complete and logged.
# {'roc_auc': np.float64(0.978296886263691),
#  'pr_auc': np.float64(0.9170423426563677),
#  'precision': 0.8589378852536748,
#  'recall': 0.8766029518509557,
#  'f1': 0.867680517303317,
#  'custom_loss': np.float64(0.4368459376164189)}

# %%
threshOpt, minScore = minimize_eval_metric_with_threshold(model_xgboost_full,  X_valid, y_valid)
print(f"Optimal threshold: {threshOpt}, Minimum eval metric score: {minScore}")
evaluate_and_log(model_xgboost_full,  X_valid, y_valid, experiment_name=EXPERIMENT_NAME, run_name="XGBoost_Optuna_fullfeatures", hp_search_history=hist_df, hp_search_plots= plot_paths, prediction_threshold=threshOpt)
# Out:
# Optimal threshold: 0.0011392603628337383, Minimum eval metric score: 0.2979815084498933
# [INFO] Logged metrics: {'roc_auc': np.float64(0.978296886263691), 'pr_auc': np.float64(0.9170423426563677), 'precision': 0.1986487849147928, 'recall': 0.9533026857004597, 'f1': 0.32878541327658867, 'custom_loss': np.float64(0.2979815084498933)}
# [INFO] Logged SHAP summary plot.
# 2025/11/30 13:46:51 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# [INFO] Evaluation complete and logged.
# {'roc_auc': np.float64(0.978296886263691),
#  'pr_auc': np.float64(0.9170423426563677),
#  'precision': 0.1986487849147928,
#  'recall': 0.9533026857004597,
#  'f1': 0.32878541327658867,
#  'custom_loss': np.float64(0.2979815084498933)}

# %% [markdown]
# ### 1.2. LightGBM

# %%
model_lgbm_full, best_params_lgbm_full, hist_df, plot_paths = train_lgbm_optuna(X_train, y_train, X_tune, y_tune, X_valid, y_valid)
# Out:
# [I 2025-11-30 18:24:17,873] A new study created in memory with name: lgbm_aucpr_optimization
# [Optuna LightGBM Tuning]:   0%|          | 0/30 [00:00<?, ?trial/s]
# [I 2025-11-30 18:25:15,547] Trial 0 finished with value: 0.9354406354964823 and parameters: {'num_leaves': 89, 'max_depth': 19, 'learning_rate': 0.04038013995157655, 'feature_fraction': 0.7595537716395071, 'bagging_fraction': 0.7586046530394261, 'bagging_freq': 5, 'min_child_samples': 52, 'lambda_l1': 4.510556069643136, 'lambda_l2': 7.351593732709463e-07}. Best is trial 0 with value: 0.9354406354964823.
# [I 2025-11-30 18:25:54,953] Trial 1 finished with value: 0.9382900451228401 and parameters: {'num_leaves': 98, 'max_depth': 20, 'learning_rate': 0.29315441288699473, 'feature_fraction': 0.9077682600481172, 'bagging_fraction': 0.6814818706169963, 'bagging_freq': 9, 'min_child_samples': 47, 'lambda_l1': 1.711599919982529e-05, 'lambda_l2': 4.193220145208493e-07}. Best is trial 1 with value: 0.9382900451228401.
# [I 2025-11-30 18:26:59,548] Trial 2 finished with value: 0.9507117129689933 and parameters: {'num_leaves': 166, 'max_depth': 16, 'learning_rate': 0.09504356911475484, 'feature_fraction': 0.689886665727723, 'bagging_fraction': 0.7096437216027316, 'bagging_freq': 3, 'min_child_samples': 18, 'lambda_l1': 0.0003403955219170385, 'lambda_l2': 7.199584977284477e-05}. Best is trial 2 with value: 0.9507117129689933.
# [I 2025-11-30 18:27:39,786] Trial 3 finished with value: 0.9450804784130904 and parameters: {'num_leaves': 79, 'max_depth': 20, 'learning_rate': 0.29153937779840994, 'feature_fraction': 0.9836331883455671, 'bagging_fraction': 0.8700737733603883, 'bagging_freq': 7, 'min_child_samples': 16, 'lambda_l1': 0.0227552959513769, 'lambda_l2': 3.989663101920119e-06}. Best is trial 2 with value: 0.9507117129689933.
# [I 2025-11-30 18:28:42,695] Trial 4 finished with value: 0.921744759346669 and parameters: {'num_leaves': 196, 'max_depth': 11, 'learning_rate': 0.01975958006203418, 'feature_fraction': 0.8227922675736911, 'bagging_fraction': 0.7112661230978745, 'bagging_freq': 10, 'min_child_samples': 48, 'lambda_l1': 1.670195382969026, 'lambda_l2': 3.8973854320055223}. Best is trial 2 with value: 0.9507117129689933.
# [I 2025-11-30 18:29:43,098] Trial 5 finished with value: 0.9511623521116905 and parameters: {'num_leaves': 256, 'max_depth': 14, 'learning_rate': 0.16628918863697742, 'feature_fraction': 0.901038657437808, 'bagging_fraction': 0.98287993272739, 'bagging_freq': 4, 'min_child_samples': 43, 'lambda_l1': 3.210219158155773e-08, 'lambda_l2': 0.0001963977090886749}. Best is trial 5 with value: 0.9511623521116905.
# [I 2025-11-30 18:30:16,133] Trial 6 finished with value: 0.9383883614289132 and parameters: {'num_leaves': 36, 'max_depth': 10, 'learning_rate': 0.12553255370072705, 'feature_fraction': 0.8323933231335857, 'bagging_fraction': 0.8471223753806181, 'bagging_freq': 4, 'min_child_samples': 29, 'lambda_l1': 1.5213186271715043e-07, 'lambda_l2': 0.0008201165906926714}. Best is trial 5 with value: 0.9511623521116905.
# [I 2025-11-30 18:31:12,452] Trial 7 finished with value: 0.9028295000237762 and parameters: {'num_leaves': 63, 'max_depth': 20, 'learning_rate': 0.015961221410604073, 'feature_fraction': 0.8300228166786667, 'bagging_fraction': 0.838804246036614, 'bagging_freq': 2, 'min_child_samples': 86, 'lambda_l1': 0.0005604953723522685, 'lambda_l2': 0.06745634898035137}. Best is trial 5 with value: 0.9511623521116905.
# [I 2025-11-30 18:31:52,914] Trial 8 finished with value: 0.9405518899624045 and parameters: {'num_leaves': 102, 'max_depth': 13, 'learning_rate': 0.21628365622910628, 'feature_fraction': 0.6841654646390682, 'bagging_fraction': 0.6291073079882833, 'bagging_freq': 1, 'min_child_samples': 38, 'lambda_l1': 2.141987658690129, 'lambda_l2': 0.0010243103640163633}. Best is trial 5 with value: 0.9511623521116905.
# [I 2025-11-30 18:32:26,162] Trial 9 finished with value: 0.9273497810427394 and parameters: {'num_leaves': 41, 'max_depth': 10, 'learning_rate': 0.05957810443177309, 'feature_fraction': 0.7827235335108373, 'bagging_fraction': 0.9809029998668718, 'bagging_freq': 6, 'min_child_samples': 30, 'lambda_l1': 0.006320652596601871, 'lambda_l2': 3.0366443391263326e-07}. Best is trial 5 with value: 0.9511623521116905.
# [I 2025-11-30 18:33:38,777] Trial 10 finished with value: 0.9524512285141347 and parameters: {'num_leaves': 252, 'max_depth': 16, 'learning_rate': 0.13684882686616612, 'feature_fraction': 0.995830034896781, 'bagging_fraction': 0.9769749417841457, 'bagging_freq': 8, 'min_child_samples': 72, 'lambda_l1': 1.7739252598513836e-08, 'lambda_l2': 1.3704943197529204e-08}. Best is trial 10 with value: 0.9524512285141347.
# [I 2025-11-30 18:34:51,165] Trial 11 finished with value: 0.9522586671749748 and parameters: {'num_leaves': 254, 'max_depth': 16, 'learning_rate': 0.13681622206137137, 'feature_fraction': 0.9970409849946047, 'bagging_fraction': 0.9959479156578803, 'bagging_freq': 8, 'min_child_samples': 79, 'lambda_l1': 1.6844942982294207e-08, 'lambda_l2': 2.8133283446440814e-08}. Best is trial 10 with value: 0.9524512285141347.
# [I 2025-11-30 18:36:41,662] Trial 12 finished with value: 0.9532368700370378 and parameters: {'num_leaves': 256, 'max_depth': 17, 'learning_rate': 0.08010784435931408, 'feature_fraction': 0.9963717200840395, 'bagging_fraction': 0.9220061691352058, 'bagging_freq': 8, 'min_child_samples': 78, 'lambda_l1': 1.804353271020478e-06, 'lambda_l2': 1.0081911046104229e-08}. Best is trial 12 with value: 0.9532368700370378.
# [I 2025-11-30 18:38:40,202] Trial 13 finished with value: 0.9529282772102309 and parameters: {'num_leaves': 216, 'max_depth': 17, 'learning_rate': 0.06253228002654082, 'feature_fraction': 0.9287963411172354, 'bagging_fraction': 0.911852704195339, 'bagging_freq': 8, 'min_child_samples': 71, 'lambda_l1': 2.2331039906778908e-06, 'lambda_l2': 1.73747156212391e-08}. Best is trial 12 with value: 0.9532368700370378.
# [I 2025-11-30 18:40:09,035] Trial 14 finished with value: 0.9479430017697178 and parameters: {'num_leaves': 207, 'max_depth': 18, 'learning_rate': 0.04124663906488511, 'feature_fraction': 0.9130542887534663, 'bagging_fraction': 0.9093362925120573, 'bagging_freq': 10, 'min_child_samples': 99, 'lambda_l1': 2.80919362216029e-06, 'lambda_l2': 1.1064134951429983e-08}. Best is trial 12 with value: 0.9532368700370378.
# [I 2025-11-30 18:41:45,261] Trial 15 finished with value: 0.9528780630335077 and parameters: {'num_leaves': 202, 'max_depth': 17, 'learning_rate': 0.06325874055519633, 'feature_fraction': 0.9401478756142063, 'bagging_fraction': 0.9156554698464349, 'bagging_freq': 7, 'min_child_samples': 65, 'lambda_l1': 2.3942689748495355e-06, 'lambda_l2': 6.0947531733661935e-06}. Best is trial 12 with value: 0.9532368700370378.
# [I 2025-11-30 18:42:52,325] Trial 16 finished with value: 0.9400546584483376 and parameters: {'num_leaves': 144, 'max_depth': 18, 'learning_rate': 0.027253892667261217, 'feature_fraction': 0.623703642005706, 'bagging_fraction': 0.91696220985697, 'bagging_freq': 8, 'min_child_samples': 65, 'lambda_l1': 1.4807311900841284e-05, 'lambda_l2': 1.1485694285172916e-07}. Best is trial 12 with value: 0.9532368700370378.
# [I 2025-11-30 18:44:16,963] Trial 17 finished with value: 0.9516495963222482 and parameters: {'num_leaves': 223, 'max_depth': 14, 'learning_rate': 0.0855537040592013, 'feature_fraction': 0.8727176139123888, 'bagging_fraction': 0.791651977674091, 'bagging_freq': 6, 'min_child_samples': 87, 'lambda_l1': 2.138741619085876e-07, 'lambda_l2': 0.01635268321564526}. Best is trial 12 with value: 0.9532368700370378.
# [I 2025-11-30 18:45:40,206] Trial 18 finished with value: 0.9451814196143918 and parameters: {'num_leaves': 167, 'max_depth': 18, 'learning_rate': 0.0359578800312492, 'feature_fraction': 0.9583405344469261, 'bagging_fraction': 0.9412094819003862, 'bagging_freq': 7, 'min_child_samples': 100, 'lambda_l1': 1.589231785991484e-06, 'lambda_l2': 4.964358893987704e-06}. Best is trial 12 with value: 0.9532368700370378.
# [I 2025-11-30 18:47:28,185] Trial 19 finished with value: 0.9527271510887526 and parameters: {'num_leaves': 226, 'max_depth': 15, 'learning_rate': 0.09182028184670273, 'feature_fraction': 0.8702785347874076, 'bagging_fraction': 0.8721489211381177, 'bagging_freq': 10, 'min_child_samples': 64, 'lambda_l1': 5.7288872043972485e-05, 'lambda_l2': 2.2762733096913564e-05}. Best is trial 12 with value: 0.9532368700370378.
# [I 2025-11-30 18:49:14,475] Trial 20 finished with value: 0.91004065530907 and parameters: {'num_leaves': 175, 'max_depth': 12, 'learning_rate': 0.010150663711889732, 'feature_fraction': 0.9564222704391624, 'bagging_fraction': 0.7926529948333552, 'bagging_freq': 9, 'min_child_samples': 78, 'lambda_l1': 2.80585843068308e-07, 'lambda_l2': 6.110690734117124e-08}. Best is trial 12 with value: 0.9532368700370378.
# [I 2025-11-30 18:51:03,801] Trial 21 finished with value: 0.9533821201477656 and parameters: {'num_leaves': 225, 'max_depth': 17, 'learning_rate': 0.0634112481648665, 'feature_fraction': 0.938332026498556, 'bagging_fraction': 0.9330569408345344, 'bagging_freq': 7, 'min_child_samples': 62, 'lambda_l1': 1.9884604168453614e-06, 'lambda_l2': 1.3762015987024094e-06}. Best is trial 21 with value: 0.9533821201477656.
# [I 2025-11-30 18:53:13,870] Trial 22 finished with value: 0.9541921653680902 and parameters: {'num_leaves': 227, 'max_depth': 17, 'learning_rate': 0.07656990174288049, 'feature_fraction': 0.936270507330223, 'bagging_fraction': 0.942671114143771, 'bagging_freq': 9, 'min_child_samples': 56, 'lambda_l1': 2.954976945576723e-05, 'lambda_l2': 9.299566730170337e-07}. Best is trial 22 with value: 0.9541921653680902.
# [I 2025-11-30 18:55:04,080] Trial 23 finished with value: 0.9541197169300554 and parameters: {'num_leaves': 234, 'max_depth': 17, 'learning_rate': 0.0789402496699889, 'feature_fraction': 0.8797160397529659, 'bagging_fraction': 0.958244124970377, 'bagging_freq': 9, 'min_child_samples': 60, 'lambda_l1': 0.00010421227842010348, 'lambda_l2': 1.1372893371349983e-06}. Best is trial 22 with value: 0.9541921653680902.
# [I 2025-11-30 18:56:57,687] Trial 24 finished with value: 0.9520019183369012 and parameters: {'num_leaves': 233, 'max_depth': 15, 'learning_rate': 0.05156956920973891, 'feature_fraction': 0.8721737720569199, 'bagging_fraction': 0.9590141587983412, 'bagging_freq': 9, 'min_child_samples': 58, 'lambda_l1': 0.003607974679473063, 'lambda_l2': 2.199259548447289e-06}. Best is trial 22 with value: 0.9541921653680902.
# [I 2025-11-30 18:58:36,908] Trial 25 finished with value: 0.9442117960099213 and parameters: {'num_leaves': 186, 'max_depth': 19, 'learning_rate': 0.027461987974144616, 'feature_fraction': 0.8813651793903695, 'bagging_fraction': 0.8790358399578548, 'bagging_freq': 9, 'min_child_samples': 57, 'lambda_l1': 7.22482000598243e-05, 'lambda_l2': 2.8326076011021207e-05}. Best is trial 22 with value: 0.9541921653680902.
# [I 2025-11-30 18:59:40,153] Trial 26 finished with value: 0.9530514147871015 and parameters: {'num_leaves': 127, 'max_depth': 17, 'learning_rate': 0.11330843784466617, 'feature_fraction': 0.8499530221176077, 'bagging_fraction': 0.9397434285018791, 'bagging_freq': 7, 'min_child_samples': 38, 'lambda_l1': 0.0011244601261588992, 'lambda_l2': 1.0308818266008709e-06}. Best is trial 22 with value: 0.9541921653680902.
# [I 2025-11-30 19:01:26,992] Trial 27 finished with value: 0.9530781339460647 and parameters: {'num_leaves': 232, 'max_depth': 19, 'learning_rate': 0.07238680245523142, 'feature_fraction': 0.9529719061756053, 'bagging_fraction': 0.835614915187973, 'bagging_freq': 6, 'min_child_samples': 58, 'lambda_l1': 6.029584600829991e-05, 'lambda_l2': 2.0644589909122553e-07}. Best is trial 22 with value: 0.9541921653680902.
# [I 2025-11-30 19:02:18,603] Trial 28 finished with value: 0.9498783747816816 and parameters: {'num_leaves': 147, 'max_depth': 16, 'learning_rate': 0.18546020247858605, 'feature_fraction': 0.7901811658204253, 'bagging_fraction': 0.8855981906995372, 'bagging_freq': 10, 'min_child_samples': 51, 'lambda_l1': 0.11841214660778816, 'lambda_l2': 1.6383706685314852e-05}. Best is trial 22 with value: 0.9541921653680902.
# [I 2025-11-30 19:04:14,210] Trial 29 finished with value: 0.95172171873695 and parameters: {'num_leaves': 237, 'max_depth': 18, 'learning_rate': 0.041357957875036024, 'feature_fraction': 0.9233206356263003, 'bagging_fraction': 0.9600013097035919, 'bagging_freq': 5, 'min_child_samples': 55, 'lambda_l1': 1.2797517882753582e-05, 'lambda_l2': 9.486417769952278e-07}. Best is trial 22 with value: 0.9541921653680902.
# [INFO] Best LightGBM params: {'num_leaves': 227, 'max_depth': 17, 'learning_rate': 0.07656990174288049, 'feature_fraction': 0.936270507330223, 'bagging_fraction': 0.942671114143771, 'bagging_freq': 9, 'min_child_samples': 56, 'lambda_l1': 2.954976945576723e-05, 'lambda_l2': 9.299566730170337e-07}

# %%
model_lgbm_full
# Out:
# LGBMClassifier(bagging_fraction=0.942671114143771, bagging_freq=9,
#                categorical_feature=['ProductCD', 'card4', 'card6',
#                                     'P_emaildomain', 'R_emaildomain', 'M1',
#                                     'M2', 'M3', 'M4', 'M5', 'M6', 'M7', 'M8',
#                                     'M9', 'id_12', 'id_15', 'id_16', 'id_23',
#                                     'id_27', 'id_28', 'id_29', 'id_30', 'id_31',
#                                     'id_33', 'id_34', 'id_35', 'id_36', 'id_37',
#                                     'id_38', 'DeviceType', ...],
#                device='cpu', eval_metric='aucpr',
#                feature_fraction=0.936270507330223,
#                lambda_l1=2.954976945576723e-05, lambda_l2=9.299566730170337e-07,
#                learning_rate=0.07656990174288049, max_depth=17,
#                min_child_samples=56, n_estimators=1000, num_leaves=227,
#                objective='binary', random_state=42,
#                scale_pos_weight=27.580278281911674, verbosity=-1)

# %%
evaluate_and_log(model_lgbm_full,  X_valid, y_valid, experiment_name=EXPERIMENT_NAME, run_name="LightGBM_Optuna_fullfeatures", hp_search_history=hist_df, hp_search_plots= plot_paths)
# Out:
# [INFO] Logged metrics: {'roc_auc': np.float64(0.9056815767165312), 'pr_auc': np.float64(0.4363099973978413), 'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'custom_loss': np.float64(3.49933958749619)}
# [INFO] Logged SHAP summary plot.
# 2025/11/30 19:05:04 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# [INFO] Evaluation complete and logged.
# {'roc_auc': np.float64(0.9056815767165312),
#  'pr_auc': np.float64(0.4363099973978413),
#  'precision': 0.0,
#  'recall': 0.0,
#  'f1': 0.0,
#  'custom_loss': np.float64(3.49933958749619)}

# %%
evaluate_and_log(model_lgbm_full, X_valid, y_valid, experiment_name=EXPERIMENT_NAME, run_name="LightGBM_Optuna_fullfeatures", hp_search_history=hist_df, hp_search_plots= plot_paths, prediction_threshold=0.25)
# Out:
# [INFO] Logged metrics: {'roc_auc': np.float64(0.9056815767165312), 'pr_auc': np.float64(0.4363099973978413), 'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'custom_loss': np.float64(3.49933958749619)}
# [INFO] Logged SHAP summary plot.
# 2025/11/30 19:05:12 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# [INFO] Evaluation complete and logged.
# {'roc_auc': np.float64(0.9056815767165312),
#  'pr_auc': np.float64(0.4363099973978413),
#  'precision': 0.0,
#  'recall': 0.0,
#  'f1': 0.0,
#  'custom_loss': np.float64(3.49933958749619)}

# %%
evaluate_and_log(model_lgbm_full, X_valid, y_valid, experiment_name=EXPERIMENT_NAME, run_name="LightGBM_Optuna_fullfeatures", hp_search_history=hist_df, hp_search_plots= plot_paths, prediction_threshold=0.10)
# Out:
# [INFO] Logged metrics: {'roc_auc': np.float64(0.9056815767165312), 'pr_auc': np.float64(0.4363099973978413), 'precision': 0.18336463643681244, 'recall': 0.8267602225985966, 'f1': 0.30015811665495434, 'custom_loss': np.float64(0.735072984048498)}
# [INFO] Logged SHAP summary plot.
# 2025/11/30 19:05:20 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# [INFO] Evaluation complete and logged.
# {'roc_auc': np.float64(0.9056815767165312),
#  'pr_auc': np.float64(0.4363099973978413),
#  'precision': 0.18336463643681244,
#  'recall': 0.8267602225985966,
#  'f1': 0.30015811665495434,
#  'custom_loss': np.float64(0.735072984048498)}

# %%
threshOpt, minScore = minimize_eval_metric_with_threshold(model_lgbm_full, X_valid, y_valid)
print(f"Optimal threshold: {threshOpt}, Minimum eval metric score: {minScore}")
evaluate_and_log(
    model_lgbm_full, 
    X_valid, y_valid, 
    experiment_name=EXPERIMENT_NAME, 
    run_name="LightGBM_Optuna_fullfeatures", 
    hp_search_history=hist_df, hp_search_plots=plot_paths, 
    prediction_threshold=threshOpt)
# Out:
# Optimal threshold: 0.04439166260234292, Minimum eval metric score: 0.6371795305991127
# [INFO] Logged metrics: {'roc_auc': np.float64(0.9056815767165312), 'pr_auc': np.float64(0.4363099973978413), 'precision': 0.08162434372656166, 'recall': 0.9216065811759013, 'f1': 0.14996653411551636, 'custom_loss': np.float64(0.6371795305991127)}
# [INFO] Logged SHAP summary plot.
# 2025/11/30 19:05:29 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# [INFO] Evaluation complete and logged.
# {'roc_auc': np.float64(0.9056815767165312),
#  'pr_auc': np.float64(0.4363099973978413),
#  'precision': 0.08162434372656166,
#  'recall': 0.9216065811759013,
#  'f1': 0.14996653411551636,
#  'custom_loss': np.float64(0.6371795305991127)}

# %% [markdown]
# ### 1.3. CatBoost

# %%
model_catboost_full, best_params_catboost_full, hist_df, plot_paths = train_catboost_optuna(X_train, y_train, X_valid, y_valid, X_valid, y_valid, early_stopping_rounds=10)
# Out:
# [I 2025-11-29 20:48:33,506] A new study created in memory with name: catboost_aucpr_optimization
# [Optuna CatBoost Tuning]:   0%|          | 0/30 [00:00<?, ?trial/s]
# [I 2025-11-29 20:53:43,096] Trial 0 finished with value: 0.9212252621609099 and parameters: {'learning_rate': 0.2860429973310247, 'depth': 6, 'l2_leaf_reg': 9.775721614705137, 'subsample': 0.8397188154264389, 'border_count': 72}. Best is trial 0 with value: 0.9212252621609099.
# [I 2025-11-29 20:58:05,595] Trial 1 finished with value: 0.8247706162486352 and parameters: {'learning_rate': 0.024897120250139276, 'depth': 5, 'l2_leaf_reg': 1.9816588919583178, 'subsample': 0.9675433936565476, 'border_count': 95}. Best is trial 0 with value: 0.9212252621609099.
# [I 2025-11-29 21:03:15,510] Trial 2 finished with value: 0.8574541559949392 and parameters: {'learning_rate': 0.04159845121979802, 'depth': 6, 'l2_leaf_reg': 1.8948022976618615, 'subsample': 0.7100551064410163, 'border_count': 85}. Best is trial 0 with value: 0.9212252621609099.
# [I 2025-11-29 21:14:03,628] Trial 3 finished with value: 0.84901512538521 and parameters: {'learning_rate': 0.012572242546478072, 'depth': 9, 'l2_leaf_reg': 1.8103122203473636, 'subsample': 0.7919929467781087, 'border_count': 120}. Best is trial 0 with value: 0.9212252621609099.
# [I 2025-11-29 21:19:55,796] Trial 4 finished with value: 0.8436624093491489 and parameters: {'learning_rate': 0.023250139297208, 'depth': 7, 'l2_leaf_reg': 5.274146525682459, 'subsample': 0.6605753360648615, 'border_count': 59}. Best is trial 0 with value: 0.9212252621609099.
# [I 2025-11-29 21:35:04,704] Trial 5 finished with value: 0.9274341424947198 and parameters: {'learning_rate': 0.051346940886330704, 'depth': 10, 'l2_leaf_reg': 1.0941941557563197, 'subsample': 0.9200310686272613, 'border_count': 103}. Best is trial 5 with value: 0.9274341424947198.
# [I 2025-11-29 21:41:12,318] Trial 6 finished with value: 0.9158405369596511 and parameters: {'learning_rate': 0.06802125194061631, 'depth': 8, 'l2_leaf_reg': 1.1148921179161468, 'subsample': 0.9187988618009969, 'border_count': 42}. Best is trial 5 with value: 0.9274341424947198.
# [I 2025-11-29 21:45:21,973] Trial 7 finished with value: 0.8247251409990106 and parameters: {'learning_rate': 0.018337117198085517, 'depth': 6, 'l2_leaf_reg': 1.179232025968656, 'subsample': 0.8342447098912646, 'border_count': 40}. Best is trial 5 with value: 0.9274341424947198.
# [I 2025-11-29 21:52:30,676] Trial 8 finished with value: 0.9202691772772225 and parameters: {'learning_rate': 0.06821306009994349, 'depth': 9, 'l2_leaf_reg': 5.901788489234022, 'subsample': 0.6949051008637761, 'border_count': 40}. Best is trial 5 with value: 0.9274341424947198.
# [I 2025-11-29 21:56:35,996] Trial 9 finished with value: 0.8799658940027513 and parameters: {'learning_rate': 0.06113456286883911, 'depth': 6, 'l2_leaf_reg': 7.9881016894510495, 'subsample': 0.9340363491570528, 'border_count': 106}. Best is trial 5 with value: 0.9274341424947198.
# [I 2025-11-29 22:08:27,390] Trial 10 finished with value: 0.9395889037415719 and parameters: {'learning_rate': 0.16941242192662748, 'depth': 10, 'l2_leaf_reg': 3.949057617800829, 'subsample': 0.6022960975808498, 'border_count': 128}. Best is trial 10 with value: 0.9395889037415719.
# [I 2025-11-29 22:20:07,766] Trial 11 finished with value: 0.9411892863253991 and parameters: {'learning_rate': 0.1695931555242062, 'depth': 10, 'l2_leaf_reg': 3.7556883365880402, 'subsample': 0.6077458138385241, 'border_count': 125}. Best is trial 11 with value: 0.9411892863253991.
# [I 2025-11-29 22:32:05,150] Trial 12 finished with value: 0.9416143493535832 and parameters: {'learning_rate': 0.18639100787412116, 'depth': 10, 'l2_leaf_reg': 4.014779974360116, 'subsample': 0.6059803637928816, 'border_count': 127}. Best is trial 12 with value: 0.9416143493535832.
# [I 2025-11-29 22:39:23,640] Trial 13 finished with value: 0.9334653216105581 and parameters: {'learning_rate': 0.14100331376556866, 'depth': 9, 'l2_leaf_reg': 3.9672249550216776, 'subsample': 0.6008046026485204, 'border_count': 116}. Best is trial 12 with value: 0.9416143493535832.
# [I 2025-11-29 22:51:10,851] Trial 14 finished with value: 0.9410841679250326 and parameters: {'learning_rate': 0.12802800440104917, 'depth': 10, 'l2_leaf_reg': 3.5859733817261934, 'subsample': 0.7499602807492967, 'border_count': 126}. Best is trial 12 with value: 0.9416143493535832.
# [I 2025-11-29 22:56:42,801] Trial 15 finished with value: 0.9340970857090315 and parameters: {'learning_rate': 0.27748697761566193, 'depth': 8, 'l2_leaf_reg': 5.900190804469441, 'subsample': 0.6495162466837093, 'border_count': 110}. Best is trial 12 with value: 0.9416143493535832.
# [I 2025-11-29 23:03:42,892] Trial 16 finished with value: 0.9332865432952276 and parameters: {'learning_rate': 0.11570906021802582, 'depth': 9, 'l2_leaf_reg': 3.0742472657221405, 'subsample': 0.6442417850962281, 'border_count': 92}. Best is trial 12 with value: 0.9416143493535832.
# [I 2025-11-29 23:13:44,484] Trial 17 finished with value: 0.942861342317062 and parameters: {'learning_rate': 0.19203113190483098, 'depth': 10, 'l2_leaf_reg': 4.926789798653422, 'subsample': 0.7415830609565688, 'border_count': 72}. Best is trial 17 with value: 0.942861342317062.
# [I 2025-11-29 23:19:08,229] Trial 18 finished with value: 0.9202438739860547 and parameters: {'learning_rate': 0.10118881847520148, 'depth': 8, 'l2_leaf_reg': 7.45650875833079, 'subsample': 0.7279566333530724, 'border_count': 72}. Best is trial 17 with value: 0.942861342317062.
# [I 2025-11-29 23:28:50,772] Trial 19 finished with value: 0.9435804168180301 and parameters: {'learning_rate': 0.22218824432567716, 'depth': 10, 'l2_leaf_reg': 5.460147714867471, 'subsample': 0.7724920764663874, 'border_count': 57}. Best is trial 19 with value: 0.9435804168180301.
# [I 2025-11-29 23:33:13,887] Trial 20 finished with value: 0.9288782776346044 and parameters: {'learning_rate': 0.22790507981360306, 'depth': 7, 'l2_leaf_reg': 5.05999227274195, 'subsample': 0.7784523408120562, 'border_count': 54}. Best is trial 19 with value: 0.9435804168180301.
# [I 2025-11-29 23:43:52,968] Trial 21 finished with value: 0.9436626117052759 and parameters: {'learning_rate': 0.18743013352582985, 'depth': 10, 'l2_leaf_reg': 6.852005346610192, 'subsample': 0.8440274016579897, 'border_count': 65}. Best is trial 21 with value: 0.9436626117052759.
# [I 2025-11-29 23:50:46,515] Trial 22 finished with value: 0.9407756252719155 and parameters: {'learning_rate': 0.21394767776567433, 'depth': 9, 'l2_leaf_reg': 6.891572362235831, 'subsample': 0.8600151372475784, 'border_count': 58}. Best is trial 21 with value: 0.9436626117052759.
# [I 2025-11-30 00:01:40,250] Trial 23 finished with value: 0.9353573982410707 and parameters: {'learning_rate': 0.09198118419471042, 'depth': 10, 'l2_leaf_reg': 8.707065184297322, 'subsample': 0.8744078685979464, 'border_count': 68}. Best is trial 21 with value: 0.9436626117052759.
# [I 2025-11-30 00:08:11,095] Trial 24 finished with value: 0.9407347413832393 and parameters: {'learning_rate': 0.2872243782641251, 'depth': 9, 'l2_leaf_reg': 6.503042500109061, 'subsample': 0.7633042651383053, 'border_count': 51}. Best is trial 21 with value: 0.9436626117052759.
# [I 2025-11-30 00:19:06,449] Trial 25 finished with value: 0.9358914088410253 and parameters: {'learning_rate': 0.08519573705189051, 'depth': 10, 'l2_leaf_reg': 4.788191569646649, 'subsample': 0.8157645712722978, 'border_count': 79}. Best is trial 21 with value: 0.9436626117052759.
# [I 2025-11-30 00:26:24,958] Trial 26 finished with value: 0.9369661745185821 and parameters: {'learning_rate': 0.1444997031443797, 'depth': 9, 'l2_leaf_reg': 6.576910784087447, 'subsample': 0.8760166840681782, 'border_count': 64}. Best is trial 21 with value: 0.9436626117052759.
# [I 2025-11-30 00:36:43,086] Trial 27 finished with value: 0.9424720452452041 and parameters: {'learning_rate': 0.21593300271964716, 'depth': 10, 'l2_leaf_reg': 4.60193045002658, 'subsample': 0.7398595921846498, 'border_count': 80}. Best is trial 21 with value: 0.9436626117052759.
# [I 2025-11-30 00:41:52,430] Trial 28 finished with value: 0.9307135738184312 and parameters: {'learning_rate': 0.1514381848136773, 'depth': 8, 'l2_leaf_reg': 5.76118644116524, 'subsample': 0.6881627767929575, 'border_count': 49}. Best is trial 21 with value: 0.9436626117052759.
# [I 2025-11-30 00:51:00,222] Trial 29 finished with value: 0.9418569209034221 and parameters: {'learning_rate': 0.25619201056013563, 'depth': 10, 'l2_leaf_reg': 9.160010232106867, 'subsample': 0.8134678135761892, 'border_count': 33}. Best is trial 21 with value: 0.9436626117052759.
# [INFO] Best CatBoost params: {'learning_rate': 0.18743013352582985, 'depth': 10, 'l2_leaf_reg': 6.852005346610192, 'subsample': 0.8440274016579897, 'border_count': 65}

# %%
evaluate_and_log(model_catboost_full,  X_valid, y_valid, experiment_name=EXPERIMENT_NAME, run_name="CATboost_Optuna_fullfeatures", hp_search_history=hist_df, hp_search_plots= plot_paths)
# Out:
# 2025/11/30 01:08:11 INFO mlflow.tracking.fluent: Experiment with name 'Fraud-detection-custom-thresholds_v2' does not exist. Creating a new experiment.
# [INFO] Logged metrics: {'roc_auc': np.float64(0.9764139849457184), 'pr_auc': np.float64(0.8693571706599657), 'precision': 0.6375523012552301, 'recall': 0.8848294217275586, 'f1': 0.7411085216333975, 'custom_loss': np.float64(0.4206234971382125)}
# [INFO] Logged SHAP summary plot.
# 2025/11/30 01:09:32 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# [INFO] Evaluation complete and logged.
# {'roc_auc': np.float64(0.9764139849457184),
#  'pr_auc': np.float64(0.8693571706599657),
#  'precision': 0.6375523012552301,
#  'recall': 0.8848294217275586,
#  'f1': 0.7411085216333975,
#  'custom_loss': np.float64(0.4206234971382125)}

# %%
evaluate_and_log(model_catboost_full,  X_valid, y_valid, experiment_name=EXPERIMENT_NAME, run_name="CATboost_Optuna_fullfeatures", hp_search_history=hist_df, hp_search_plots= plot_paths, prediction_threshold=0.25)
# Out:
# [INFO] Logged metrics: {'roc_auc': np.float64(0.9764139849457184), 'pr_auc': np.float64(0.8693571706599657), 'precision': 0.3744872045321352, 'recall': 0.9276554560851682, 'f1': 0.5335745598775311, 'custom_loss': np.float64(0.307379686388729)}
# [INFO] Logged SHAP summary plot.
# 2025/11/30 01:10:40 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# [INFO] Evaluation complete and logged.
# {'roc_auc': np.float64(0.9764139849457184),
#  'pr_auc': np.float64(0.8693571706599657),
#  'precision': 0.3744872045321352,
#  'recall': 0.9276554560851682,
#  'f1': 0.5335745598775311,
#  'custom_loss': np.float64(0.307379686388729)}

# %%
evaluate_and_log(model_catboost_full,  X_valid, y_valid, experiment_name=EXPERIMENT_NAME, run_name="CATboost_Optuna_fullfeatures", hp_search_history=hist_df, hp_search_plots= plot_paths, prediction_threshold=0.1)
# Out:
# [INFO] Logged metrics: {'roc_auc': np.float64(0.9764139849457184), 'pr_auc': np.float64(0.8693571706599657), 'precision': 0.18166743436204513, 'recall': 0.9542705056859424, 'f1': 0.30522772123979414, 'custom_loss': np.float64(0.31044467775256546)}
# [INFO] Logged SHAP summary plot.
# 2025/11/30 01:11:48 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# [INFO] Evaluation complete and logged.
# {'roc_auc': np.float64(0.9764139849457184),
#  'pr_auc': np.float64(0.8693571706599657),
#  'precision': 0.18166743436204513,
#  'recall': 0.9542705056859424,
#  'f1': 0.30522772123979414,
#  'custom_loss': np.float64(0.31044467775256546)}

# %%
threshOpt, minScore = minimize_eval_metric_with_threshold(model_catboost_full,  X_valid, y_valid)
print(f"Optimal threshold: {threshOpt}, Minimum eval metric score: {minScore}")
evaluate_and_log(
    model_catboost_full, 
    X_valid, y_valid,
    experiment_name=EXPERIMENT_NAME, run_name="CATboost_Optuna_fullfeatures", 
    hp_search_history=hist_df, hp_search_plots= plot_paths, 
    prediction_threshold=threshOpt)
# Out:
# Optimal threshold: 0.056640611442584844, Minimum eval metric score: 0.3448877298743523
# [INFO] Logged metrics: {'roc_auc': np.float64(0.9764139849457184), 'pr_auc': np.float64(0.8693571706599657), 'precision': 0.12395263271805336, 'recall': 0.9699975804500363, 'f1': 0.2198157692729466, 'custom_loss': np.float64(0.3448877298743523)}
# [INFO] Logged SHAP summary plot.
# 2025/11/30 01:12:57 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# [INFO] Evaluation complete and logged.
# {'roc_auc': np.float64(0.9764139849457184),
#  'pr_auc': np.float64(0.8693571706599657),
#  'precision': 0.12395263271805336,
#  'recall': 0.9699975804500363,
#  'f1': 0.2198157692729466,
#  'custom_loss': np.float64(0.3448877298743523)}

# %% [markdown]
# ## 2. Reduced Features

# %%
# ---- 1. Compute SHAP importance for each model ----
df_xgb = get_top_features_shap(model_xgboost_full, train, target).rename(
    columns={"importance": "importance_xgb"}
)
df_lgbm = get_top_features_shap(model_lgbm_full, train, target).rename(
    columns={"importance": "importance_lgbm"}
)
df_cat = get_top_features_shap(model_catboost_full, train, target).rename(
    columns={"importance": "importance_cat"}
)

# ---- 2. Merge all importance tables ----
df = (
    df_xgb.merge(df_lgbm, on="feature")
          .merge(df_cat, on="feature")
)

# ---- 3. Rank features within each model (1 = most important) ----
df["rank_xgb"] = df["importance_xgb"].rank(method="min", ascending=False)
df["rank_lgbm"] = df["importance_lgbm"].rank(method="min", ascending=False)
df["rank_cat"] = df["importance_cat"].rank(method="min", ascending=False)

# ---- 4. Determine the top 30% threshold ----
n_features = len(df)
top_30_cutoff = int(n_features * 0.30)

# ---- 5. Check if a feature appears in top 30% in each model ----
df["in_top_xgb"]  = df["rank_xgb"]  <= top_30_cutoff
df["in_top_lgbm"] = df["rank_lgbm"] <= top_30_cutoff
df["in_top_cat"]  = df["rank_cat"]  <= top_30_cutoff

# ---- 6. Apply the rule: “Top 30% for at least 2 models” ----
df["top_count"] = (
    df["in_top_xgb"].astype(int)
  + df["in_top_lgbm"].astype(int)
  + df["in_top_cat"].astype(int)
)

df_selected = df[df["top_count"] >= 2]  # final selected features

# ---- 7. Sort by mean importance (optional but nice) ----
df["importance_mean"] = df[["importance_xgb","importance_lgbm","importance_cat"]].mean(axis=1)
df_selected = df_selected.sort_values("importance_mean", ascending=False)

# ---- 8. Save to CSV ----
df.to_csv(f"{data_folder}/feature_importances_shap_fullmodels.csv", index=False)
df_selected.to_csv(f"{data_folder}/selected_features_shap.csv", index=False)

# ---- 9. List of selected feature names ----
selected_feature_list = df_selected["feature"].tolist()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 2
#       1 # ---- 1. Compute SHAP importance for each model ----
# ----> 2 df_xgb = get_top_features_shap(model_xgboost_full, train, target).rename(
#       3     columns={"importance": "importance_xgb"}
#       4 )
#       5 df_lgbm = get_top_features_shap(model_lgbm_full, train, target).rename(
#       6     columns={"importance": "importance_lgbm"}
#       7 )
#       8 df_cat = get_top_features_shap(model_catboost_full, train, target).rename(
#       9     columns={"importance": "importance_cat"}
#      10 )
#
# NameError: name 'train' is not defined

# %%
X_reduced = train[selected_feature_list]

# %%
df.head()

# %%
df_selected.head()

# %%
del df_xgb, df_lgbm, df_cat, df_selected, df

# %%
# X_reduced, feature_ranking = select_important_features(
#     train,
#     target,
#     top_n=100,                # or None to use cumulative 95%
#     use_shap=True,            # optional, slower but more accurate
#     remove_correlated=True,
#     correlation_threshold=0.95
# )

# %%
X_train_reduced = X_train[selected_feature_list]
X_valid_reduced = X_valid[selected_feature_list]
X_tune_reduced = X_tune[selected_feature_list]

# %% [markdown]
# ### 2.1. XGBoost

# %%
model_xgboost_reduced, best_params_xgboost_reduced, hist_df, plot_paths = train_xgb_optuna(X_train_reduced, y_train, X_tune_reduced, y_tune, X_valid_reduced, y_valid, n_trials=30)
evaluate_and_log(model_xgboost_reduced, X_valid_reduced, y_valid, experiment_name=EXPERIMENT_NAME, run_name="XGBoost_Optuna_Reduced", hp_search_history=hist_df, hp_search_plots= plot_paths)
evaluate_and_log(model_xgboost_reduced, X_valid_reduced, y_valid, experiment_name=EXPERIMENT_NAME, run_name="XGBoost_Optuna_Reduced", hp_search_history=hist_df, hp_search_plots= plot_paths, prediction_threshold=0.25)

# %%
threshOpt, minScore = minimize_eval_metric_with_threshold(model_xgboost_reduced, X_valid_reduced, y_valid)
print(f"Optimal threshold: {threshOpt}, Minimum eval metric score: {minScore}")
evaluate_and_log(
    model_xgboost_reduced, 
    X_valid_reduced, y_valid,
    experiment_name=EXPERIMENT_NAME, run_name="XGBoost_Optuna_Reduced", 
    hp_search_history=hist_df, hp_search_plots= plot_paths, 
    prediction_threshold=threshOpt)

# %% [markdown]
# ### 2.2. LightGBM

# %%
model_lgmb_reduced, best_params_lgmb_reduced, hist_df, plot_paths = train_lgbm_optuna(X_train_reduced, y_train, X_tune_reduced, y_tune, X_valid_reduced, y_valid, n_trials=30)
evaluate_and_log(model_lgmb_reduced, X_valid_reduced, y_valid, experiment_name=EXPERIMENT_NAME, run_name="LGBM_Optuna_Reduced", hp_search_history=hist_df, hp_search_plots= plot_paths)
evaluate_and_log(model_lgmb_reduced, X_valid_reduced, y_valid, experiment_name=EXPERIMENT_NAME, run_name="LGBM_Optuna_Reduced", hp_search_history=hist_df, hp_search_plots= plot_paths, prediction_threshold=0.25)

# %%
threshOpt, minScore = minimize_eval_metric_with_threshold(model_lgmb_reduced, X_valid_reduced, y_valid)
print(f"Optimal threshold: {threshOpt}, Minimum eval metric score: {minScore}")
evaluate_and_log(
    model_lgmb_reduced, 
    X_valid_reduced, y_valid,
    experiment_name=EXPERIMENT_NAME, run_name="LGBM_Optuna_Reduced", 
    hp_search_history=hist_df, hp_search_plots= plot_paths, 
    prediction_threshold=threshOpt)

# %% [markdown]
# ### 2.3. CatBoost

# %%
model_catoost_reduced, best_params_catoost_reduced, hist_df, plot_paths = train_catboost_optuna(X_train_reduced, y_train, X_tune_reduced, y_tune, X_valid_reduced, y_valid, n_trials=30)
evaluate_and_log(model_catoost_reduced, X_valid_reduced, y_valid, experiment_name=EXPERIMENT_NAME, run_name="CATBoost_Optuna_Reduced", hp_search_history=hist_df, hp_search_plots= plot_paths)
evaluate_and_log(model_catoost_reduced, X_valid_reduced, y_valid, experiment_name=EXPERIMENT_NAME, run_name="CATBoost_Optuna_Reduced", hp_search_history=hist_df, hp_search_plots= plot_paths, prediction_threshold=0.25)

# %%
threshOpt, minScore = minimize_eval_metric_with_threshold(model_catoost_reduced, X_valid_reduced, y_valid)
print(f"Optimal threshold: {threshOpt}, Minimum eval metric score: {minScore}")
evaluate_and_log(
    model_catoost_reduced, 
    X_valid_reduced, y_valid,
    experiment_name=EXPERIMENT_NAME, run_name="CATBoost_Optuna_Reduced", 
    hp_search_history=hist_df, hp_search_plots= plot_paths, 
    prediction_threshold=threshOpt)

# %% [markdown]
# ## 3. Ensemble

# %%
base_models, X_tr, X_va, y_tr, y_va, X_test, y_test, best_params_dict = train_best_base_models_from_mlflow(
    train, target, test_size=0.15 ,experiment_name=EXPERIMENT_NAME
)

# %% [markdown]
# ### 3.1. Logistic

# %%
ensemble, base_models, X_meta_va, y_va, X_meta_test, y_test, best_params_log, hist_df, plot_paths = train_ensemble(
    base_models, X_tr, y_tr, X_va, y_va, X_test, y_test, n_trials=50
)

# %%
evaluate_and_log(ensemble, pd.DataFrame(X_meta_va), y_va, experiment_name=EXPERIMENT_NAME, run_name="Ensemble_from_best_base_models", hp_search_history=hist_df)

# %% [markdown]
# ### 3.2. NN

# %%
nn_model, base_mdls, X_val, y_val, X_test, y_test, params, hist, plots = train_neural_network_ensemble(
    base_models=base_models,
    X_tr=X_tr,
    y_tr=y_tr,
    X_va=X_va,
    y_va=y_va,
    X_test=X_test,
    y_test=y_test,
    n_trials=30,
    epochs=100
)
