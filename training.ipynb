# %% [markdown]
# # Training

# %% [markdown]
# ## 0.Setup and data loading

# %%
import pandas as pd
import numpy as np
import os
import random

# ignore warnings
import warnings
warnings.filterwarnings('ignore')
from sklearn.model_selection import train_test_split


import importlib
import train_models_util
import feature_importance
importlib.reload(train_models_util)
importlib.reload(feature_importance)
from train_models_util import (
    train_xgb_optuna, 
    train_catboost_optuna, 
    train_lgbm_optuna,
    train_best_base_models_from_mlflow,
    train_ensemble, 
    train_neural_network_ensemble,
    train_tree_optuna,
    minimize_eval_metric_with_threshold
)
from evaluate_models_util import evaluate_and_log
from feature_importance import select_important_features, get_top_features_shap

# set all random seeds for reproducibility
np.random.seed(42)
random.seed(42)
os.environ['PYTHONHASHSEED'] = str(42)

# %%
EXPERIMENT_NAME = "Fraud-detection-custom-thresholds_v4"

# %%
data_folder = 'ieee-fraud-detection-data/processed/'

train = pd.read_csv(f'{data_folder}train_processed_v2.csv')
test = pd.read_csv(f'{data_folder}test_processed_v2.csv')
target = pd.read_csv(f'{data_folder}target.csv')['isFraud']

# %%
cat_cols = np.array(train.select_dtypes(include=['object']).columns)
for c in cat_cols:
    if c in train.columns:
        if train[c].isnull().sum()>0 or test[c].isnull().sum()>0:
            train[c].fillna('missing', inplace=True)
            test[c].fillna('missing', inplace=True)
        train[c] = train[c].astype('category')
        test[c] = test[c].astype('category')

# %%
#THIS IS WRONG
# # get all fraud samples
# fraud_indices = target[target == 1].index

# # sample 5× non-fraud, without replacement
# non_fraud_indices = target[target == 0].sample(
#     n=len(fraud_indices) * 3,
#     random_state=42
# ).index

# # build tuning dataset
# X_tune = pd.concat([train.loc[fraud_indices], train.loc[non_fraud_indices]], axis=0)
# y_tune = pd.concat([target.loc[fraud_indices], target.loc[non_fraud_indices]], axis=0)

# %%
X_train, X_valid, y_train, y_valid = train_test_split(train, target, test_size=0.2, stratify=target, random_state=42)

# %%
# attempt without suffle, since the data have time relation
n = len(train)
split_idx = int(n * 0.8)  # 4/5 split

X_train = train.iloc[:split_idx]
y_train = target.iloc[:split_idx]
X_valid = train.iloc[split_idx:]
y_valid = target.iloc[split_idx:]

# %%
# X_train.shape, X_valid.shape, X_tune.shape

# %%
del train, target, cat_cols, c #,fraud_indices, non_fraud_indices,
import gc
gc.collect()
# Out:
# 0

# %% [markdown]
# ## 1. Full Features

# %% [markdown]
# ### 1.1. XGBoost

# %%
model_xgboost_full, best_params_xgboost_full, hist_df, plot_paths = train_xgb_optuna(X_train, y_train, X_train, y_train, X_valid, y_valid, early_stopping_rounds=10)
# Out:
# [I 2025-12-03 13:01:06,000] A new study created in memory with name: xgboost_aucpr_optimization
# [Optuna XGBoost Tuning]:   0%|          | 0/30 [00:00<?, ?trial/s]
# [I 2025-12-03 13:13:13,294] Trial 0 finished with value: 0.8034715417912341 and parameters: {'learning_rate': 0.06351859523582477, 'max_depth': 8, 'subsample': 0.7990546947720916, 'colsample_bytree': 0.9854291579747783, 'min_child_weight': 0.15636535087214387, 'gamma': 4.092943669386593}. Best is trial 0 with value: 0.8034715417912341.
# [I 2025-12-03 13:27:04,273] Trial 1 finished with value: 0.7884827439603921 and parameters: {'learning_rate': 0.022237919610860628, 'max_depth': 11, 'subsample': 0.8237868227162372, 'colsample_bytree': 0.5710071333115424, 'min_child_weight': 0.0044403694771470645, 'gamma': 2.779188981370297}. Best is trial 0 with value: 0.8034715417912341.
# [I 2025-12-03 13:47:04,012] Trial 2 finished with value: 0.8023025556503861 and parameters: {'learning_rate': 0.013218862325441748, 'max_depth': 15, 'subsample': 0.8369021010467927, 'colsample_bytree': 0.5487872129835882, 'min_child_weight': 0.07754257335544931, 'gamma': 1.370402483783415}. Best is trial 0 with value: 0.8034715417912341.
# [I 2025-12-03 13:54:59,840] Trial 3 finished with value: 0.8581520856675843 and parameters: {'learning_rate': 0.18561773310692908, 'max_depth': 14, 'subsample': 0.8264473502113829, 'colsample_bytree': 0.9036303380439368, 'min_child_weight': 0.0017740639708053558, 'gamma': 1.53406959039868}. Best is trial 3 with value: 0.8581520856675843.
# [I 2025-12-03 14:03:39,485] Trial 4 finished with value: 0.8543129531811727 and parameters: {'learning_rate': 0.20913207541456727, 'max_depth': 12, 'subsample': 0.7891410224985445, 'colsample_bytree': 0.9643960862631964, 'min_child_weight': 0.0037450751278799983, 'gamma': 2.0596612016218216}. Best is trial 3 with value: 0.8581520856675843.
# [I 2025-12-03 14:16:20,117] Trial 5 finished with value: 0.8449201129358 and parameters: {'learning_rate': 0.0918205611213589, 'max_depth': 10, 'subsample': 0.6251379068970381, 'colsample_bytree': 0.8930494484037284, 'min_child_weight': 0.6016304357509109, 'gamma': 3.8783282918297033}. Best is trial 3 with value: 0.8581520856675843.
# [I 2025-12-03 14:34:34,004] Trial 6 finished with value: 0.7851924344860732 and parameters: {'learning_rate': 0.014032288643102795, 'max_depth': 14, 'subsample': 0.5561215778390403, 'colsample_bytree': 0.659126287910015, 'min_child_weight': 0.0015955496939406785, 'gamma': 1.2494475961821228}. Best is trial 3 with value: 0.8581520856675843.
# [I 2025-12-03 14:53:03,472] Trial 7 finished with value: 0.8256239591600162 and parameters: {'learning_rate': 0.026961241595516217, 'max_depth': 15, 'subsample': 0.5737531068600763, 'colsample_bytree': 0.8964601942573381, 'min_child_weight': 0.004899545922855637, 'gamma': 3.6988400300318176}. Best is trial 3 with value: 0.8581520856675843.
# [I 2025-12-03 15:06:11,773] Trial 8 finished with value: 0.7895758585439977 and parameters: {'learning_rate': 0.02995689392501486, 'max_depth': 10, 'subsample': 0.6653089311036964, 'colsample_bytree': 0.9643164691979964, 'min_child_weight': 0.002850632033904762, 'gamma': 4.63811122611424}. Best is trial 3 with value: 0.8581520856675843.
# [I 2025-12-03 15:15:56,784] Trial 9 finished with value: 0.6727610497921609 and parameters: {'learning_rate': 0.011662202274274558, 'max_depth': 10, 'subsample': 0.9602840010014956, 'colsample_bytree': 0.7305475651928774, 'min_child_weight': 0.26076641077523455, 'gamma': 3.101115800969237}. Best is trial 3 with value: 0.8581520856675843.
# [I 2025-12-03 15:24:16,799] Trial 10 finished with value: 0.8679815362613666 and parameters: {'learning_rate': 0.283018821119661, 'max_depth': 13, 'subsample': 0.9605653715816632, 'colsample_bytree': 0.819959088297679, 'min_child_weight': 0.018767011336879642, 'gamma': 0.19162314199430464}. Best is trial 10 with value: 0.8679815362613666.
# [I 2025-12-03 15:33:31,661] Trial 11 finished with value: 0.8715011468458166 and parameters: {'learning_rate': 0.28755119982955424, 'max_depth': 13, 'subsample': 0.991784701371311, 'colsample_bytree': 0.8124742406895379, 'min_child_weight': 0.019166454073151668, 'gamma': 0.08199796755408603}. Best is trial 11 with value: 0.8715011468458166.
# [I 2025-12-03 15:45:52,375] Trial 12 finished with value: 0.8775466461444988 and parameters: {'learning_rate': 0.2602340610204441, 'max_depth': 13, 'subsample': 0.9725755739435947, 'colsample_bytree': 0.8017297782470512, 'min_child_weight': 0.019702510747035724, 'gamma': 0.019470106922508487}. Best is trial 12 with value: 0.8775466461444988.
# [I 2025-12-03 16:00:47,839] Trial 13 finished with value: 0.8710465912320636 and parameters: {'learning_rate': 0.11798346271353312, 'max_depth': 12, 'subsample': 0.9941701432395025, 'colsample_bytree': 0.774818262222704, 'min_child_weight': 0.020313259663073145, 'gamma': 0.01877916194600222}. Best is trial 12 with value: 0.8775466461444988.
# [I 2025-12-03 16:07:10,984] Trial 14 finished with value: 0.8560225032796107 and parameters: {'learning_rate': 0.29496839901026634, 'max_depth': 13, 'subsample': 0.9038145568349804, 'colsample_bytree': 0.7040385159990286, 'min_child_weight': 0.04609306539182065, 'gamma': 0.7235257080682904}. Best is trial 12 with value: 0.8775466461444988.
# [I 2025-12-03 16:20:17,934] Trial 15 finished with value: 0.8716078035605966 and parameters: {'learning_rate': 0.12647889299552897, 'max_depth': 13, 'subsample': 0.9048411354876436, 'colsample_bytree': 0.8177643526119559, 'min_child_weight': 0.009830453792417412, 'gamma': 0.5335685281047043}. Best is trial 12 with value: 0.8775466461444988.
# [I 2025-12-03 16:32:37,661] Trial 16 finished with value: 0.8694609197772495 and parameters: {'learning_rate': 0.1312904437291831, 'max_depth': 14, 'subsample': 0.8952508635963295, 'colsample_bytree': 0.6631556576445534, 'min_child_weight': 0.009674811504558244, 'gamma': 0.6399186091137342}. Best is trial 12 with value: 0.8775466461444988.
# [I 2025-12-03 16:46:45,276] Trial 17 finished with value: 0.8489035056365863 and parameters: {'learning_rate': 0.06030344188085811, 'max_depth': 11, 'subsample': 0.734479853199244, 'colsample_bytree': 0.846458611459889, 'min_child_weight': 0.007992631891232177, 'gamma': 2.118525933823217}. Best is trial 12 with value: 0.8775466461444988.
# [I 2025-12-03 16:58:01,100] Trial 18 finished with value: 0.846011656678789 and parameters: {'learning_rate': 0.16101423561440728, 'max_depth': 8, 'subsample': 0.8916281374905736, 'colsample_bytree': 0.7719890637045247, 'min_child_weight': 0.04230361032159225, 'gamma': 0.7674913164249524}. Best is trial 12 with value: 0.8775466461444988.
# [I 2025-12-03 17:11:36,998] Trial 19 finished with value: 0.8673154689159824 and parameters: {'learning_rate': 0.08516229644626058, 'max_depth': 12, 'subsample': 0.9192063439083414, 'colsample_bytree': 0.6324581666998027, 'min_child_weight': 0.010441880556530498, 'gamma': 1.7922679466920124}. Best is trial 12 with value: 0.8775466461444988.
# [I 2025-12-03 17:28:42,474] Trial 20 finished with value: 0.8453055361049687 and parameters: {'learning_rate': 0.04146425380425246, 'max_depth': 13, 'subsample': 0.7202604804769789, 'colsample_bytree': 0.8509038499182747, 'min_child_weight': 0.09202701145884187, 'gamma': 0.97874099531678}. Best is trial 12 with value: 0.8775466461444988.
# [I 2025-12-03 17:36:32,613] Trial 21 finished with value: 0.8681732183465546 and parameters: {'learning_rate': 0.2431805907889491, 'max_depth': 13, 'subsample': 0.9974352944083946, 'colsample_bytree': 0.8040509948376224, 'min_child_weight': 0.020700456451980122, 'gamma': 0.3273356978832523}. Best is trial 12 with value: 0.8775466461444988.
# [I 2025-12-03 17:46:59,584] Trial 22 finished with value: 0.871060247868786 and parameters: {'learning_rate': 0.16068639304289356, 'max_depth': 14, 'subsample': 0.941295200392328, 'colsample_bytree': 0.7428065400123651, 'min_child_weight': 0.014450313665839265, 'gamma': 0.4265559906014723}. Best is trial 12 with value: 0.8775466461444988.
# [I 2025-12-03 18:03:01,744] Trial 23 finished with value: 0.8756619789490815 and parameters: {'learning_rate': 0.11395009368075967, 'max_depth': 13, 'subsample': 0.9970384315788985, 'colsample_bytree': 0.8541427490924246, 'min_child_weight': 0.033570025820864206, 'gamma': 0.05187203426097514}. Best is trial 12 with value: 0.8775466461444988.
# [I 2025-12-03 18:16:58,305] Trial 24 finished with value: 0.8698167709776534 and parameters: {'learning_rate': 0.10074946108677937, 'max_depth': 12, 'subsample': 0.8653887994244981, 'colsample_bytree': 0.8585699496918021, 'min_child_weight': 0.04642864120256105, 'gamma': 1.0467255063590006}. Best is trial 12 with value: 0.8775466461444988.
# [I 2025-12-03 18:34:12,465] Trial 25 finished with value: 0.8722620431325742 and parameters: {'learning_rate': 0.07375811534502232, 'max_depth': 15, 'subsample': 0.9404976139773953, 'colsample_bytree': 0.9196369935148001, 'min_child_weight': 0.02922131496921257, 'gamma': 0.520334901754181}. Best is trial 12 with value: 0.8775466461444988.
# [I 2025-12-03 18:52:04,110] Trial 26 finished with value: 0.8719650040798554 and parameters: {'learning_rate': 0.07458729231339176, 'max_depth': 14, 'subsample': 0.9456479744405651, 'colsample_bytree': 0.9316128942433973, 'min_child_weight': 0.0998121482968785, 'gamma': 0.11061376178627746}. Best is trial 12 with value: 0.8775466461444988.
# [I 2025-12-03 19:11:07,700] Trial 27 finished with value: 0.8473430374794574 and parameters: {'learning_rate': 0.03526289105410645, 'max_depth': 15, 'subsample': 0.8622927497957689, 'colsample_bytree': 0.9304019561845652, 'min_child_weight': 0.03374462819952789, 'gamma': 0.9911673102936981}. Best is trial 12 with value: 0.8775466461444988.
# [I 2025-12-03 19:28:12,796] Trial 28 finished with value: 0.8606203715845334 and parameters: {'learning_rate': 0.05108228360563072, 'max_depth': 15, 'subsample': 0.9602486110132277, 'colsample_bytree': 0.8725589936408947, 'min_child_weight': 0.23306526769723535, 'gamma': 1.627372466105117}. Best is trial 12 with value: 0.8775466461444988.
# [I 2025-12-03 19:41:59,383] Trial 29 finished with value: 0.8383942441153689 and parameters: {'learning_rate': 0.04995357913984728, 'max_depth': 11, 'subsample': 0.7766383174031695, 'colsample_bytree': 0.9780546172573458, 'min_child_weight': 0.0652574886742242, 'gamma': 2.5303432265770445}. Best is trial 12 with value: 0.8775466461444988.
# [INFO] Best XGBoost params: {'learning_rate': 0.2602340610204441, 'max_depth': 13, 'subsample': 0.9725755739435947, 'colsample_bytree': 0.8017297782470512, 'min_child_weight': 0.019702510747035724, 'gamma': 0.019470106922508487}

# %%
evaluate_and_log(model_xgboost_full, X_valid, y_valid, experiment_name=EXPERIMENT_NAME, run_name="XGBoost_Optuna_fullfeatures", hp_search_history=hist_df, hp_search_plots= plot_paths)
# Out:
# 2025/12/03 19:46:35 INFO mlflow.tracking.fluent: Experiment with name 'Fraud-detection-custom-thresholds_v3' does not exist. Creating a new experiment.
# [INFO] Logged metrics: {'roc_auc': np.float64(0.9776125288426118), 'pr_auc': np.float64(0.9155361043373691), 'precision': 0.9602763385146805, 'recall': 0.8071618678925719, 'f1': 0.877086893650585, 'custom_loss': np.float64(0.6759745317844684)}
# [INFO] Logged SHAP summary plot.
# 2025/12/03 19:47:05 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# [INFO] Evaluation complete and logged.
# {'roc_auc': np.float64(0.9776125288426118),
#  'pr_auc': np.float64(0.9155361043373691),
#  'precision': 0.9602763385146805,
#  'recall': 0.8071618678925719,
#  'f1': 0.877086893650585,
#  'custom_loss': np.float64(0.6759745317844684)}

# %%
evaluate_and_log(model_xgboost_full,  X_valid, y_valid, experiment_name=EXPERIMENT_NAME, run_name="XGBoost_Optuna_fullfeatures", hp_search_history=hist_df, hp_search_plots= plot_paths, prediction_threshold=0.25)
# Out:
# [INFO] Logged metrics: {'roc_auc': np.float64(0.9776125288426118), 'pr_auc': np.float64(0.9155361043373691), 'precision': 0.9372464160129835, 'recall': 0.838374062424389, 'f1': 0.8850574712643678, 'custom_loss': np.float64(0.5675483455820097)}
# [INFO] Logged SHAP summary plot.
# 2025/12/03 19:47:29 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# [INFO] Evaluation complete and logged.
# {'roc_auc': np.float64(0.9776125288426118),
#  'pr_auc': np.float64(0.9155361043373691),
#  'precision': 0.9372464160129835,
#  'recall': 0.838374062424389,
#  'f1': 0.8850574712643678,
#  'custom_loss': np.float64(0.5675483455820097)}

# %%
evaluate_and_log(model_xgboost_full, X_valid, y_valid, experiment_name=EXPERIMENT_NAME, run_name="XGBoost_Optuna_fullfeatures", hp_search_history=hist_df, hp_search_plots= plot_paths, prediction_threshold=0.10)
# Out:
# [INFO] Logged metrics: {'roc_auc': np.float64(0.9776125288426118), 'pr_auc': np.float64(0.9155361043373691), 'precision': 0.8937875751503006, 'recall': 0.8632954270505686, 'f1': 0.8782769230769231, 'custom_loss': np.float64(0.4819656585498019)}
# [INFO] Logged SHAP summary plot.
# 2025/12/03 19:47:53 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# [INFO] Evaluation complete and logged.
# {'roc_auc': np.float64(0.9776125288426118),
#  'pr_auc': np.float64(0.9155361043373691),
#  'precision': 0.8937875751503006,
#  'recall': 0.8632954270505686,
#  'f1': 0.8782769230769231,
#  'custom_loss': np.float64(0.4819656585498019)}

# %%
threshOpt, minScore = minimize_eval_metric_with_threshold(model_xgboost_full,  X_valid, y_valid)
print(f"Optimal threshold: {threshOpt}, Minimum eval metric score: {minScore}")
evaluate_and_log(model_xgboost_full,  X_valid, y_valid, experiment_name=EXPERIMENT_NAME, run_name="XGBoost_Optuna_fullfeatures", hp_search_history=hist_df, hp_search_plots= plot_paths, prediction_threshold=threshOpt)
# Out:
# Optimal threshold: 9.81056746240938e-06, Minimum eval metric score: 0.6068598232126529
# [INFO] Logged metrics: {'roc_auc': np.float64(0.9776125288426118), 'pr_auc': np.float64(0.9155361043373691), 'precision': 0.05716401643238409, 'recall': 0.9898378901524316, 'f1': 0.10808597207360732, 'custom_loss': np.float64(0.6068598232126529)}
# [INFO] Logged SHAP summary plot.
# 2025/12/03 19:48:19 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# [INFO] Evaluation complete and logged.
# {'roc_auc': np.float64(0.9776125288426118),
#  'pr_auc': np.float64(0.9155361043373691),
#  'precision': 0.05716401643238409,
#  'recall': 0.9898378901524316,
#  'f1': 0.10808597207360732,
#  'custom_loss': np.float64(0.6068598232126529)}

# %% [markdown]
# ### 1.2. LightGBM

# %%
model_lgbm_full, best_params_lgbm_full, hist_df, plot_paths = train_lgbm_optuna(X_train, y_train,  X_train, y_train, X_valid, y_valid)
# Out:
# [I 2025-12-03 19:48:19,884] A new study created in memory with name: lgbm_aucpr_optimization
# [Optuna LightGBM Tuning]:   0%|          | 0/30 [00:00<?, ?trial/s]
# [I 2025-12-03 19:49:30,356] Trial 0 finished with value: 0.3319401356684155 and parameters: {'num_leaves': 93, 'max_depth': 17, 'learning_rate': 0.07093807431566478, 'feature_fraction': 0.6620839099624509, 'bagging_fraction': 0.9585739569476259, 'bagging_freq': 1, 'min_child_samples': 71, 'lambda_l1': 6.203166917167362e-07, 'lambda_l2': 1.0756584701882994}. Best is trial 0 with value: 0.3319401356684155.
# [I 2025-12-03 19:50:50,754] Trial 1 finished with value: 0.5216533742761759 and parameters: {'num_leaves': 200, 'max_depth': 20, 'learning_rate': 0.02213942620784039, 'feature_fraction': 0.7084122784116766, 'bagging_fraction': 0.6510218495056791, 'bagging_freq': 10, 'min_child_samples': 85, 'lambda_l1': 2.1877029533874874, 'lambda_l2': 1.529226632695873e-06}. Best is trial 1 with value: 0.5216533742761759.
# [I 2025-12-03 19:52:05,705] Trial 2 finished with value: 0.41466368682952776 and parameters: {'num_leaves': 169, 'max_depth': 18, 'learning_rate': 0.04532759025006359, 'feature_fraction': 0.7392225181778753, 'bagging_fraction': 0.6631610389676615, 'bagging_freq': 9, 'min_child_samples': 65, 'lambda_l1': 6.999115321095934e-06, 'lambda_l2': 2.9138916689886513e-05}. Best is trial 1 with value: 0.5216533742761759.
# [I 2025-12-03 19:53:15,238] Trial 3 finished with value: 0.46527460780749047 and parameters: {'num_leaves': 89, 'max_depth': 15, 'learning_rate': 0.014325993712017525, 'feature_fraction': 0.8991355346598835, 'bagging_fraction': 0.613808350529795, 'bagging_freq': 6, 'min_child_samples': 67, 'lambda_l1': 1.370428170083542, 'lambda_l2': 3.0581059760519915}. Best is trial 1 with value: 0.5216533742761759.
# [I 2025-12-03 19:54:56,465] Trial 4 finished with value: 0.5632177250079126 and parameters: {'num_leaves': 226, 'max_depth': 13, 'learning_rate': 0.012386275753916366, 'feature_fraction': 0.8639077193997138, 'bagging_fraction': 0.9196933078179506, 'bagging_freq': 8, 'min_child_samples': 74, 'lambda_l1': 5.4558466748863e-07, 'lambda_l2': 0.0035849946558852925}. Best is trial 4 with value: 0.5632177250079126.
# [I 2025-12-03 19:56:02,412] Trial 5 finished with value: 0.4457024986732081 and parameters: {'num_leaves': 79, 'max_depth': 16, 'learning_rate': 0.02199793372430566, 'feature_fraction': 0.6036093050873635, 'bagging_fraction': 0.8870168282913238, 'bagging_freq': 10, 'min_child_samples': 41, 'lambda_l1': 0.7349835206480803, 'lambda_l2': 0.00042706869918888735}. Best is trial 4 with value: 0.5632177250079126.
# [I 2025-12-03 21:03:52,506] Trial 28 finished with value: 0.3110094757417237 and parameters: {'num_leaves': 243, 'max_depth': 16, 'learning_rate': 0.1100747809193384, 'feature_fraction': 0.7214939725248732, 'bagging_fraction': 0.812986952091851, 'bagging_freq': 4, 'min_child_samples': 50, 'lambda_l1': 0.0019522700794633158, 'lambda_l2': 8.51465678646764}. Best is trial 23 with value: 0.8703922246129739.
# [I 2025-12-03 21:05:08,560] Trial 29 finished with value: 0.34618513120112754 and parameters: {'num_leaves': 125, 'max_depth': 17, 'learning_rate': 0.07042538150432658, 'feature_fraction': 0.8842495076770942, 'bagging_fraction': 0.974632790624779, 'bagging_freq': 1, 'min_child_samples': 36, 'lambda_l1': 6.701143755998958e-05, 'lambda_l2': 0.9936130937999769}. Best is trial 23 with value: 0.8703922246129739.
# [INFO] Best LightGBM params: {'num_leaves': 223, 'max_depth': 17, 'learning_rate': 0.15088674011896516, 'feature_fraction': 0.831066537674629, 'bagging_fraction': 0.8289232036486788, 'bagging_freq': 3, 'min_child_samples': 33, 'lambda_l1': 1.149923805979539e-08, 'lambda_l2': 9.19036820301362}

# %%
evaluate_and_log(model_lgbm_full,  X_valid, y_valid, experiment_name=EXPERIMENT_NAME, run_name="LightGBM_Optuna_fullfeatures", hp_search_history=hist_df, hp_search_plots= plot_paths)
# Out:
# [INFO] Logged metrics: {'roc_auc': np.float64(0.9788393197514088), 'pr_auc': np.float64(0.9141876469570723), 'precision': 0.9267379679144385, 'recall': 0.8386160174207598, 'f1': 0.8804775816080275, 'custom_loss': np.float64(0.5670572696176381)}
# [INFO] Logged SHAP summary plot.
# 2025/12/03 21:08:28 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# [INFO] Evaluation complete and logged.
# {'roc_auc': np.float64(0.9788393197514088),
#  'pr_auc': np.float64(0.9141876469570723),
#  'precision': 0.9267379679144385,
#  'recall': 0.8386160174207598,
#  'f1': 0.8804775816080275,
#  'custom_loss': np.float64(0.5670572696176381)}

# %%
evaluate_and_log(model_lgbm_full, X_valid, y_valid, experiment_name=EXPERIMENT_NAME, run_name="LightGBM_Optuna_fullfeatures", hp_search_history=hist_df, hp_search_plots= plot_paths, prediction_threshold=0.25)
# Out:
# [INFO] Logged metrics: {'roc_auc': np.float64(0.9788393197514088), 'pr_auc': np.float64(0.9141876469570723), 'precision': 0.8531567746512178, 'recall': 0.8729736269053956, 'f1': 0.8629514470222435, 'custom_loss': np.float64(0.4497663155755749)}
# [INFO] Logged SHAP summary plot.
# 2025/12/03 21:08:53 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# [INFO] Evaluation complete and logged.
# {'roc_auc': np.float64(0.9788393197514088),
#  'pr_auc': np.float64(0.9141876469570723),
#  'precision': 0.8531567746512178,
#  'recall': 0.8729736269053956,
#  'f1': 0.8629514470222435,
#  'custom_loss': np.float64(0.4497663155755749)}

# %%
evaluate_and_log(model_lgbm_full, X_valid, y_valid, experiment_name=EXPERIMENT_NAME, run_name="LightGBM_Optuna_fullfeatures", hp_search_history=hist_df, hp_search_plots= plot_paths, prediction_threshold=0.10)
# Out:
# [INFO] Logged metrics: {'roc_auc': np.float64(0.9788393197514088), 'pr_auc': np.float64(0.9141876469570723), 'precision': 0.713874496257916, 'recall': 0.9000725864989112, 'f1': 0.7962328767123288, 'custom_loss': np.float64(0.36230399295559995)}
# [INFO] Logged SHAP summary plot.
# 2025/12/03 21:09:19 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# [INFO] Evaluation complete and logged.
# {'roc_auc': np.float64(0.9788393197514088),
#  'pr_auc': np.float64(0.9141876469570723),
#  'precision': 0.713874496257916,
#  'recall': 0.9000725864989112,
#  'f1': 0.7962328767123288,
#  'custom_loss': np.float64(0.36230399295559995)}

# %%
threshOpt, minScore = minimize_eval_metric_with_threshold(model_lgbm_full, X_valid, y_valid)
print(f"Optimal threshold: {threshOpt}, Minimum eval metric score: {minScore}")
evaluate_and_log(
    model_lgbm_full, 
    X_valid, y_valid, 
    experiment_name=EXPERIMENT_NAME, 
    run_name="LightGBM_Optuna_fullfeatures", 
    hp_search_history=hist_df, hp_search_plots=plot_paths, 
    prediction_threshold=threshOpt)
# Out:
# Optimal threshold: 0.00036546924429878806, Minimum eval metric score: 0.45168828529820165
# [INFO] Logged metrics: {'roc_auc': np.float64(0.9788393197514088), 'pr_auc': np.float64(0.9141876469570723), 'precision': 0.08116863639090527, 'recall': 0.9820953302685701, 'f1': 0.14994458810491318, 'custom_loss': np.float64(0.45168828529820165)}
# [INFO] Logged SHAP summary plot.
# 2025/12/03 21:09:48 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# [INFO] Evaluation complete and logged.
# {'roc_auc': np.float64(0.9788393197514088),
#  'pr_auc': np.float64(0.9141876469570723),
#  'precision': 0.08116863639090527,
#  'recall': 0.9820953302685701,
#  'f1': 0.14994458810491318,
#  'custom_loss': np.float64(0.45168828529820165)}

# %% [markdown]
# ### 1.3. CatBoost

# %%
model_catboost_full, best_params_catboost_full, hist_df, plot_paths = train_catboost_optuna(X_train, y_train, X_train, y_train, X_valid, y_valid, early_stopping_rounds=10)
# Out:
# [I 2025-12-03 21:09:49,180] A new study created in memory with name: catboost_aucpr_optimization
# [Optuna CatBoost Tuning]:   0%|          | 0/30 [00:00<?, ?trial/s]
# [I 2025-12-03 21:25:32,012] Trial 0 finished with value: 0.6735109695200783 and parameters: {'learning_rate': 0.1352067011736096, 'depth': 6, 'l2_leaf_reg': 9.312047419398002, 'subsample': 0.6056104761067427, 'border_count': 89}. Best is trial 0 with value: 0.6735109695200783.
# [I 2025-12-03 21:40:38,945] Trial 1 finished with value: 0.612243164834815 and parameters: {'learning_rate': 0.07433624068979262, 'depth': 5, 'l2_leaf_reg': 7.839162424805284, 'subsample': 0.93837684206264, 'border_count': 105}. Best is trial 0 with value: 0.6735109695200783.
# [I 2025-12-03 21:55:44,569] Trial 2 finished with value: 0.609077497106695 and parameters: {'learning_rate': 0.07079394232890084, 'depth': 5, 'l2_leaf_reg': 5.904048410274738, 'subsample': 0.849773853043581, 'border_count': 117}. Best is trial 0 with value: 0.6735109695200783.
# [I 2025-12-03 22:10:23,482] Trial 3 finished with value: 0.6877021688121393 and parameters: {'learning_rate': 0.23289563857859136, 'depth': 5, 'l2_leaf_reg': 2.222836016022129, 'subsample': 0.7719377322905613, 'border_count': 121}. Best is trial 3 with value: 0.6877021688121393.
# [I 2025-12-03 22:23:39,974] Trial 4 finished with value: 0.5948082670996753 and parameters: {'learning_rate': 0.06806477850958086, 'depth': 5, 'l2_leaf_reg': 9.623534454573807, 'subsample': 0.6153643853461781, 'border_count': 77}. Best is trial 3 with value: 0.6877021688121393.
# [I 2025-12-03 22:45:04,869] Trial 5 finished with value: 0.7623275996138 and parameters: {'learning_rate': 0.231792553058083, 'depth': 7, 'l2_leaf_reg': 6.17613281226378, 'subsample': 0.8556572842455992, 'border_count': 94}. Best is trial 5 with value: 0.7623275996138.
# [I 2025-12-04 12:22:21,632] Trial 28 finished with value: 0.7999493295845381 and parameters: {'learning_rate': 0.22594301877037504, 'depth': 8, 'l2_leaf_reg': 2.5881212509940945, 'subsample': 0.930637020302751, 'border_count': 113}. Best is trial 11 with value: 0.825327743232735.
# [I 2025-12-04 12:41:54,453] Trial 29 finished with value: 0.7078511661701881 and parameters: {'learning_rate': 0.14865681601637476, 'depth': 6, 'l2_leaf_reg': 1.729451462300806, 'subsample': 0.9536691849599678, 'border_count': 127}. Best is trial 11 with value: 0.825327743232735.
# [INFO] Best CatBoost params: {'learning_rate': 0.15013622966459636, 'depth': 10, 'l2_leaf_reg': 4.168068031663588, 'subsample': 0.8760510519082981, 'border_count': 89}

# %%
evaluate_and_log(model_catboost_full,  X_valid, y_valid, experiment_name=EXPERIMENT_NAME, run_name="CATboost_Optuna_fullfeatures", hp_search_history=hist_df, hp_search_plots= plot_paths)
# Out:
# [INFO] Logged metrics: {'roc_auc': np.float64(0.9766901628549776), 'pr_auc': np.float64(0.879964761240323), 'precision': 0.6898192197906755, 'recall': 0.8770868618436971, 'f1': 0.7722624627183639, 'custom_loss': np.float64(0.4439157381379754)}
# [INFO] Logged SHAP summary plot.
# 2025/12/04 13:19:42 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# [INFO] Evaluation complete and logged.
# {'roc_auc': np.float64(0.9766901628549776),
#  'pr_auc': np.float64(0.879964761240323),
#  'precision': 0.6898192197906755,
#  'recall': 0.8770868618436971,
#  'f1': 0.7722624627183639,
#  'custom_loss': np.float64(0.4439157381379754)}

# %%
evaluate_and_log(model_catboost_full,  X_valid, y_valid, experiment_name=EXPERIMENT_NAME, run_name="CATboost_Optuna_fullfeatures", hp_search_history=hist_df, hp_search_plots= plot_paths, prediction_threshold=0.25)
# Out:
# [INFO] Logged metrics: {'roc_auc': np.float64(0.9766901628549776), 'pr_auc': np.float64(0.879964761240323), 'precision': 0.4281403665623603, 'recall': 0.9269295910960561, 'f1': 0.585735035547741, 'custom_loss': np.float64(0.29902292816743997)}
# [INFO] Logged SHAP summary plot.
# 2025/12/04 13:21:09 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# [INFO] Evaluation complete and logged.
# {'roc_auc': np.float64(0.9766901628549776),
#  'pr_auc': np.float64(0.879964761240323),
#  'precision': 0.4281403665623603,
#  'recall': 0.9269295910960561,
#  'f1': 0.585735035547741,
#  'custom_loss': np.float64(0.29902292816743997)}

# %%
evaluate_and_log(model_catboost_full,  X_valid, y_valid, experiment_name=EXPERIMENT_NAME, run_name="CATboost_Optuna_fullfeatures", hp_search_history=hist_df, hp_search_plots= plot_paths, prediction_threshold=0.1)
# Out:
# [INFO] Logged metrics: {'roc_auc': np.float64(0.9766901628549776), 'pr_auc': np.float64(0.879964761240323), 'precision': 0.21323887296522634, 'recall': 0.9540285506895717, 'f1': 0.3485678925035361, 'custom_loss': np.float64(0.2840451112541064)}
# [INFO] Logged SHAP summary plot.
# 2025/12/04 13:22:34 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# [INFO] Evaluation complete and logged.
# {'roc_auc': np.float64(0.9766901628549776),
#  'pr_auc': np.float64(0.879964761240323),
#  'precision': 0.21323887296522634,
#  'recall': 0.9540285506895717,
#  'f1': 0.3485678925035361,
#  'custom_loss': np.float64(0.2840451112541064)}

# %%
threshOpt, minScore = minimize_eval_metric_with_threshold(model_catboost_full,  X_valid, y_valid)
print(f"Optimal threshold: {threshOpt}, Minimum eval metric score: {minScore}")
evaluate_and_log(
    model_catboost_full, 
    X_valid, y_valid,
    experiment_name=EXPERIMENT_NAME, run_name="CATboost_Optuna_fullfeatures", 
    hp_search_history=hist_df, hp_search_plots= plot_paths, 
    prediction_threshold=threshOpt)
# Out:
# Optimal threshold: 0.04881344988467075, Minimum eval metric score: 0.3403071764825414
# [INFO] Logged metrics: {'roc_auc': np.float64(0.9766901628549776), 'pr_auc': np.float64(0.879964761240323), 'precision': 0.13187176016112523, 'recall': 0.9663682555044761, 'f1': 0.23207437536316095, 'custom_loss': np.float64(0.3403071764825414)}
# [INFO] Logged SHAP summary plot.
# 2025/12/04 13:24:05 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# [INFO] Evaluation complete and logged.
# {'roc_auc': np.float64(0.9766901628549776),
#  'pr_auc': np.float64(0.879964761240323),
#  'precision': 0.13187176016112523,
#  'recall': 0.9663682555044761,
#  'f1': 0.23207437536316095,
#  'custom_loss': np.float64(0.3403071764825414)}

# %% [markdown]
# ## 2. Reduced Features

# %%
# ---- 1. Compute SHAP importance for each model ----
df_xgb = get_top_features_shap(model_xgboost_full, X_train, y_train).rename(
    columns={"importance": "importance_xgb"}
)
df_lgbm = get_top_features_shap(model_lgbm_full, X_train, y_train).rename(
    columns={"importance": "importance_lgbm"}
)
df_cat = get_top_features_shap(model_catboost_full, X_train, y_train).rename(
    columns={"importance": "importance_cat"}
)

# ---- 2. Merge all importance tables ----
df = (
    df_xgb.merge(df_lgbm, on="feature")
          .merge(df_cat, on="feature")
)

# ---- 3. Rank features within each model (1 = most important) ----
df["rank_xgb"] = df["importance_xgb"].rank(method="min", ascending=False)
df["rank_lgbm"] = df["importance_lgbm"].rank(method="min", ascending=False)
df["rank_cat"] = df["importance_cat"].rank(method="min", ascending=False)

# ---- 4. Determine the top 30% threshold ----
n_features = len(df)
top_30_cutoff = int(n_features * 0.30)

# ---- 5. Check if a feature appears in top 30% in each model ----
df["in_top_xgb"]  = df["rank_xgb"]  <= top_30_cutoff
df["in_top_lgbm"] = df["rank_lgbm"] <= top_30_cutoff
df["in_top_cat"]  = df["rank_cat"]  <= top_30_cutoff

# ---- 6. Apply the rule: “Top 30% for at least 2 models” ----
df["top_count"] = (
    df["in_top_xgb"].astype(int)
  + df["in_top_lgbm"].astype(int)
  + df["in_top_cat"].astype(int)
)

df_selected = df[df["top_count"] >= 2]  # final selected features

# %%
# ---- 7. Sort by mean importance (optional but nice) ----
df_selected["importance_mean"] = df_selected[["importance_xgb","importance_lgbm","importance_cat"]].mean(axis=1)
df_selected = df_selected.sort_values("importance_mean", ascending=False)

# ---- 8. Save to CSV ----
df.to_csv(f"{data_folder}/feature_importances_shap_fullmodels.csv", index=False)
df_selected.to_csv(f"{data_folder}/selected_features_shap.csv", index=False)

# ---- 9. List of selected feature names ----
selected_feature_list = df_selected["feature"].tolist()

# %%
del df_xgb, df_lgbm, df_cat, df_selected, df

# %%
# X_reduced, feature_ranking = select_important_features(
#     train,
#     target,
#     top_n=100,                # or None to use cumulative 95%
#     use_shap=True,            # optional, slower but more accurate
#     remove_correlated=True,
#     correlation_threshold=0.95
# )

# %%
X_train_reduced = X_train[selected_feature_list]
X_valid_reduced = X_valid[selected_feature_list]
# X_tune_reduced = X_tune[selected_feature_list]

# %%
X_train_reduced.shape, X_valid_reduced.shape#, X_tune_reduced.shape
# Out:
# ((472432, 204), (118108, 204))

# %% [markdown]
# ### 2.1. XGBoost

# %%
model_xgboost_reduced, best_params_xgboost_reduced, hist_df, plot_paths = train_xgb_optuna(X_train_reduced, y_train, X_train_reduced, y_train, X_valid_reduced, y_valid, n_trials=30)
evaluate_and_log(model_xgboost_reduced, X_valid_reduced, y_valid, experiment_name=EXPERIMENT_NAME, run_name="XGBoost_Optuna_Reduced", hp_search_history=hist_df, hp_search_plots= plot_paths)
evaluate_and_log(model_xgboost_reduced, X_valid_reduced, y_valid, experiment_name=EXPERIMENT_NAME, run_name="XGBoost_Optuna_Reduced", hp_search_history=hist_df, hp_search_plots= plot_paths, prediction_threshold=0.25)
# Out:
# [I 2025-12-04 13:36:01,918] A new study created in memory with name: xgboost_aucpr_optimization
# [Optuna XGBoost Tuning]:   0%|          | 0/30 [00:00<?, ?trial/s]
# [I 2025-12-04 13:42:13,065] Trial 0 finished with value: 0.8630463200053381 and parameters: {'learning_rate': 0.07176724745521722, 'max_depth': 14, 'subsample': 0.691345645851472, 'colsample_bytree': 0.6651480001823453, 'min_child_weight': 0.06023782199441705, 'gamma': 1.7370321473816035}. Best is trial 0 with value: 0.8630463200053381.
# [I 2025-12-04 13:46:41,587] Trial 1 finished with value: 0.8599377017077033 and parameters: {'learning_rate': 0.1457272701871864, 'max_depth': 12, 'subsample': 0.9341473866854714, 'colsample_bytree': 0.5789044790956329, 'min_child_weight': 0.0433759404138579, 'gamma': 2.7320366584200495}. Best is trial 0 with value: 0.8630463200053381.
# [I 2025-12-04 13:52:16,653] Trial 2 finished with value: 0.8735479778170822 and parameters: {'learning_rate': 0.1796242010672382, 'max_depth': 11, 'subsample': 0.8416375127681059, 'colsample_bytree': 0.9936583740935362, 'min_child_weight': 0.0439235111639909, 'gamma': 0.22590913518882538}. Best is trial 2 with value: 0.8735479778170822.
# [I 2025-12-04 13:57:11,341] Trial 3 finished with value: 0.7046446179521731 and parameters: {'learning_rate': 0.01276595848434439, 'max_depth': 9, 'subsample': 0.904644766956171, 'colsample_bytree': 0.5748246707914506, 'min_child_weight': 0.04295603208570904, 'gamma': 4.537390386191357}. Best is trial 2 with value: 0.8735479778170822.
# [I 2025-12-04 14:02:10,890] Trial 4 finished with value: 0.8347534575654629 and parameters: {'learning_rate': 0.056925172285526446, 'max_depth': 10, 'subsample': 0.9136626767293097, 'colsample_bytree': 0.6585580200710912, 'min_child_weight': 0.02466271104031565, 'gamma': 3.8767461154070966}. Best is trial 2 with value: 0.8735479778170822.
# [I 2025-12-04 14:07:12,271] Trial 5 finished with value: 0.8450585830484095 and parameters: {'learning_rate': 0.07355445674243596, 'max_depth': 10, 'subsample': 0.8131775866697647, 'colsample_bytree': 0.731075813824623, 'min_child_weight': 0.7532944271655405, 'gamma': 2.177451982069919}. Best is trial 2 with value: 0.8735479778170822.
# [I 2025-12-04 14:12:00,625] Trial 6 finished with value: 0.846389569147569 and parameters: {'learning_rate': 0.0917856951798278, 'max_depth': 9, 'subsample': 0.7794696683820466, 'colsample_bytree': 0.874787652629031, 'min_child_weight': 0.004383643959570209, 'gamma': 2.2481614855640193}. Best is trial 2 with value: 0.8735479778170822.
# [I 2025-12-04 14:17:28,984] Trial 7 finished with value: 0.8531318977107379 and parameters: {'learning_rate': 0.07830737968200369, 'max_depth': 11, 'subsample': 0.6337831578525718, 'colsample_bytree': 0.7310998542307083, 'min_child_weight': 0.004014644808820306, 'gamma': 2.2438339149022966}. Best is trial 2 with value: 0.8735479778170822.
# [I 2025-12-04 14:22:49,377] Trial 8 finished with value: 0.8708937382593988 and parameters: {'learning_rate': 0.10616946306120874, 'max_depth': 15, 'subsample': 0.9466084794998542, 'colsample_bytree': 0.5118832490941972, 'min_child_weight': 0.06336523824748584, 'gamma': 1.045613287821428}. Best is trial 2 with value: 0.8735479778170822.
# [I 2025-12-04 14:27:42,509] Trial 9 finished with value: 0.8591949264756268 and parameters: {'learning_rate': 0.09495650854134335, 'max_depth': 10, 'subsample': 0.8497313272289686, 'colsample_bytree': 0.6863750550344914, 'min_child_weight': 0.009493919354603819, 'gamma': 1.1441130262824935}. Best is trial 2 with value: 0.8735479778170822.
# [I 2025-12-04 14:33:22,481] Trial 10 finished with value: 0.8519168964603164 and parameters: {'learning_rate': 0.28970797573801305, 'max_depth': 13, 'subsample': 0.5156564868119247, 'colsample_bytree': 0.9679614347588797, 'min_child_weight': 0.36079984442605506, 'gamma': 0.010357484002749134}. Best is trial 2 with value: 0.8735479778170822.
# [I 2025-12-04 14:38:09,457] Trial 11 finished with value: 0.8738009881903449 and parameters: {'learning_rate': 0.24441741735611605, 'max_depth': 15, 'subsample': 0.9913182314112717, 'colsample_bytree': 0.8467031513603405, 'min_child_weight': 0.23542507654029604, 'gamma': 0.055564862334883836}. Best is trial 11 with value: 0.8738009881903449.
# [I 2025-12-04 14:42:30,541] Trial 12 finished with value: 0.871847511862399 and parameters: {'learning_rate': 0.28006579243741686, 'max_depth': 12, 'subsample': 0.9851293575811143, 'colsample_bytree': 0.8568646342339389, 'min_child_weight': 0.19673348744765778, 'gamma': 0.07925139403889206}. Best is trial 11 with value: 0.8738009881903449.
# [I 2025-12-04 14:51:27,100] Trial 13 finished with value: 0.8141899558341121 and parameters: {'learning_rate': 0.025101523566204032, 'max_depth': 15, 'subsample': 0.9976985150108947, 'colsample_bytree': 0.9989644477721686, 'min_child_weight': 0.16694287297539492, 'gamma': 0.7546985323650737}. Best is trial 11 with value: 0.8738009881903449.
# [I 2025-12-04 14:56:19,484] Trial 14 finished with value: 0.8617395590827543 and parameters: {'learning_rate': 0.1796698982777007, 'max_depth': 13, 'subsample': 0.7124076382963198, 'colsample_bytree': 0.9040103022953013, 'min_child_weight': 0.013385185024786481, 'gamma': 0.6350172234258649}. Best is trial 11 with value: 0.8738009881903449.
# [I 2025-12-04 15:00:26,296] Trial 15 finished with value: 0.8551914767155177 and parameters: {'learning_rate': 0.18428441198783826, 'max_depth': 8, 'subsample': 0.8716529581102206, 'colsample_bytree': 0.8143670322868507, 'min_child_weight': 0.0011209711142003682, 'gamma': 3.2559318929208447}. Best is trial 11 with value: 0.8738009881903449.
# [I 2025-12-04 15:54:13,156] Trial 26 finished with value: 0.8665043195926749 and parameters: {'learning_rate': 0.1256159092412826, 'max_depth': 10, 'subsample': 0.847812468591706, 'colsample_bytree': 0.8987022068538293, 'min_child_weight': 0.034430857288621004, 'gamma': 1.3234625206357038}. Best is trial 22 with value: 0.8754450963919588.
# [I 2025-12-04 15:58:15,792] Trial 27 finished with value: 0.8521994730407739 and parameters: {'learning_rate': 0.23294456969550437, 'max_depth': 13, 'subsample': 0.8857472900803097, 'colsample_bytree': 0.9951354211156122, 'min_child_weight': 0.9950406038362506, 'gamma': 1.8856358660365748}. Best is trial 22 with value: 0.8754450963919588.
# [I 2025-12-04 16:02:48,318] Trial 28 finished with value: 0.7773336938026403 and parameters: {'learning_rate': 0.04452213896125395, 'max_depth': 8, 'subsample': 0.8033695196821501, 'colsample_bytree': 0.9594863441120867, 'min_child_weight': 0.09496369425612841, 'gamma': 0.793693205371484}. Best is trial 22 with value: 0.8754450963919588.
# [I 2025-12-04 16:10:49,929] Trial 29 finished with value: 0.8694063636750721 and parameters: {'learning_rate': 0.060276158043403846, 'max_depth': 15, 'subsample': 0.9293527051195429, 'colsample_bytree': 0.8960839182455477, 'min_child_weight': 0.20787180956093249, 'gamma': 0.3410185262490484}. Best is trial 22 with value: 0.8754450963919588.
# [INFO] Best XGBoost params: {'learning_rate': 0.22200082505495905, 'max_depth': 11, 'subsample': 0.964424583105341, 'colsample_bytree': 0.994828611125093, 'min_child_weight': 0.0955612051839127, 'gamma': 0.08080617635702997}
# [INFO] Logged metrics: {'roc_auc': np.float64(0.9772594974500788), 'pr_auc': np.float64(0.9132602394981091), 'precision': 0.9518958687040181, 'recall': 0.8139366077909509, 'f1': 0.8775270640406939, 'custom_loss': np.float64(0.6525383547261828)}
# [INFO] Logged SHAP summary plot.
# 2025/12/04 16:14:10 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# [INFO] Evaluation complete and logged.
# [INFO] Logged metrics: {'roc_auc': np.float64(0.9772594974500788), 'pr_auc': np.float64(0.9132602394981091), 'precision': 0.9196639537936466, 'recall': 0.8475683522864748, 'f1': 0.8821455552757492, 'custom_loss': np.float64(0.5360009482846209)}
# [INFO] Logged SHAP summary plot.
# 2025/12/04 16:14:29 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# [INFO] Evaluation complete and logged.
# {'roc_auc': np.float64(0.9772594974500788),
#  'pr_auc': np.float64(0.9132602394981091),
#  'precision': 0.9196639537936466,
#  'recall': 0.8475683522864748,
#  'f1': 0.8821455552757492,
#  'custom_loss': np.float64(0.5360009482846209)}

# %%
threshOpt, minScore = minimize_eval_metric_with_threshold(model_xgboost_reduced, X_valid_reduced, y_valid)
print(f"Optimal threshold: {threshOpt}, Minimum eval metric score: {minScore}")
evaluate_and_log(
    model_xgboost_reduced, 
    X_valid_reduced, y_valid,
    experiment_name=EXPERIMENT_NAME, run_name="XGBoost_Optuna_Reduced", 
    hp_search_history=hist_df, hp_search_plots= plot_paths, 
    prediction_threshold=threshOpt)
# Out:
# Optimal threshold: 8.940413681557402e-05, Minimum eval metric score: 0.4438056693873404
# [INFO] Logged metrics: {'roc_auc': np.float64(0.9772594974500788), 'pr_auc': np.float64(0.9132602394981091), 'precision': 0.08599723139175806, 'recall': 0.9770142753447859, 'f1': 0.15808017538365174, 'custom_loss': np.float64(0.4438056693873404)}
# [INFO] Logged SHAP summary plot.
# 2025/12/04 16:14:51 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# [INFO] Evaluation complete and logged.
# {'roc_auc': np.float64(0.9772594974500788),
#  'pr_auc': np.float64(0.9132602394981091),
#  'precision': 0.08599723139175806,
#  'recall': 0.9770142753447859,
#  'f1': 0.15808017538365174,
#  'custom_loss': np.float64(0.4438056693873404)}

# %% [markdown]
# ### 2.2. LightGBM

# %%
model_lgmb_reduced, best_params_lgmb_reduced, hist_df, plot_paths = train_lgbm_optuna(X_train_reduced, y_train,X_train_reduced, y_train, X_valid_reduced, y_valid, n_trials=30)
evaluate_and_log(model_lgmb_reduced, X_valid_reduced, y_valid, experiment_name=EXPERIMENT_NAME, run_name="LGBM_Optuna_Reduced", hp_search_history=hist_df, hp_search_plots= plot_paths)
evaluate_and_log(model_lgmb_reduced, X_valid_reduced, y_valid, experiment_name=EXPERIMENT_NAME, run_name="LGBM_Optuna_Reduced", hp_search_history=hist_df, hp_search_plots= plot_paths, prediction_threshold=0.25)
# Out:
# [I 2025-12-04 16:14:51,420] A new study created in memory with name: lgbm_aucpr_optimization
# [Optuna LightGBM Tuning]:   0%|          | 0/30 [00:00<?, ?trial/s]
# [I 2025-12-04 16:15:15,244] Trial 0 finished with value: 0.3649651158860292 and parameters: {'num_leaves': 154, 'max_depth': 10, 'learning_rate': 0.07818826768085109, 'feature_fraction': 0.9708317533394086, 'bagging_fraction': 0.9465268769671564, 'bagging_freq': 3, 'min_child_samples': 32, 'lambda_l1': 7.226811826299855e-05, 'lambda_l2': 2.530288493438748e-06}. Best is trial 0 with value: 0.3649651158860292.
# [I 2025-12-04 16:15:40,221] Trial 1 finished with value: 0.4357502758764789 and parameters: {'num_leaves': 96, 'max_depth': 17, 'learning_rate': 0.030688501428436876, 'feature_fraction': 0.6525009460832843, 'bagging_fraction': 0.9802238149545179, 'bagging_freq': 1, 'min_child_samples': 65, 'lambda_l1': 3.548066991375513e-08, 'lambda_l2': 0.0049208112880928245}. Best is trial 1 with value: 0.4357502758764789.
# [I 2025-12-04 16:15:57,970] Trial 2 finished with value: 0.2678817250144218 and parameters: {'num_leaves': 27, 'max_depth': 12, 'learning_rate': 0.08276828313328968, 'feature_fraction': 0.6463822363322019, 'bagging_fraction': 0.9258597769911485, 'bagging_freq': 10, 'min_child_samples': 28, 'lambda_l1': 0.7096431094470825, 'lambda_l2': 9.189796986983384e-08}. Best is trial 1 with value: 0.4357502758764789.
# [I 2025-12-04 16:16:26,243] Trial 3 finished with value: 0.4632378101913263 and parameters: {'num_leaves': 155, 'max_depth': 19, 'learning_rate': 0.032907341441621954, 'feature_fraction': 0.7609248950700332, 'bagging_fraction': 0.8076367525464778, 'bagging_freq': 1, 'min_child_samples': 14, 'lambda_l1': 5.193893017599048e-05, 'lambda_l2': 0.0002966039412659312}. Best is trial 3 with value: 0.4632378101913263.
# [I 2025-12-04 16:16:44,742] Trial 4 finished with value: 0.27881308276688577 and parameters: {'num_leaves': 41, 'max_depth': 14, 'learning_rate': 0.1367067755506105, 'feature_fraction': 0.6537339580583184, 'bagging_fraction': 0.8883440350413879, 'bagging_freq': 5, 'min_child_samples': 84, 'lambda_l1': 3.089832298291744e-07, 'lambda_l2': 0.0006683058098640906}. Best is trial 3 with value: 0.4632378101913263.
# [I 2025-12-04 16:17:09,236] Trial 5 finished with value: 0.3806834267058654 and parameters: {'num_leaves': 189, 'max_depth': 10, 'learning_rate': 0.057590371403906826, 'feature_fraction': 0.9065778326298791, 'bagging_fraction': 0.8526011384950816, 'bagging_freq': 10, 'min_child_samples': 76, 'lambda_l1': 1.5263205592170923, 'lambda_l2': 6.799873191430393e-05}. Best is trial 3 with value: 0.4632378101913263.
# [I 2025-12-04 16:17:29,634] Trial 6 finished with value: 0.26767439806660787 and parameters: {'num_leaves': 64, 'max_depth': 19, 'learning_rate': 0.10303969720318909, 'feature_fraction': 0.7455552071519064, 'bagging_fraction': 0.6248894163261699, 'bagging_freq': 5, 'min_child_samples': 78, 'lambda_l1': 3.2199932791186146e-06, 'lambda_l2': 2.991742251694528}. Best is trial 3 with value: 0.4632378101913263.
# [I 2025-12-04 16:19:08,074] Trial 7 finished with value: 0.8387083565616397 and parameters: {'num_leaves': 242, 'max_depth': 10, 'learning_rate': 0.20819177182316687, 'feature_fraction': 0.8893499011666283, 'bagging_fraction': 0.638849449910523, 'bagging_freq': 1, 'min_child_samples': 69, 'lambda_l1': 0.0005904029258078435, 'lambda_l2': 0.07869312027117527}. Best is trial 7 with value: 0.8387083565616397.
# [I 2025-12-04 16:19:42,607] Trial 8 finished with value: 0.575080300078111 and parameters: {'num_leaves': 224, 'max_depth': 16, 'learning_rate': 0.01283985144065461, 'feature_fraction': 0.639739526882097, 'bagging_fraction': 0.7807016258006523, 'bagging_freq': 9, 'min_child_samples': 48, 'lambda_l1': 1.933078810938518e-06, 'lambda_l2': 0.0011603769122264759}. Best is trial 7 with value: 0.8387083565616397.
# [I 2025-12-04 16:20:04,088] Trial 9 finished with value: 0.29631926685007093 and parameters: {'num_leaves': 69, 'max_depth': 18, 'learning_rate': 0.06698831833277061, 'feature_fraction': 0.792655701974359, 'bagging_fraction': 0.7802151178234071, 'bagging_freq': 5, 'min_child_samples': 91, 'lambda_l1': 5.1522823835165523e-08, 'lambda_l2': 2.277751499035544}. Best is trial 7 with value: 0.8387083565616397.
# [I 2025-12-04 16:21:33,853] Trial 10 finished with value: 0.818405404209179 and parameters: {'num_leaves': 230, 'max_depth': 14, 'learning_rate': 0.24447177243193124, 'feature_fraction': 0.8759628676321364, 'bagging_fraction': 0.6181384852957487, 'bagging_freq': 8, 'min_child_samples': 52, 'lambda_l1': 0.01450427035434689, 'lambda_l2': 0.054440348619551285}. Best is trial 7 with value: 0.8387083565616397.
# [I 2025-12-04 16:22:39,041] Trial 11 finished with value: 0.7522905639696512 and parameters: {'num_leaves': 255, 'max_depth': 14, 'learning_rate': 0.2816372725274161, 'feature_fraction': 0.8783880582651815, 'bagging_fraction': 0.6115116738900669, 'bagging_freq': 8, 'min_child_samples': 53, 'lambda_l1': 0.011958935109903531, 'lambda_l2': 0.07270554934981585}. Best is trial 7 with value: 0.8387083565616397.
# [I 2025-12-04 16:24:05,936] Trial 12 finished with value: 0.8257026042355898 and parameters: {'num_leaves': 256, 'max_depth': 13, 'learning_rate': 0.24438938765289267, 'feature_fraction': 0.8609445974627224, 'bagging_fraction': 0.6884677555976227, 'bagging_freq': 7, 'min_child_samples': 63, 'lambda_l1': 0.0073408049880964886, 'lambda_l2': 0.042131245072629574}. Best is trial 7 with value: 0.8387083565616397.
# [I 2025-12-04 16:25:51,691] Trial 13 finished with value: 0.8524783676018122 and parameters: {'num_leaves': 200, 'max_depth': 12, 'learning_rate': 0.175165128085638, 'feature_fraction': 0.9774738812858256, 'bagging_fraction': 0.7080860077628457, 'bagging_freq': 7, 'min_child_samples': 67, 'lambda_l1': 0.005213659800166604, 'lambda_l2': 0.0806031673104345}. Best is trial 13 with value: 0.8524783676018122.
# [I 2025-12-04 16:27:35,310] Trial 14 finished with value: 0.8558646789460139 and parameters: {'num_leaves': 194, 'max_depth': 11, 'learning_rate': 0.15305171337594348, 'feature_fraction': 0.9943858806921546, 'bagging_fraction': 0.6982239676098684, 'bagging_freq': 3, 'min_child_samples': 68, 'lambda_l1': 0.0013572802384382036, 'lambda_l2': 0.3992126475602348}. Best is trial 14 with value: 0.8558646789460139.
# [I 2025-12-04 16:27:59,054] Trial 15 finished with value: 0.3042057039263873 and parameters: {'num_leaves': 198, 'max_depth': 12, 'learning_rate': 0.1332207226463566, 'feature_fraction': 0.9953921636316252, 'bagging_fraction': 0.7085783217391096, 'bagging_freq': 3, 'min_child_samples': 97, 'lambda_l1': 0.11648483327923843, 'lambda_l2': 4.366428021481879}. Best is trial 14 with value: 0.8558646789460139.
# [I 2025-12-04 16:29:48,980] Trial 16 finished with value: 0.8597889539738991 and parameters: {'num_leaves': 193, 'max_depth': 12, 'learning_rate': 0.147977156544817, 'feature_fraction': 0.9573895135386917, 'bagging_fraction': 0.7087871923223472, 'bagging_freq': 3, 'min_child_samples': 41, 'lambda_l1': 0.0005596470244140779, 'lambda_l2': 0.4132086083554194}. Best is trial 16 with value: 0.8597889539738991.
# [I 2025-12-04 16:30:12,369] Trial 17 finished with value: 0.4045772199547195 and parameters: {'num_leaves': 121, 'max_depth': 11, 'learning_rate': 0.040410036813861745, 'feature_fraction': 0.9357005411349577, 'bagging_fraction': 0.7270780498502165, 'bagging_freq': 4, 'min_child_samples': 43, 'lambda_l1': 0.00035095779492807876, 'lambda_l2': 0.6364918252415094}. Best is trial 16 with value: 0.8597889539738991.
# [I 2025-12-04 16:30:42,150] Trial 18 finished with value: 0.5179236761118747 and parameters: {'num_leaves': 174, 'max_depth': 15, 'learning_rate': 0.020325926873514064, 'feature_fraction': 0.9398011317638394, 'bagging_fraction': 0.6774327394635902, 'bagging_freq': 3, 'min_child_samples': 39, 'lambda_l1': 2.842969715104288e-05, 'lambda_l2': 9.153305799227132e-06}. Best is trial 16 with value: 0.8597889539738991.
# [I 2025-12-04 16:31:04,495] Trial 19 finished with value: 0.3644729019319912 and parameters: {'num_leaves': 126, 'max_depth': 11, 'learning_rate': 0.13230874162564527, 'feature_fraction': 0.8253775363934714, 'bagging_fraction': 0.7447562365360708, 'bagging_freq': 2, 'min_child_samples': 23, 'lambda_l1': 0.10760227588213155, 'lambda_l2': 0.00614256892857412}. Best is trial 16 with value: 0.8597889539738991.
# [I 2025-12-04 16:40:41,673] Trial 27 finished with value: 0.860783130435926 and parameters: {'num_leaves': 118, 'max_depth': 13, 'learning_rate': 0.20550966993327444, 'feature_fraction': 0.9580990845246821, 'bagging_fraction': 0.8639091073543712, 'bagging_freq': 6, 'min_child_samples': 78, 'lambda_l1': 0.0007551545136847769, 'lambda_l2': 0.9662580940011571}. Best is trial 23 with value: 0.8651776056604138.
# [I 2025-12-04 16:42:08,389] Trial 28 finished with value: 0.8599275789038258 and parameters: {'num_leaves': 110, 'max_depth': 16, 'learning_rate': 0.20670986794252647, 'feature_fraction': 0.9050687638351066, 'bagging_fraction': 0.880619901509651, 'bagging_freq': 7, 'min_child_samples': 77, 'lambda_l1': 0.04217317637404419, 'lambda_l2': 0.0021893354785860837}. Best is trial 23 with value: 0.8651776056604138.
# [I 2025-12-04 16:42:29,558] Trial 29 finished with value: 0.30784171659430615 and parameters: {'num_leaves': 92, 'max_depth': 13, 'learning_rate': 0.07948407581602503, 'feature_fraction': 0.6974418462100834, 'bagging_fraction': 0.9233995299567553, 'bagging_freq': 6, 'min_child_samples': 91, 'lambda_l1': 0.00010441138474449523, 'lambda_l2': 1.5696866353392775e-08}. Best is trial 23 with value: 0.8651776056604138.
# [INFO] Best LightGBM params: {'num_leaves': 169, 'max_depth': 13, 'learning_rate': 0.16498113155739738, 'feature_fraction': 0.9586765310450978, 'bagging_fraction': 0.8218429541917868, 'bagging_freq': 6, 'min_child_samples': 81, 'lambda_l1': 0.00220500614939493, 'lambda_l2': 0.010291676687411806}
# [INFO] Logged metrics: {'roc_auc': np.float64(0.9773062050072636), 'pr_auc': np.float64(0.9068656651169572), 'precision': 0.9211297628563816, 'recall': 0.8364384224534237, 'f1': 0.8767435962465128, 'custom_loss': np.float64(0.5748636840857521)}
# [INFO] Logged SHAP summary plot.
# 2025/12/04 16:43:38 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# [INFO] Evaluation complete and logged.
# [INFO] Logged metrics: {'roc_auc': np.float64(0.9773062050072636), 'pr_auc': np.float64(0.9068656651169572), 'precision': 0.8433592828497287, 'recall': 0.8649891120251633, 'f1': 0.8540372670807453, 'custom_loss': np.float64(0.47807091814271685)}
# [INFO] Logged SHAP summary plot.
# 2025/12/04 16:43:56 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# [INFO] Evaluation complete and logged.
# {'roc_auc': np.float64(0.9773062050072636),
#  'pr_auc': np.float64(0.9068656651169572),
#  'precision': 0.8433592828497287,
#  'recall': 0.8649891120251633,
#  'f1': 0.8540372670807453,
#  'custom_loss': np.float64(0.47807091814271685)}

# %%
threshOpt, minScore = minimize_eval_metric_with_threshold(model_lgmb_reduced, X_valid_reduced, y_valid)
print(f"Optimal threshold: {threshOpt}, Minimum eval metric score: {minScore}")
evaluate_and_log(
    model_lgmb_reduced, 
    X_valid_reduced, y_valid,
    experiment_name=EXPERIMENT_NAME, run_name="LGBM_Optuna_Reduced", 
    hp_search_history=hist_df, hp_search_plots= plot_paths, 
    prediction_threshold=threshOpt)
# Out:
# Optimal threshold: 0.002786915222931217, Minimum eval metric score: 0.30500897483659023
# [INFO] Logged metrics: {'roc_auc': np.float64(0.9773062050072636), 'pr_auc': np.float64(0.9068656651169572), 'precision': 0.18891977379468994, 'recall': 0.953786595693201, 'f1': 0.31537261490459617, 'custom_loss': np.float64(0.30500897483659023)}
# [INFO] Logged SHAP summary plot.
# 2025/12/04 16:44:16 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# [INFO] Evaluation complete and logged.
# {'roc_auc': np.float64(0.9773062050072636),
#  'pr_auc': np.float64(0.9068656651169572),
#  'precision': 0.18891977379468994,
#  'recall': 0.953786595693201,
#  'f1': 0.31537261490459617,
#  'custom_loss': np.float64(0.30500897483659023)}

# %% [markdown]
# ### 2.3. CatBoost

# %%
model_catoost_reduced, best_params_catoost_reduced, hist_df, plot_paths = train_catboost_optuna(X_train_reduced, y_train, X_train_reduced, y_train, X_valid_reduced, y_valid, n_trials=30)
evaluate_and_log(model_catoost_reduced, X_valid_reduced, y_valid, experiment_name=EXPERIMENT_NAME, run_name="CATBoost_Optuna_Reduced", hp_search_history=hist_df, hp_search_plots= plot_paths)
evaluate_and_log(model_catoost_reduced, X_valid_reduced, y_valid, experiment_name=EXPERIMENT_NAME, run_name="CATBoost_Optuna_Reduced", hp_search_history=hist_df, hp_search_plots= plot_paths, prediction_threshold=0.25)
# Out:
# [I 2025-12-04 16:44:16,902] A new study created in memory with name: catboost_aucpr_optimization
# [Optuna CatBoost Tuning]:   0%|          | 0/30 [00:00<?, ?trial/s]
# [I 2025-12-04 17:10:15,109] Trial 0 finished with value: 0.8391740681370675 and parameters: {'learning_rate': 0.16955881882276694, 'depth': 10, 'l2_leaf_reg': 1.8440763087524017, 'subsample': 0.8991191065727072, 'border_count': 100}. Best is trial 0 with value: 0.8391740681370675.
# [I 2025-12-04 17:18:31,617] Trial 1 finished with value: 0.6422839073671373 and parameters: {'learning_rate': 0.11848791671646595, 'depth': 5, 'l2_leaf_reg': 6.8641793249297445, 'subsample': 0.6374770173673866, 'border_count': 45}. Best is trial 0 with value: 0.8391740681370675.
# [I 2025-12-04 17:33:48,563] Trial 2 finished with value: 0.7409910860232771 and parameters: {'learning_rate': 0.09219575657073187, 'depth': 8, 'l2_leaf_reg': 1.5198720901163405, 'subsample': 0.8610808219451966, 'border_count': 90}. Best is trial 0 with value: 0.8391740681370675.
# [I 2025-12-04 17:50:15,351] Trial 3 finished with value: 0.8062916699587177 and parameters: {'learning_rate': 0.17484878825430017, 'depth': 9, 'l2_leaf_reg': 1.3438115538481763, 'subsample': 0.6197787018857407, 'border_count': 102}. Best is trial 0 with value: 0.8391740681370675.
# [I 2025-12-04 18:07:51,124] Trial 4 finished with value: 0.6798342914468871 and parameters: {'learning_rate': 0.04131425319381325, 'depth': 9, 'l2_leaf_reg': 2.042971111098198, 'subsample': 0.7889355728487379, 'border_count': 114}. Best is trial 0 with value: 0.8391740681370675.
# [I 2025-12-04 18:19:34,648] Trial 5 finished with value: 0.6834813624753209 and parameters: {'learning_rate': 0.1388061844383211, 'depth': 6, 'l2_leaf_reg': 5.199680661595989, 'subsample': 0.6874761273771817, 'border_count': 50}. Best is trial 0 with value: 0.8391740681370675.
# [I 2025-12-04 18:31:23,351] Trial 6 finished with value: 0.5400099843798062 and parameters: {'learning_rate': 0.021716913158379116, 'depth': 6, 'l2_leaf_reg': 2.3586207857304475, 'subsample': 0.6033988901130215, 'border_count': 52}. Best is trial 0 with value: 0.8391740681370675.
# [I 2025-12-04 18:53:32,400] Trial 7 finished with value: 0.812532996261341 and parameters: {'learning_rate': 0.1696135489183319, 'depth': 9, 'l2_leaf_reg': 1.2941856258429811, 'subsample': 0.7175470280052151, 'border_count': 41}. Best is trial 0 with value: 0.8391740681370675.
# [INFO] Logged metrics: {'roc_auc': np.float64(0.9754692979595376), 'pr_auc': np.float64(0.8970774703292203), 'precision': 0.8177898797367824, 'recall': 0.8720058069199129, 'f1': 0.8440281030444965, 'custom_loss': np.float64(0.4546940088732347)}
# [INFO] Logged SHAP summary plot.
# 2025/12/05 03:43:20 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# [INFO] Evaluation complete and logged.
# [INFO] Logged metrics: {'roc_auc': np.float64(0.9754692979595376), 'pr_auc': np.float64(0.8970774703292203), 'precision': 0.6309925725860904, 'recall': 0.9044277764335834, 'f1': 0.7433628318584071, 'custom_loss': np.float64(0.3529481491516239)}
# [INFO] Logged SHAP summary plot.
# 2025/12/05 03:44:56 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# [INFO] Evaluation complete and logged.
# {'roc_auc': np.float64(0.9754692979595376),
#  'pr_auc': np.float64(0.8970774703292203),
#  'precision': 0.6309925725860904,
#  'recall': 0.9044277764335834,
#  'f1': 0.7433628318584071,
#  'custom_loss': np.float64(0.3529481491516239)}

# %%
threshOpt, minScore = minimize_eval_metric_with_threshold(model_catoost_reduced, X_valid_reduced, y_valid)
print(f"Optimal threshold: {threshOpt}, Minimum eval metric score: {minScore}")
evaluate_and_log(
    model_catoost_reduced, 
    X_valid_reduced, y_valid,
    experiment_name=EXPERIMENT_NAME, run_name="CATBoost_Optuna_Reduced", 
    hp_search_history=hist_df, hp_search_plots= plot_paths, 
    prediction_threshold=threshOpt)
# Out:
# Optimal threshold: 0.05759661424438101, Minimum eval metric score: 0.30367968300199816
# [INFO] Logged metrics: {'roc_auc': np.float64(0.9754692979595376), 'pr_auc': np.float64(0.8970774703292203), 'precision': 0.29011697660467906, 'recall': 0.9361238809581418, 'f1': 0.4429560936516114, 'custom_loss': np.float64(0.30367968300199816)}
# [INFO] Logged SHAP summary plot.
# 2025/12/05 03:46:31 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# [INFO] Evaluation complete and logged.
# {'roc_auc': np.float64(0.9754692979595376),
#  'pr_auc': np.float64(0.8970774703292203),
#  'precision': 0.29011697660467906,
#  'recall': 0.9361238809581418,
#  'f1': 0.4429560936516114,
#  'custom_loss': np.float64(0.30367968300199816)}

# %% [markdown]
# ## 3. Ensemble

# %%
base_models, X_tr, X_va, y_tr, y_va, X_test, y_test, best_params_dict = train_best_base_models_from_mlflow(
    train, target, test_size=0.15 ,experiment_name=EXPERIMENT_NAME
)

# %% [markdown]
# ### 3.1. Logistic

# %%
# Build train meta features
X_meta = pd.DataFrame(np.column_stack([m.predict_proba(X_train_reduced)[:, 1] for m in [model_xgboost_reduced, model_lgmb_reduced, model_catoost_reduced]]))
X_meta_val = pd.DataFrame(np.column_stack([m.predict_proba(X_valid_reduced)[:, 1] for m in  [model_xgboost_reduced, model_lgmb_reduced, model_catoost_reduced]]))

# %%
ensemble, best_params_log, hist_df, plot_paths = train_ensemble(
    X_meta, y_train, X_meta_val, y_valid
)
# Out:
# [I 2025-12-05 03:46:48,671] A new study created in memory with name: ensemble_meta_learner_pr_auc_optimization
# [INFO] Generating meta-features...
# [INFO] Optimizing meta-learner with Optuna...
# [Optuna Ensemble Meta-Learner Tuning]:   0%|          | 0/30 [00:00<?, ?trial/s]
# [I 2025-12-05 03:47:04,967] Trial 0 finished with value: 1.0 and parameters: {'C': 0.04009477966365624, 'class_weight': None, 'solver': 'sag', 'penalty_sag': None}. Best is trial 0 with value: 1.0.
# [I 2025-12-05 03:49:41,101] Trial 1 finished with value: 1.0 and parameters: {'C': 1.7519066126045513, 'class_weight': 'balanced', 'solver': 'saga', 'penalty_saga': 'l1'}. Best is trial 0 with value: 1.0.
# [I 2025-12-05 03:49:42,281] Trial 2 finished with value: 1.0 and parameters: {'C': 0.04268818260828977, 'class_weight': 'balanced', 'solver': 'lbfgs', 'penalty_lbfgs': None}. Best is trial 0 with value: 1.0.
# [I 2025-12-05 03:50:33,764] Trial 3 finished with value: 1.0 and parameters: {'C': 35.759967400668934, 'class_weight': None, 'solver': 'saga', 'penalty_saga': 'l2'}. Best is trial 0 with value: 1.0.
# [I 2025-12-05 03:50:36,268] Trial 4 finished with value: 1.0 and parameters: {'C': 0.002622715531492202, 'class_weight': None, 'solver': 'sag', 'penalty_sag': 'l2'}. Best is trial 0 with value: 1.0.
# [I 2025-12-05 03:50:37,988] Trial 5 finished with value: 1.0 and parameters: {'C': 3.367493896429527, 'class_weight': None, 'solver': 'newton-cg', 'penalty_newton-cg': 'l2'}. Best is trial 0 with value: 1.0.
# [I 2025-12-05 03:50:40,086] Trial 6 finished with value: 1.0 and parameters: {'C': 0.06797042384447947, 'class_weight': None, 'solver': 'liblinear', 'penalty_liblinear': 'l1'}. Best is trial 0 with value: 1.0.
# [I 2025-12-05 03:50:42,790] Trial 7 finished with value: 1.0 and parameters: {'C': 0.0010516614779510166, 'class_weight': None, 'solver': 'sag', 'penalty_sag': 'l2'}. Best is trial 0 with value: 1.0.
# [I 2025-12-05 03:50:44,598] Trial 8 finished with value: 1.0 and parameters: {'C': 0.08766333286002653, 'class_weight': 'balanced', 'solver': 'newton-cg', 'penalty_newton-cg': None}. Best is trial 0 with value: 1.0.
# [I 2025-12-05 03:50:46,396] Trial 9 finished with value: 1.0 and parameters: {'C': 0.13187400238285446, 'class_weight': 'balanced', 'solver': 'newton-cg', 'penalty_newton-cg': 'l2'}. Best is trial 0 with value: 1.0.
# [I 2025-12-05 03:51:02,769] Trial 10 finished with value: 1.0 and parameters: {'C': 0.00028124878259657495, 'class_weight': None, 'solver': 'sag', 'penalty_sag': None}. Best is trial 0 with value: 1.0.
# [I 2025-12-05 03:53:41,053] Trial 11 finished with value: 1.0 and parameters: {'C': 2.491910340263526, 'class_weight': 'balanced', 'solver': 'saga', 'penalty_saga': 'l1'}. Best is trial 0 with value: 1.0.
# [I 2025-12-05 03:55:28,800] Trial 12 finished with value: 1.0 and parameters: {'C': 0.7592577565409198, 'class_weight': 'balanced', 'solver': 'saga', 'penalty_saga': 'elasticnet', 'l1_ratio': 0.9932582067545072}. Best is trial 0 with value: 1.0.
# [I 2025-12-05 03:55:30,113] Trial 13 finished with value: 1.0 and parameters: {'C': 0.006862329826282914, 'class_weight': 'balanced', 'solver': 'liblinear', 'penalty_liblinear': 'l2'}. Best is trial 0 with value: 1.0.
# [I 2025-12-05 03:55:31,098] Trial 14 finished with value: 1.0 and parameters: {'C': 79.49150972866026, 'class_weight': None, 'solver': 'lbfgs', 'penalty_lbfgs': 'l2'}. Best is trial 0 with value: 1.0.
# [I 2025-12-05 04:00:40,232] Trial 15 finished with value: 1.0 and parameters: {'C': 0.505197504669359, 'class_weight': 'balanced', 'solver': 'saga', 'penalty_saga': 'l1'}. Best is trial 0 with value: 1.0.
# [I 2025-12-05 04:00:56,619] Trial 16 finished with value: 1.0 and parameters: {'C': 10.788935982717675, 'class_weight': None, 'solver': 'sag', 'penalty_sag': None}. Best is trial 0 with value: 1.0.
# [I 2025-12-05 04:00:59,160] Trial 17 finished with value: 1.0 and parameters: {'C': 0.0145891150544282, 'class_weight': 'balanced', 'solver': 'sag', 'penalty_sag': None}. Best is trial 0 with value: 1.0.
# [I 2025-12-05 04:06:12,355] Trial 18 finished with value: 1.0 and parameters: {'C': 1.2934877591267249, 'class_weight': None, 'solver': 'saga', 'penalty_saga': 'l1'}. Best is trial 0 with value: 1.0.
# [I 2025-12-05 04:06:14,348] Trial 19 finished with value: 1.0 and parameters: {'C': 0.22788371236003369, 'class_weight': 'balanced', 'solver': 'liblinear', 'penalty_liblinear': 'l1'}. Best is trial 0 with value: 1.0.
# [I 2025-12-05 04:06:15,340] Trial 20 finished with value: 1.0 and parameters: {'C': 7.422696850507776, 'class_weight': None, 'solver': 'lbfgs', 'penalty_lbfgs': None}. Best is trial 0 with value: 1.0.
# [I 2025-12-05 04:06:16,518] Trial 21 finished with value: 1.0 and parameters: {'C': 0.02763999819746995, 'class_weight': 'balanced', 'solver': 'lbfgs', 'penalty_lbfgs': None}. Best is trial 0 with value: 1.0.
# [I 2025-12-05 04:06:17,688] Trial 22 finished with value: 1.0 and parameters: {'C': 0.029086074882509836, 'class_weight': 'balanced', 'solver': 'lbfgs', 'penalty_lbfgs': None}. Best is trial 0 with value: 1.0.
# [I 2025-12-05 04:06:18,866] Trial 23 finished with value: 1.0 and parameters: {'C': 0.3284963428671572, 'class_weight': 'balanced', 'solver': 'lbfgs', 'penalty_lbfgs': 'l2'}. Best is trial 0 with value: 1.0.
# [I 2025-12-05 04:06:20,052] Trial 24 finished with value: 1.0 and parameters: {'C': 0.004588373841910678, 'class_weight': 'balanced', 'solver': 'lbfgs', 'penalty_lbfgs': None}. Best is trial 0 with value: 1.0.
# [I 2025-12-05 04:06:27,448] Trial 25 finished with value: 1.0 and parameters: {'C': 0.04424490271941901, 'class_weight': 'balanced', 'solver': 'saga', 'penalty_saga': 'elasticnet', 'l1_ratio': 0.14961204720501042}. Best is trial 0 with value: 1.0.
# [I 2025-12-05 04:06:30,005] Trial 26 finished with value: 1.0 and parameters: {'C': 0.0008125606824974431, 'class_weight': 'balanced', 'solver': 'sag', 'penalty_sag': None}. Best is trial 0 with value: 1.0.
# [I 2025-12-05 04:06:31,176] Trial 27 finished with value: 1.0 and parameters: {'C': 0.011311164999366997, 'class_weight': 'balanced', 'solver': 'lbfgs', 'penalty_lbfgs': None}. Best is trial 0 with value: 1.0.
# [I 2025-12-05 04:06:34,635] Trial 28 finished with value: 1.0 and parameters: {'C': 0.18209582529087873, 'class_weight': None, 'solver': 'saga', 'penalty_saga': 'l2'}. Best is trial 0 with value: 1.0.
# [I 2025-12-05 04:06:51,073] Trial 29 finished with value: 1.0 and parameters: {'C': 26.924300842887817, 'class_weight': None, 'solver': 'sag', 'penalty_sag': None}. Best is trial 0 with value: 1.0.
# [INFO] Best meta-learner params: {'C': 0.04009477966365624, 'class_weight': None, 'solver': 'sag', 'penalty_sag': None}
# [INFO] Ensemble validation PR-AUC: 0.9043
# [INFO] Ensemble validation ROC-AUC: 0.9785

# %%
evaluate_and_log(ensemble, X_meta_val, y_valid, experiment_name=EXPERIMENT_NAME, run_name="Ensemble_from_best_base_models", hp_search_history=hist_df)
# Out:
# [INFO] Logged metrics: {'roc_auc': np.float64(0.9784540736883788), 'pr_auc': np.float64(0.904260950338986), 'precision': 0.9380697050938338, 'recall': 0.846600532300992, 'f1': 0.8899910975454661, 'custom_loss': np.float64(0.5387526670504962)}
# [WARN] SHAP skipped: Model type not yet supported by TreeExplainer: <class 'sklearn.linear_model._logistic.LogisticRegression'>
# 2025/12/05 04:06:58 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# [INFO] Evaluation complete and logged.
# {'roc_auc': np.float64(0.9784540736883788),
#  'pr_auc': np.float64(0.904260950338986),
#  'precision': 0.9380697050938338,
#  'recall': 0.846600532300992,
#  'f1': 0.8899910975454661,
#  'custom_loss': np.float64(0.5387526670504962)}

# %% [markdown]
# ### 3.2. NN

# %%
nn_model, base_mdls, X_val, y_val, X_test, y_test, params, hist, plots = train_neural_network_ensemble(
    base_models=base_models,
    X_tr=X_tr,
    y_tr=y_tr,
    X_va=X_va,
    y_va=y_va,
    X_test=X_test,
    y_test=y_test,
    n_trials=30,
    epochs=100
)

# %% [markdown]
# ## 4. create submission on test

# %%
import mlflow.pyfunc

model = mlflow.pyfunc.load_model("mlruns/306298534761506969/models/m-13e4ef05880a4806b656985753497758/artifacts").get_raw_model()

# %%
expected_features = [
    'C1', 'R_emaildomain', 'C14', 'P_emaildomain', 'id_31', 'uid_D3_mean', 
    'DeviceInfo', 'C13', 'ProductCD_TransactionAmt_rel', 'card1', 
    'uid_M4_freq', 'uid_C13_mean', 'uid_C13_std', 'uid_D2_mean', 
    'uid_C13_rel', 'uid_TransactionAmt_mean', 'card2', 'uid_C11_mean', 
    'uid_C1_mean', 'addr1', 'uid_V_PCA_4_mean', 'uid_D11_mean', 
    'uid_V_PCA_13_mean', 'uid_C2_mean', 'uid_C6_mean', 'C5', 'D3', 
    'uid_D2_std', 'card6', 'C8', 'uid_D11_std', 'M5', 'uid_card2_mean', 
    'uid_C14_mean', 'card6_TransactionAmt_mean', 'uid_dist1_mean', 'C11', 
    'hour_of_day', 'uid_TransactionAmt_std', 'uid_V_PCA_12_mean', 'id_30', 
    'uid_M5_freq', 'uid_card5_mean', 'uid_V_PCA_2_mean', 'uid_V_PCA_9_std', 
    'uid_V_PCA_5_mean', 'uid_V_PCA_11_mean', 'uid_D15_mean', 
    'uid_V_PCA_3_std', 'M4', 'uid_V_PCA_9_mean', 'uid_D10_mean', 
    'uid_M6_freq', 'uid_D5_mean', 'C2', 'uid_V_PCA_13_std', 
    'uid_DecimalPlaces_mean', 'card5', 'uid_V_PCA_4_std', 'D8', 
    'uid_C9_mean', 'uid_C1_std', 'uid_D10_std', 'uid_C14_rel', 'M6', 
    'uid_V_PCA_1_mean', 'D2', 'uid_P_emaildomain_freq', 'uid_C5_mean', 
    'uid_V_PCA_10_mean', 'id_02', 'uid_V_PCA_10_std', 'uid_V_PCA_3_mean', 
    'id_20', 'M3', 'V_PCA_2', 'uid_V_PCA_6_mean', 'uid_V_PCA_11_std', 
    'uid_V_PCA_7_std', 'card4', 'uid_V_PCA_8_mean', 'V_PCA_4', 
    'card6_TransactionAmt_rel', 'V_PCA_9', 'uid_D4_mean', 'uid_C6_std', 
    'C6', 'uid_hour_of_day_TransactionAmt_mean', 'dist1', 
    'TransactionAmt_Scaled', 'uid_V_PCA_5_std', 'uid_V_PCA_1_std', 'D4', 
    'uid_C9_std', 'D15', 'uid_C1_rel', 'day_of_week', 'uid_V_PCA_7_mean', 
    'id_05', 'uid_day_of_week_TransactionAmt_mean', 'uid_D5_std', 
    'uid_D3_std', 'uid_id_02_mean', 'uid_D4_std', 'uid_DecimalPlaces_rel', 
    'uid_V_PCA_12_std', 'uid_V_PCA_2_std', 'uid_C11_std', 'D10', 
    'uid_V_PCA_6_std', 'uid_C6_rel', 'uid_day_of_week_TransactionAmt_rel'
]

df_aligned = test[expected_features]

# %%
train = train[expected_features]

# %%
preds = model.predict_proba(df_aligned)

# %%
test['isFraud']=preds[:,1]

# %%
test[['TransactionID', 'isFraud']].to_csv(data_folder + "submission.csv", index=False)

# %%
test = pd.read_csv(f'test_processed.csv')
